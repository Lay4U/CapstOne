# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset_ori.csv')
del df['Unnamed: 0']
df
# Out:
#                  date  number            name   div     a    b    c     d  \
# 0         2008-01-01      150       서울역(150)    승차    379  287  371   876
# 1         2008-01-01      150       서울역(150)    하차    145  707  689  1037
# 2         2008-01-01      151        시청(151)    승차    131  131  101   152
# 3         2008-01-01      151        시청(151)    하차     35  158  203   393
# 4         2008-01-01      152        종각(152)    승차   1287  867  400   330
# 5         2008-01-01      152        종각(152)    하차     74  147  261   473
# 6         2008-01-01      153      종로3가(153)    승차    484  290  192   218
# 7         2008-01-01      153      종로3가(153)    하차     28   80  116   238
# 8         2008-01-01      154      종로5가(154)    승차     89   77   86   115
# 9         2008-01-01      154      종로5가(154)    하차     14   76   93   123
# 10        2008-01-01      155       동대문(155)    승차    190  149  152   253
# 11        2008-01-01      155       동대문(155)    하차     23  111  120   150
# ...

# %%
# df2 = pd.melt(df, id_vars=[" 날짜 ", " 역번호 ", " 역명 ", " 구분 "], value_name="t")
# df2 = pd.melt(df, id_vars=["location", "name"], var_name="Date", value_name="Value")
# df2 = pd.melt(df,id_vars=["date", "number", "name", "div","a","b",'c','d','e','f','g','h','i','j','k','l','m','o','p','q','r'], value_name='t')
df2 = pd.melt(df,id_vars=["date", "number", "name", "div","a","b",'c','d','e','f','g','h','i','j','k','l','m','o','p','q','r'], value_name='t')
df2
# Out:
#                  date  number            name   div     a    b    c     d  \
# 0         2008-01-01      150       서울역(150)    승차    379  287  371   876
# 1         2008-01-01      150       서울역(150)    하차    145  707  689  1037
# 2         2008-01-01      151        시청(151)    승차    131  131  101   152
# 3         2008-01-01      151        시청(151)    하차     35  158  203   393
# 4         2008-01-01      152        종각(152)    승차   1287  867  400   330
# 5         2008-01-01      152        종각(152)    하차     74  147  261   473
# 6         2008-01-01      153      종로3가(153)    승차    484  290  192   218
# 7         2008-01-01      153      종로3가(153)    하차     28   80  116   238
# 8         2008-01-01      154      종로5가(154)    승차     89   77   86   115
# 9         2008-01-01      154      종로5가(154)    하차     14   76   93   123
# 10        2008-01-01      155       동대문(155)    승차    190  149  152   253
# 11        2008-01-01      155       동대문(155)    하차     23  111  120   150
# ...

# %%
del df2['variable']

# %%
df2=df2.rename(columns = {' 날짜 ':'date'})
df2=df2.rename(columns = {' 역번호 ':'number'})
df2=df2.rename(columns = {' 역명 ':'name'})
df2=df2.rename(columns = {' 구분 ':'di'})

# %%
df2
# Out:
#                   date  number            name    di     t
# 0          2008-01-01      150       서울역(150)    승차    379
# 1          2008-01-01      150       서울역(150)    하차    145
# 2          2008-01-01      151        시청(151)    승차    131
# 3          2008-01-01      151        시청(151)    하차     35
# 4          2008-01-01      152        종각(152)    승차   1287
# 5          2008-01-01      152        종각(152)    하차     74
# 6          2008-01-01      153      종로3가(153)    승차    484
# 7          2008-01-01      153      종로3가(153)    하차     28
# 8          2008-01-01      154      종로5가(154)    승차     89
# 9          2008-01-01      154      종로5가(154)    하차     14
# 10         2008-01-01      155       동대문(155)    승차    190
# 11         2008-01-01      155       동대문(155)    하차     23
# 12         2008-01-01      156       신설동(156)    승차     65
# 13         2008-01-01      156       신설동(156)    하차     15
# 14         2008-01-01      157       제기동(157)    승차    156
# ...

# %%
df3 = df2.copy()
df3['t'] = df3.t - df3.t.shift(-1)
df3.drop_duplicates(['date','number','name'])
df3
# Out:
#                   date  number            name    di       t
# 0          2008-01-01      150       서울역(150)    승차    234.0
# 1          2008-01-01      150       서울역(150)    하차     14.0
# 2          2008-01-01      151        시청(151)    승차     96.0
# 3          2008-01-01      151        시청(151)    하차  -1252.0
# 4          2008-01-01      152        종각(152)    승차   1213.0
# 5          2008-01-01      152        종각(152)    하차   -410.0
# 6          2008-01-01      153      종로3가(153)    승차    456.0
# 7          2008-01-01      153      종로3가(153)    하차    -61.0
# 8          2008-01-01      154      종로5가(154)    승차     75.0
# 9          2008-01-01      154      종로5가(154)    하차   -176.0
# 10         2008-01-01      155       동대문(155)    승차    167.0
# 11         2008-01-01      155       동대문(155)    하차    -42.0
# 12         2008-01-01      156       신설동(156)    승차     50.0
# 13         2008-01-01      156       신설동(156)    하차   -141.0
# ...

# %%
df3 = df3.iloc[::2]

# %%
df3
# Out:
#                   date  number            name    di       t
# 0          2008-01-01      150       서울역(150)    승차    234.0
# 2          2008-01-01      151        시청(151)    승차     96.0
# 4          2008-01-01      152        종각(152)    승차   1213.0
# 6          2008-01-01      153      종로3가(153)    승차    456.0
# 8          2008-01-01      154      종로5가(154)    승차     75.0
# 10         2008-01-01      155       동대문(155)    승차    167.0
# 12         2008-01-01      156       신설동(156)    승차     50.0
# 14         2008-01-01      157       제기동(157)    승차    140.0
# 16         2008-01-01      158   청량리(지하)(158)    승차    174.0
# 18         2008-01-01      159       동묘앞(159)    승차     24.0
# 20         2008-01-01      201        시청(201)    승차     26.0
# 22         2008-01-01      202     을지로입구(202)    승차    132.0
# 24         2008-01-01      203     을지로3가(203)    승차     11.0
# 26         2008-01-01      204     을지로4가(204)    승차      3.0
# ...

# %%
del df3['di']

# %%
df3.to_csv('gg.csv')

# %%
df = pd.read_csv('gg.csv')

# %%
df
# Out:
#           Unnamed: 0          date  number            name       t
# 0                  0   2008-01-01      150       서울역(150)    234.0
# 1                  2   2008-01-01      151        시청(151)     96.0
# 2                  4   2008-01-01      152        종각(152)   1213.0
# 3                  6   2008-01-01      153      종로3가(153)    456.0
# 4                  8   2008-01-01      154      종로5가(154)     75.0
# 5                 10   2008-01-01      155       동대문(155)    167.0
# 6                 12   2008-01-01      156       신설동(156)     50.0
# 7                 14   2008-01-01      157       제기동(157)    140.0
# 8                 16   2008-01-01      158   청량리(지하)(158)    174.0
# 9                 18   2008-01-01      159       동묘앞(159)     24.0
# 10                20   2008-01-01      201        시청(201)     26.0
# 11                22   2008-01-01      202     을지로입구(202)    132.0
# 12                24   2008-01-01      203     을지로3가(203)     11.0
# ...

# %%
df
# Out:
#                  date  number            name   div     a    b    c     d  \
# 0         2008-01-01      150       서울역(150)    승차    379  287  371   876
# 1         2008-01-01      150       서울역(150)    하차    145  707  689  1037
# 2         2008-01-01      151        시청(151)    승차    131  131  101   152
# 3         2008-01-01      151        시청(151)    하차     35  158  203   393
# 4         2008-01-01      152        종각(152)    승차   1287  867  400   330
# 5         2008-01-01      152        종각(152)    하차     74  147  261   473
# 6         2008-01-01      153      종로3가(153)    승차    484  290  192   218
# 7         2008-01-01      153      종로3가(153)    하차     28   80  116   238
# 8         2008-01-01      154      종로5가(154)    승차     89   77   86   115
# 9         2008-01-01      154      종로5가(154)    하차     14   76   93   123
# 10        2008-01-01      155       동대문(155)    승차    190  149  152   253
# 11        2008-01-01      155       동대문(155)    하차     23  111  120   150
# ...

# %%
letters = list("abcdefghijklmnopqrst")
df = pd.concat([df.iloc[:, 5:25]]).assign(t=df[letters[5:]].values[0])
df = df.reset_index(drop=True)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-802c5dda79ac> in <module>
#       1 letters = list("abcdefghijklmnopqrst")
# ----> 2 df = pd.concat([df.iloc[:, 5:25]]).assign(t=df[letters[5:]].values[0])
#       3 df = df.reset_index(drop=True)
#       4 df
#
# D:\Anaconda3\envs\me\lib\site-packages\pandas\core\frame.py in assign(self, **kwargs)
#    3539         if PY36:
#    3540             for k, v in kwargs.items():
# -> 3541                 data[k] = com.apply_if_callable(v, data)
#    3542         else:
#    3543             # <= 3.5: do all calculations first...
#
# D:\Anaconda3\envs\me\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3358         else:
#    3359             # set column
# -> 3360             self._set_item(key, value)
#    3361
#    3362     def _setitem_slice(self, key, value):
#
# ...

# %%
df.iloc[:, 5:25]
# Out:
#            b    c     d     e     f     g     h     i     j     k     l     m  \
# 0        287  371   876   965  1389  1989  2375  2588  2885  2520  3078  3495
# 1        707  689  1037  1170  1376  1451  1743  1984  2077  1955  2304  2203
# 2        131  101   152   191   202   275   361   471   678   892   900  1154
# 3        158  203   393   375   460   591   841  1116  1148  1157  1153  1303
# 4        867  400   330   345   338   595   791  1182  1475  1867  2269  2777
# 5        147  261   473   597   698  1074  1719  1817  2089  2161  2298  2360
# 6        290  192   218   281   429   566   943  1238  1449  1652  2000  1768
# 7         80  116   238   390   609  1001  1680  2246  2387  1991  1896  1543
# 8         77   86   115   122   192   253   315   414   452   553   647   596
# 9         76   93   123   137   193   310   409   544   551   445   399   393
# 10       149  152   253   365   390   467   541   670   727   900   891   867
# ...

# %%
s=pd.Series(df.columns)
s[(s>='a').cummax()==1]='a'
df.columns=s
df=df.melt()

yourdf=df.set_index(['variable',df.groupby('variable').cumcount()]).\
          value.unstack(0).ffill()
yourdf
# Out:
# variable             a
# 0          2008-01-01
# 1          2008-01-01
# 2          2008-01-01
# 3          2008-01-01
# 4          2008-01-01
# 5          2008-01-01
# 6          2008-01-01
# 7          2008-01-01
# 8          2008-01-01
# 9          2008-01-01
# 10         2008-01-01
# 11         2008-01-01
# 12         2008-01-01
# 13         2008-01-01
# 14         2008-01-01
# 15         2008-01-01
# 16         2008-01-01
# 17         2008-01-01
# 18         2008-01-01
# 19         2008-01-01
# 20         2008-01-01
# 21         2008-01-01
# 22         2008-01-01
# 23         2008-01-01
# 24         2008-01-01
# 25         2008-01-01
# 26         2008-01-01
# 27         2008-01-01
# 28         2008-01-01
# 29         2008-01-01
# ...                ...
# 46128834            14
# 46128835           148
# 46128836             0
# 46128837            17
# 46128838             1
# 46128839            44
# 46128840             1
# 46128841            25
# 46128842             0
# ...

# %%
df
# Out:
#                  date  number            name   div     a    b    c     d  \
# 0         2008-01-01      150       서울역(150)    승차    379  287  371   876
# 1         2008-01-01      150       서울역(150)    하차    145  707  689  1037
# 2         2008-01-01      151        시청(151)    승차    131  131  101   152
# 3         2008-01-01      151        시청(151)    하차     35  158  203   393
# 4         2008-01-01      152        종각(152)    승차   1287  867  400   330
# 5         2008-01-01      152        종각(152)    하차     74  147  261   473
# 6         2008-01-01      153      종로3가(153)    승차    484  290  192   218
# 7         2008-01-01      153      종로3가(153)    하차     28   80  116   238
# 8         2008-01-01      154      종로5가(154)    승차     89   77   86   115
# 9         2008-01-01      154      종로5가(154)    하차     14   76   93   123
# 10        2008-01-01      155       동대문(155)    승차    190  149  152   253
# 11        2008-01-01      155       동대문(155)    하차     23  111  120   150
# ...

# %%
df1 = df.iloc[:,4:25]
df1 = df1.append([df1]*(len(df.iloc[:,4:25].T)-1))
df1.insert(df1.shape[1]+5,'a',list(df.iloc[:,4:25].values[0]))
df1
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-35-cae3a6fcb2af> in <module>
#       1 df1 = df.iloc[:,4:25]
# ----> 2 df1 = df1.append([df1]*(len(df.iloc[:,4:25].T)-1))
#       3 df1.insert(df1.shape[1]+5,'a',list(df.iloc[:,4:25].values[0]))
#       4 df1
#
# D:\Anaconda3\envs\me\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6699         return concat(to_concat, ignore_index=ignore_index,
#    6700                       verify_integrity=verify_integrity,
# -> 6701                       sort=sort)
#    6702
#    6703     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# D:\Anaconda3\envs\me\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
# ...

# %%
df1.shape[1]
# Out:
# 20
