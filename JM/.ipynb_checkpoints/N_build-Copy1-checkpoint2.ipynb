# %%
import pandas as pd
import numpy as np
import re
import requests
from bs4 import BeautifulSoup

# %%
from selenium import webdriver
 
path="C:\\Users\\wkdwj\\Downloads\\chromedriver_win32\\chromedriver"

# %%
#데이터 역명 불러오기
s=pd.read_csv('StationName.csv')
del s['Unnamed: 1']
s=s.dropna()

# %%
s=s['name']

# %%
s=list(s)
s
# Out:
# ["{'동대입구(322)'",
#  " '송정'",
#  " '신길(5)'",
#  " '고속터미널(329)'",
#  " '잠원(328)'",
#  " '마천'",
#  " '보문(6)'",
#  " '군자(7)'",
#  " '대청(337)'",
#  " '상동'",
#  " '길동'",
#  " '망원'",
#  " '구의(213)'",
#  " '장한평'",
#  " '잠실나루(215)'",
#  " '시청(151)'",
#  " '광흥창'",
#  " '신설동(246)'",
#  " '청구(6)'",
#  " '석계(6)'",
#  " '신풍'",
#  " '가락시장(340)'",
#  " '서울대입구(228)'",
#  " '불광(312)'",
#  " '이태원'",
#  " '송파'",
#  " '을지로3가(203)'",
#  " '왕십리(5)'",
#  " '수유(414)'",
#  " '상도'",
#  " '신설동(156)'",
#  " '도곡(334)'",
#  " '강동구청'",
#  " '석촌'",
#  " '부천종합운동장'",
#  " '신당(206)'",
#  " '압구정(326)'",
#  " '고속터미널(7)'",
#  " '굴포천'",
#  " '중계'",
#  " '문정'",
#  " '남한산성입구'",
#  " '을지로4가(204)'",
#  " '성수(211)'",
#  " '역삼(221)'",
#  " '미아삼거리(416)'",
#  " '월드컵경기장'",
#  " '먹골'",
#  " '공덕(6)'",
#  " '신흥'",
#  " '시청(201)'",
#  " '왕십리(208)'",
#  " '동작(431)'",
#  " '마곡'",
#  " '경찰병원(341)'",
#  " '봉천(229)'",
#  " '춘의'",
#  " '신도림(234)'",
#  " '삼각지(428)'",
#  " '대림(233)'",
#  " '산성'",
#  " '안암'",
#  " '당고개(409)'",
#  " '우장산'",
#  " '경복궁(317)'",
#  " '광명사거리'",
#  " '중화'",
#  " '돌곶이'",
#  " '용두(250)'",
#  " '천호(8)'",
#  " '삼산체육관'",
#  " '부평구청(7)'",
#  " '동대문역사문화공원5'",
#  " '둔촌동'",
#  " '뚝섬(210)'",
#  " '암사'",
#  " '태릉입구(6)'",
#  " '대림(7)'",
#  " '온수(7)'",
#  " '충무로(423)'",
#  " '지축(309)'",
#  " '남부터미널(331)'",
#  " '연신내(6)'",
#  " '성신여대입구(418)'",
#  " '여의나루'",
#  " '보라매'",
#  " '미아사거리(416)'",
#  " '청구(5)'",
#  " '불광(6)'",
#  " '양평(5)'",
#  " '상봉(7)'",
#  " '선릉(220)'",
#  " '용마산'",
#  " '남성'",
#  " '삼성(219)'",
#  " '개화산'",
#  " '영등포시장'",
#  " '복정(8)'",
#  " '영등포구청(236)'",
#  " '행당'",
#  " '창신'",
#  " '이촌(430)'",
#  " '마들'",
#  " '뚝섬유원지'",
#  " '양재(332)'",
#  " '광화문'",
#  " '논현'",
#  " '방이'",
#  " '반포'",
#  " '신대방삼거리'",
#  " '대흥'",
#  " '노원(7)'",
#  " '홍대입구(239)'",
#  " '쌍문(413)'",
#  " '왕십리(성동구청)(208)'",
#  " '종로3가(153)'",
#  " '김포공항(5)'",
#  " '사당(433)'",
#  " '종합운동장(218)'",
#  " '신대방(231)'",
#  " '종로3가(319)'",
#  " '동대문운동장(205)'",
#  " '응암'",
#  " '상일동'",
#  " '독바위'",
#  " '상계(410)'",
#  " '동묘앞(6)'",
#  " '방배(225)'",
#  " '노원(411)'",
#  " '동대문(421)'",
#  " '거여'",
#  " '아현(242)'",
#  " '구파발(310)'",
#  " '부천시청'",
#  " '금호(324)'",
#  " '마포구청'",
#  " '숭실대입구'",
#  " '용답(244)'",
#  " '건대입구(212)'",
#  " '하계'",
#  " '강동'",
#  " '낙성대(227)'",
#  " '서초(224)'",
#  " '수유(강북구청)(414)'",
#  " '미아(415)'",
#  " '건대입구(7)'",
#  " '을지로입구(202)'",
#  " '한성대입구(419)'",
#  " '무악재(315)'",
#  " '회현(425)'",
#  " '발산'",
#  " '군자(5)'",
#  " '고덕'",
#  " '새절'",
#  " '명동(424)'",
#  " '수서(339)'",
#  " '안국(318)'",
#  " '혜화(420)'",
#  " '모란(8)'",
#  " '사가정'",
#  " '숙대입구(427)'",
#  " '충정로(5)'",
#  " '디지털미디어시티(6)'",
#  " '학여울(336)'",
#  " '애오개'",
#  " '양천구청(248)'",
#  " '이수(7)'",
#  " '연신내(311)'",
#  " '공릉'",
#  " '신중동'",
#  " '창동(412)'",
#  " '면목'",
#  " '몽촌토성'",
#  " '신용산(429)'",
#  " '천호(5)'",
#  " '길음(417)'",
#  " '상수'",
#  " '상월곡'",
#  " '수락산'",
#  " '동대문(155)'",
#  " '동대문역사문화공원(422)'",
#  " '봉화산'",
#  " '버티고개'",
#  " '장지'",
#  " '아차산'",
#  " '학동'",
#  " '오금'",
#  " '중곡'",
#  " '영등포구청(5)'",
#  " '신림(230)'",
#  " '독립문(316)'",
#  " '오목교'",
#  " '개롱'",
#  " '공덕(5)'",
#  " '여의도(5)'",
#  " '서울역(150)'",
#  " '종로3가(5)'",
#  " '종각(152)'",
#  " '홍제(314)'",
#  " '강남구청'",
#  " '신금호'",
#  " '강변(214)'",
#  " '역촌'",
#  " '서대문'",
#  " '충정로(243)'",
#  " '태릉입구(7)'",
#  " '합정(238)'",
#  " '굽은다리'",
#  " '합정(6)'",
#  " '효창공원앞'",
#  " '삼각지(6)'",
#  " '신당(6)'",
#  " '신천(217)'",
#  " '청량리(지하)(158)'",
#  " '구산'",
#  " '남태령(434)'",
#  " '동대문운동장(422)'",
#  " '마장'",
#  " '천왕'",
#  " '보문'",
#  " '녹사평'",
#  " '단대오거리'",
#  " '장승배기'",
#  " '교대(223)'",
#  " '신정네거리(249)'",
#  " '신사(327)'",
#  " '대치(335)'",
#  " '을지로4가(5)'",
#  " '올림픽공원'",
#  " '고려대'",
#  " '을지로3가(320)'",
#  " '수진'",
#  " '구로디지털단지(232)'",
#  " '서울역(426)'",
#  " '제기동(157)'",
#  " '강남(222)'",
#  " '화랑대'",
#  " '까치울'",
#  " '철산'",
#  " '옥수(325)'",
#  " '도림천(247)'",
#  " '마포'",
#  " '내방'",
#  " '종로5가(154)'",
#  " '한양대(209)'",
#  " '사당(226)'",
#  " '당산(237)'",
#  " '월곡'",
#  " '가락시장(8)'",
#  " '도봉산(7)'",
#  " '남구로'",
#  " '어린이대공원'",
#  " '화곡'",
#  " '까치산(5)'",
#  " '매봉(333)'",
#  " '청담'",
#  " '상왕십리(207)'",
#  " '가산디지털단지(7)'",
#  " '방화'",
#  " '교대(330)'",
#  " '약수(6)'",
#  " '녹번(313)'",
#  " '성내(215)'",
#  " '신촌(240)'",
#  " '잠실(216)'",
#  " '동대문역사문화공원(205)'",
#  " '일원(338)'",
#  " '동묘앞(159)'",
#  " '오금(342)'",
#  " '이대(241)'",
#  " '증산'",
#  " '광나루'",
#  " '잠실(8)'",
#  " '신답(245)'",
#  " '장암'",
#  " '답십리'",
#  " '약수(323)'",
#  " '명일'",
#  " '목동'",
#  " '문래(235)'",
#  " '한강진'",
#  " '잠실새내(217)'",
#  " '신정'",
#  " '총신대입구(432)'}"]

# %%
#한글만 추출하여 역명 전처리

for i in range(len(s)):
    t = re.sub('{|\'|\'','', s[i])
    t = t.split("(")
    s[i]= t[0]
    s[i]=s[i].strip()

# %%
# s=list(set(s))
# s

# %%
s = list(sorted(set(s)))
s
# Out:
# ['가락시장',
#  '가산디지털단지',
#  '강남',
#  '강남구청',
#  '강동',
#  '강동구청',
#  '강변',
#  '개롱',
#  '개화산',
#  '거여',
#  '건대입구',
#  '경복궁',
#  '경찰병원',
#  '고덕',
#  '고려대',
#  '고속터미널',
#  '공덕',
#  '공릉',
#  '광나루',
#  '광명사거리',
#  '광화문',
#  '광흥창',
#  '교대',
#  '구로디지털단지',
#  '구산',
#  '구의',
#  '구파발',
#  '군자',
#  '굴포천',
#  '굽은다리',
#  '금호',
#  '길동',
#  '길음',
#  '김포공항',
#  '까치산',
#  '까치울',
#  '낙성대',
#  '남구로',
#  '남부터미널',
#  '남성',
#  '남태령',
#  '남한산성입구',
#  '내방',
#  '노원',
#  '녹번',
#  '녹사평',
#  '논현',
#  '단대오거리',
#  '답십리',
#  '당고개',
#  '당산',
#  '대림',
#  '대청',
#  '대치',
#  '대흥',
#  '도곡',
#  '도림천',
#  '도봉산',
#  '독립문',
#  '독바위',
#  '돌곶이',
#  '동대문',
#  '동대문역사문화공원',
#  '동대문역사문화공원5',
#  '동대문운동장',
#  '동대입구',
#  '동묘앞',
#  '동작',
#  '둔촌동',
#  '디지털미디어시티',
#  '뚝섬',
#  '뚝섬유원지',
#  '마곡',
#  '마들',
#  '마장',
#  '마천',
#  '마포',
#  '마포구청',
#  '망원',
#  '매봉',
#  '먹골',
#  '면목',
#  '명동',
#  '명일',
#  '모란',
#  '목동',
#  '몽촌토성',
#  '무악재',
#  '문래',
#  '문정',
#  '미아',
#  '미아사거리',
#  '미아삼거리',
#  '반포',
#  '발산',
#  '방배',
#  '방이',
#  '방화',
#  '버티고개',
#  '보라매',
#  '보문',
#  '복정',
#  '봉천',
#  '봉화산',
#  '부천시청',
#  '부천종합운동장',
#  '부평구청',
#  '불광',
#  '사가정',
#  '사당',
#  '산성',
#  '삼각지',
#  '삼산체육관',
#  '삼성',
#  '상계',
#  '상도',
#  '상동',
#  '상봉',
#  '상수',
#  '상왕십리',
#  '상월곡',
#  '상일동',
#  '새절',
#  '서대문',
#  '서울대입구',
#  '서울역',
#  '서초',
#  '석계',
#  '석촌',
#  '선릉',
#  '성내',
#  '성수',
#  '성신여대입구',
#  '송정',
#  '송파',
#  '수락산',
#  '수서',
#  '수유',
#  '수진',
#  '숙대입구',
#  '숭실대입구',
#  '시청',
#  '신금호',
#  '신길',
#  '신답',
#  '신당',
#  '신대방',
#  '신대방삼거리',
#  '신도림',
#  '신림',
#  '신사',
#  '신설동',
#  '신용산',
#  '신정',
#  '신정네거리',
#  '신중동',
#  '신천',
#  '신촌',
#  '신풍',
#  '신흥',
#  '쌍문',
#  '아차산',
#  '아현',
#  '안국',
#  '안암',
#  '암사',
#  '압구정',
#  '애오개',
#  '약수',
#  '양재',
#  '양천구청',
#  '양평',
#  '어린이대공원',
#  '여의나루',
#  '여의도',
#  '역삼',
#  '역촌',
#  '연신내',
#  '영등포구청',
#  '영등포시장',
#  '오금',
#  '오목교',
#  '옥수',
#  '온수',
#  '올림픽공원',
#  '왕십리',
#  '용답',
#  '용두',
#  '용마산',
#  '우장산',
#  '월곡',
#  '월드컵경기장',
#  '을지로3가',
#  '을지로4가',
#  '을지로입구',
#  '응암',
#  '이대',
#  '이수',
#  '이촌',
#  '이태원',
#  '일원',
#  '잠실',
#  '잠실나루',
#  '잠실새내',
#  '잠원',
#  '장승배기',
#  '장암',
#  '장지',
#  '장한평',
#  '제기동',
#  '종각',
#  '종로3가',
#  '종로5가',
#  '종합운동장',
#  '중계',
#  '중곡',
#  '중화',
#  '증산',
#  '지축',
#  '창동',
#  '창신',
#  '천왕',
#  '천호',
#  '철산',
#  '청구',
#  '청담',
#  '청량리',
#  '총신대입구',
#  '춘의',
#  '충무로',
#  '충정로',
#  '태릉입구',
#  '하계',
#  '학동',
#  '학여울',
#  '한강진',
#  '한성대입구',
#  '한양대',
#  '합정',
#  '행당',
#  '혜화',
#  '홍대입구',
#  '홍제',
#  '화곡',
#  '화랑대',
#  '회현',
#  '효창공원앞']

# %%
'''이상값 (1) 조정'''
#서울역->서울 변경완료
#동대문운동장->동대문역사문화공원 '동대문운동장' 삭제필
#성내->잠실나루 '성내' 삭제필
#신천->잠실새내(2015 이후 변경) '신천' value를 '잠실새내'에 넣고 '신천' 삭제필
#미아삼거리->미아사거리 '미아삼거리' 삭제필
#총신대입구,이수->총신대입구(이수) 두 역을 하나로 통합해 만들고 '총신대입구' '이수' 삭제 필

s[s.index("서울역")]="서울"

# %%
del s[s.index("성내")]

# %%
del s[s.index("동대문운동장")]

# %%
s.index("신천")#62개
del s[s.index("신천")]

# %%
del s[s.index("미아삼거리")]

# %%
s[s.index("이수")]="총신대입구(이수)"
del s[s.index("총신대입구")]

# %%
del s[s.index("동대문역사문화공원5")]

# %%
s
# Out:
# ['가락시장',
#  '가산디지털단지',
#  '강남',
#  '강남구청',
#  '강동',
#  '강동구청',
#  '강변',
#  '개롱',
#  '개화산',
#  '거여',
#  '건대입구',
#  '경복궁',
#  '경찰병원',
#  '고덕',
#  '고려대',
#  '고속터미널',
#  '공덕',
#  '공릉',
#  '광나루',
#  '광명사거리',
#  '광화문',
#  '광흥창',
#  '교대',
#  '구로디지털단지',
#  '구산',
#  '구의',
#  '구파발',
#  '군자',
#  '굴포천',
#  '굽은다리',
#  '금호',
#  '길동',
#  '길음',
#  '김포공항',
#  '까치산',
#  '까치울',
#  '낙성대',
#  '남구로',
#  '남부터미널',
#  '남성',
#  '남태령',
#  '남한산성입구',
#  '내방',
#  '노원',
#  '녹번',
#  '녹사평',
#  '논현',
#  '단대오거리',
#  '답십리',
#  '당고개',
#  '당산',
#  '대림',
#  '대청',
#  '대치',
#  '대흥',
#  '도곡',
#  '도림천',
#  '도봉산',
#  '독립문',
#  '독바위',
#  '돌곶이',
#  '동대문',
#  '동대문역사문화공원',
#  '동대입구',
#  '동묘앞',
#  '동작',
#  '둔촌동',
#  '디지털미디어시티',
#  '뚝섬',
#  '뚝섬유원지',
#  '마곡',
#  '마들',
#  '마장',
#  '마천',
#  '마포',
#  '마포구청',
#  '망원',
#  '매봉',
#  '먹골',
#  '면목',
#  '명동',
#  '명일',
#  '모란',
#  '목동',
#  '몽촌토성',
#  '무악재',
#  '문래',
#  '문정',
#  '미아',
#  '미아사거리',
#  '반포',
#  '발산',
#  '방배',
#  '방이',
#  '방화',
#  '버티고개',
#  '보라매',
#  '보문',
#  '복정',
#  '봉천',
#  '봉화산',
#  '부천시청',
#  '부천종합운동장',
#  '부평구청',
#  '불광',
#  '사가정',
#  '사당',
#  '산성',
#  '삼각지',
#  '삼산체육관',
#  '삼성',
#  '상계',
#  '상도',
#  '상동',
#  '상봉',
#  '상수',
#  '상왕십리',
#  '상월곡',
#  '상일동',
#  '새절',
#  '서대문',
#  '서울대입구',
#  '서울',
#  '서초',
#  '석계',
#  '석촌',
#  '선릉',
#  '성수',
#  '성신여대입구',
#  '송정',
#  '송파',
#  '수락산',
#  '수서',
#  '수유',
#  '수진',
#  '숙대입구',
#  '숭실대입구',
#  '시청',
#  '신금호',
#  '신길',
#  '신답',
#  '신당',
#  '신대방',
#  '신대방삼거리',
#  '신도림',
#  '신림',
#  '신사',
#  '신설동',
#  '신용산',
#  '신정',
#  '신정네거리',
#  '신중동',
#  '신촌',
#  '신풍',
#  '신흥',
#  '쌍문',
#  '아차산',
#  '아현',
#  '안국',
#  '안암',
#  '암사',
#  '압구정',
#  '애오개',
#  '약수',
#  '양재',
#  '양천구청',
#  '양평',
#  '어린이대공원',
#  '여의나루',
#  '여의도',
#  '역삼',
#  '역촌',
#  '연신내',
#  '영등포구청',
#  '영등포시장',
#  '오금',
#  '오목교',
#  '옥수',
#  '온수',
#  '올림픽공원',
#  '왕십리',
#  '용답',
#  '용두',
#  '용마산',
#  '우장산',
#  '월곡',
#  '월드컵경기장',
#  '을지로3가',
#  '을지로4가',
#  '을지로입구',
#  '응암',
#  '이대',
#  '총신대입구(이수)',
#  '이촌',
#  '이태원',
#  '일원',
#  '잠실',
#  '잠실나루',
#  '잠실새내',
#  '잠원',
#  '장승배기',
#  '장암',
#  '장지',
#  '장한평',
#  '제기동',
#  '종각',
#  '종로3가',
#  '종로5가',
#  '종합운동장',
#  '중계',
#  '중곡',
#  '중화',
#  '증산',
#  '지축',
#  '창동',
#  '창신',
#  '천왕',
#  '천호',
#  '철산',
#  '청구',
#  '청담',
#  '청량리',
#  '춘의',
#  '충무로',
#  '충정로',
#  '태릉입구',
#  '하계',
#  '학동',
#  '학여울',
#  '한강진',
#  '한성대입구',
#  '한양대',
#  '합정',
#  '행당',
#  '혜화',
#  '홍대입구',
#  '홍제',
#  '화곡',
#  '화랑대',
#  '회현',
#  '효창공원앞']

# %%
len(s)
# Out:
# 241

# %%
#예시로 서울역 정보 끌어오기
url="http://swopenapi.seoul.go.kr/api/subway/4f6c71586a73616c39336853514355/xml/gateInfo/0/30/서울"
result=requests.get(url)
bs_obj=BeautifulSoup(result.content,"html.parser")
print(bs_obj)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><gateinfo><result><code>INFO-000</code><developermessage></developermessage><link/><message>정상 처리되었습니다.</message><status>200</status><total>18</total></result><row><rownum>1</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>1</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>갤러리아백화점, 롯데마트, 서울역, 지상서울역, 시티투어버스정류장</cfrbuild></row><row><rownum>2</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>2</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>(구)서울역사, 국민고충처리위원회, 서소문공원, 역전우체국, 역전파출소, 철도청서울지역사무소, 한경신문사</cfrbuild></row><row><rownum>3</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>3</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>YTN방송국, 프랑스문화원, 한국산업안전공단, 호암아트홀 , 태평로우체국</cfrbuild></row><row><rownum>4</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>4</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>국제화재,대한화재, 남대문시장, 남대문시장방면, 연세빌딩, 외한은행, 청파도서관, 숭례문광장, 한국장학재단</cfrbuild></row><row><rownum>5</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>5</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>남산공원방면, 연세빌딩 , 우리은행</cfrbuild></row><row><rownum>6</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>6</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>우리은행</cfrbuild></row><row><rownum>7</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>7</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>우리은행, 남대문시장</cfrbuild></row><row><rownum>8</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>8</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>GS빌딩, 신한은행 , 힐튼호텔, 우리은행</cfrbuild></row><row><rownum>9</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>9</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>남대문경찰서, 대우빌딩, 힐튼호텔, 우리은행</cfrbuild></row><row><rownum>10</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>9-1</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>남대문경찰서, 대우빌딩, 힐튼호텔, 우리은행</cfrbuild></row><row><rownum>11</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1004000426</statnid><statnnm>서울</statnnm><ectrcno>10</ectrcno><subwayid>1004</subwayid><subwaynm>4호선</subwaynm><ectrccnt>5</ectrccnt><cfrbuild>남대문경찰서, 우리은행, 국민은행, 남산공원, 부패방지위원회, 용산도서관, 한국고속철도</cfrbuild></row><row><rownum>12</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1004000426</statnid><statnnm>서울</statnnm><ectrcno>11</ectrcno><subwayid>1004</subwayid><subwaynm>4호선</subwaynm><ectrccnt>5</ectrccnt><cfrbuild>남대문경찰서, 남산공원, 삼광초등학교, 용산도서관</cfrbuild></row><row><rownum>13</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid>1004000426</statnid><statnnm>서울</statnnm><ectrcno>12</ectrcno><subwayid>1004</subwayid><subwaynm>4호선</subwaynm><ectrccnt>5</ectrccnt><cfrbuild>남영치안센터, 남산공원, 우리은행, 후암우체국, 삼광초등학교, 후암시장</cfrbuild></row><row><rownum>14</rownum><selectedcount>18</selectedcount><totalcount>18</totalcount><statnid ...

# %%
#출구근처 주변 빌딩 정보만 끌어오기
bd=bs_obj.find_all("cfrbuild")
bd
# Out:
# [<cfrbuild>갤러리아백화점, 롯데마트, 서울역, 지상서울역, 시티투어버스정류장</cfrbuild>,
#  <cfrbuild>(구)서울역사, 국민고충처리위원회, 서소문공원, 역전우체국, 역전파출소, 철도청서울지역사무소, 한경신문사</cfrbuild>,
#  <cfrbuild>YTN방송국, 프랑스문화원, 한국산업안전공단, 호암아트홀 , 태평로우체국</cfrbuild>,
#  <cfrbuild>국제화재,대한화재, 남대문시장, 남대문시장방면, 연세빌딩, 외한은행, 청파도서관, 숭례문광장, 한국장학재단</cfrbuild>,
#  <cfrbuild>남산공원방면, 연세빌딩 , 우리은행</cfrbuild>,
#  <cfrbuild>우리은행</cfrbuild>,
#  <cfrbuild>우리은행, 남대문시장</cfrbuild>,
#  <cfrbuild>GS빌딩, 신한은행 , 힐튼호텔, 우리은행</cfrbuild>,
#  <cfrbuild>남대문경찰서, 대우빌딩, 힐튼호텔, 우리은행</cfrbuild>,
#  <cfrbuild>남대문경찰서, 대우빌딩, 힐튼호텔, 우리은행</cfrbuild>,
#  <cfrbuild>남대문경찰서, 우리은행, 국민은행, 남산공원, 부패방지위원회, 용산도서관, 한국고속철도</cfrbuild>,
#  <cfrbuild>남대문경찰서, 남산공원, 삼광초등학교, 용산도서관</cfrbuild>,
#  <cfrbuild>남영치안센터, 남산공원, 우리은행, 후암우체국, 삼광초등학교, 후암시장</cfrbuild>,
#  <cfrbuild>동자동파출소, 삼광초등학교, 후암시장, 후암우체국</cfrbuild>,
#  <cfrbuild>철도청서울지역사무소, 시티투어버스정류장, 서울역, 서울역광장</cfrbuild>,
#  <cfrbuild>우편취급소, 경기여자상업고등학교</cfrbuild>,
#  <cfrbuild>청파도서관, 중림동 주민센터</cfrbuild>,
#  <cfrbuild>청파도서관, 환일고등학교, 서울송의초등학교, 공덕동주민센터, 만리통시장, 배문고등학교</cfrbuild>]

# %%
# ,로 쪼개서 개수
bd=str(bd)
bd.split(",")
len(bd.split(","))
# Out:
# 79

# %%
list1=list()
for i in range(len(s)):
    url="http://swopenapi.seoul.go.kr/api/subway/4f6c71586a73616c39336853514355/xml/gateInfo/0/30/"+s[i]
    result=requests.get(url)
    bs_obj=BeautifulSoup(result.content,"html.parser")
    bd=bs_obj.find_all("cfrbuild")
    bd=str(bd)
    num=len(bd.split(","))
    list1.append(num)

# %%
list1
# Out:
# [7,
#  14,
#  38,
#  43,
#  42,
#  50,
#  19,
#  9,
#  15,
#  42,
#  33,
#  22,
#  67,
#  37,
#  25,
#  20,
#  24,
#  26,
#  20,
#  18,
#  39,
#  22,
#  48,
#  63,
#  41,
#  16,
#  22,
#  23,
#  11,
#  50,
#  55,
#  19,
#  61,
#  33,
#  9,
#  79,
#  6,
#  35,
#  18,
#  17,
#  8,
#  27,
#  28,
#  16,
#  62,
#  9,
#  44,
#  11,
#  74,
#  19,
#  17,
#  19,
#  10,
#  46,
#  24,
#  21,
#  28,
#  29,
#  8,
#  20,
#  33,
#  19,
#  22,
#  9,
#  52,
#  35,
#  20,
#  27,
#  17,
#  20,
#  33,
#  21,
#  37,
#  23,
#  13,
#  13,
#  26,
#  17,
#  19,
#  64,
#  41,
#  26,
#  28,
#  79,
#  53,
#  33,
#  12,
#  69,
#  9,
#  29,
#  31,
#  18,
#  8,
#  18,
#  30,
#  33,
#  16,
#  56,
#  46,
#  30,
#  34,
#  48,
#  24,
#  9,
#  60,
#  30,
#  75,
#  32,
#  34,
#  23,
#  5,
#  15,
#  2,
#  38,
#  4,
#  35,
#  21,
#  8,
#  11,
#  16,
#  1,
#  9,
#  37,
#  25,
#  31,
#  19,
#  13,
#  32,
#  15,
#  23,
#  25,
#  31,
#  20,
#  79,
#  23,
#  39,
#  18,
#  30,
#  22,
#  54,
#  19,
#  12,
#  20,
#  26,
#  10,
#  20,
#  11,
#  17,
#  36,
#  12,
#  42,
#  9,
#  20,
#  20,
#  12,
#  28,
#  6,
#  50,
#  16,
#  19,
#  13,
#  12,
#  16,
#  18,
#  34,
#  22,
#  21,
#  41,
#  25,
#  15,
#  30,
#  29,
#  49,
#  21,
#  34,
#  33,
#  13,
#  9,
#  40,
#  27,
#  15,
#  22,
#  61,
#  22,
#  31,
#  18,
#  35,
#  43,
#  32,
#  13,
#  49,
#  46,
#  20,
#  37,
#  21,
#  51,
#  27,
#  13,
#  22,
#  27,
#  29,
#  147,
#  59,
#  39,
#  15,
#  9,
#  37,
#  10,
#  30,
#  18,
#  35,
#  48,
#  43,
#  26,
#  30,
#  5,
#  31,
#  33,
#  121,
#  19,
#  20,
#  54,
#  29,
#  21,
#  29,
#  26,
#  18,
#  41,
#  20,
#  47,
#  19,
#  29,
#  25,
#  82,
#  17,
#  16,
#  19,
#  13,
#  41,
#  57,
#  14]

# %%
#잠실새내역 value 값 변경
list1[120]=62

# %%
for i in range(len(s)):
    print(s[i],list1[i])
# Out:
# 마천 7
# 공릉 14
# 종합운동장 38
# 서대문 43
# 당산 42
# 건대입구 50
# 상동 19
# 양평 9
# 수진 15
# 역삼 42
# 학동 33
# 단대오거리 22
# 삼성 67
# 명동 37
# 구의 25
# 신풍 20
# 애오개 24
# 온수 26
# 상왕십리 20
# 새절 18
# 노원 39
# 고려대 22
# 잠실 48
# 양재 63
# 숙대입구 41
# 남구로 16
# 명일 22
# 석촌 23
# 굽은다리 11
# 신당 50
# 신림 55
# 망원 19
# 성수 61
# 수유 33
# 천왕 9
# 총신대입구(이수) 79
# 까치울 6
# 신정네거리 35
# 송정 18
# 군자 17
# 까치산 8
# 아현 27
# 광명사거리 28
# 매봉 16
# 을지로입구 62
# 개화산 9
# 충정로 44
# 면목 11
# 선릉 74
# 사가정 19
# 녹사평 17
# 녹번 19
# 문정 10
# 제기동 46
# 회현 24
# 남한산성입구 21
# 광나루 28
# 철산 29
# 버티고개 8
# 강동 20
# 모란 33
# 신정 19
# 신대방 22
# 학여울 9
# 경복궁 52
# 신용산 35
# 답십리 20
# 논현 27
# 상월곡 17
# 우장산 20
# 신촌 33
# 화랑대 21
# 발산 37
# 남부터미널 23
# 응암 13
# 길동 13
# 강동구청 26
# 영등포시장 17
# 동작 19
# 안국 64
# 고속터미널 41
# 을지로4가 26
# 한성대입구 28
# 서울 79
# 가락시장 53
# 강변 33
# 행당 12
# 서울대입구 69
# 부천종합운동장 9
# 천호 29
# 오목교 31
# 올림픽공원 18
# 신답 8
# 신대방삼거리 18
# 방배 30
# 합정 33
# 석계 16
# 신도림 56
# 공덕 46
# 장승배기 30
# 불광 34
# 대림 48
# 쌍문 24
# 김포공항 9
# 낙성대 60
# 동대입구 30
# 신설동 75
# 마포구청 32
# 독립문 34
# 옥수 23
# 남태령 5
# 도봉산 15
# 마곡 2
# 미아 38
# 지축 4
# 종각 35
# 고덕 21
# 복정 8
# 한강진 11
# 구산 16
# 잠실새내 62
# 신길 9
# 동대문역사문화공원 37
# 월드컵경기장 25
# 홍제 31
# 부천시청 19
# 이태원 13
# 중계 32
# 춘의 15
# 송파 23
# 대치 25
# 삼각지 31
# 마포 20
# 사당 79
# 개롱 23
# 길음 39
# 방이 18
# 보라매 30
# 무악재 22
# 교대 54
# 내방 19
# 도림천 12
# 먹골 20
# 청담 26
# 한양대 10
# 장한평 20
# 반포 11
# 몽촌토성 17
# 양천구청 36
# 아차산 12
# 태릉입구 42
# 경찰병원 9
# 신중동 20
# 둔촌동 20
# 여의도 12
# 청량리 28
# 장암 6
# 미아사거리 50
# 봉화산 16
# 중곡 19
# 당고개 13
# 안암 12
# 굴포천 16
# 여의나루 18
# 혜화 34
# 하계 22
# 구파발 21
# 대청 41
# 잠원 25
# 신흥 15
# 성신여대입구 30
# 보문 29
# 서초 49
# 뚝섬유원지 21
# 화곡 34
# 신사 33
# 청구 13
# 숭실대입구 9
# 영등포구청 40
# 디지털미디어시티 27
# 역촌 15
# 압구정 22
# 동묘앞 61
# 가산디지털단지 22
# 약수 31
# 암사 18
# 수락산 35
# 상계 43
# 목동 32
# 용마산 13
# 문래 49
# 광화문 46
# 돌곶이 20
# 방화 37
# 이대 21
# 부평구청 51
# 도곡 27
# 창신 13
# 상도 22
# 창동 27
# 수서 29
# 시청 147
# 을지로3가 59
# 용두 39
# 신금호 15
# 남성 9
# 잠실나루 37
# 장지 10
# 일원 30
# 증산 18
# 상봉 35
# 왕십리 48
# 충무로 43
# 이촌 26
# 홍대입구 30
# 독바위 5
# 연신내 31
# 대흥 33
# 동대문 121
# 거여 19
# 금호 20
# 뚝섬 54
# 효창공원앞 29
# 중화 21
# 어린이대공원 29
# 광흥창 26
# 오금 18
# 구로디지털단지 41
# 마장 20
# 종로3가 47
# 월곡 19
# 강남구청 29
# 마들 25
# 강남 82
# 상수 17
# 삼산체육관 16
# 상일동 19
# 용답 13
# 봉천 41
# 종로5가 57
# 산성 14

# %%
for i in range(len(s)):
    print(list1[i])
# Out:
# 7
# 14
# 38
# 43
# 42
# 50
# 19
# 9
# 15
# 42
# 33
# 22
# 67
# 37
# 25
# 20
# 24
# 26
# 20
# 18
# 39
# 22
# 48
# 63
# 41
# 16
# 22
# 23
# 11
# 50
# 55
# 19
# 61
# 33
# 9
# 79
# 6
# 35
# 18
# 17
# 8
# 27
# 28
# 16
# 62
# 9
# 44
# 11
# 74
# 19
# 17
# 19
# 10
# 46
# 24
# 21
# 28
# 29
# 8
# 20
# 33
# 19
# 22
# 9
# 52
# 35
# 20
# 27
# 17
# 20
# 33
# 21
# 37
# 23
# 13
# 13
# 26
# 17
# 19
# 64
# 41
# 26
# 28
# 79
# 53
# 33
# 12
# 69
# 9
# 29
# 31
# 18
# 8
# 18
# 30
# 33
# 16
# 56
# 46
# 30
# 34
# 48
# 24
# 9
# 60
# 30
# 75
# 32
# 34
# 23
# 5
# 15
# 2
# 38
# 4
# 35
# 21
# 8
# 11
# 16
# 62
# 9
# 37
# 25
# 31
# 19
# 13
# 32
# 15
# 23
# 25
# 31
# 20
# 79
# 23
# 39
# 18
# 30
# 22
# 54
# 19
# 12
# 20
# 26
# 10
# 20
# 11
# 17
# 36
# 12
# 42
# 9
# 20
# 20
# 12
# 28
# 6
# 50
# 16
# 19
# 13
# 12
# 16
# 18
# 34
# 22
# 21
# 41
# 25
# 15
# 30
# 29
# 49
# 21
# 34
# 33
# 13
# 9
# 40
# 27
# 15
# 22
# 61
# 22
# 31
# 18
# 35
# 43
# 32
# 13
# 49
# 46
# 20
# 37
# 21
# 51
# 27
# 13
# 22
# 27
# 29
# 147
# 59
# 39
# 15
# 9
# 37
# 10
# 30
# 18
# 35
# 48
# 43
# 26
# 30
# 5
# 31
# 33
# 121
# 19
# 20
# 54
# 29
# 21
# 29
# 26
# 18
# 41
# 20
# 47
# 19
# 29
# 25
# 82
# 17
# 16
# 19
# 13
# 41
# 57
# 14
