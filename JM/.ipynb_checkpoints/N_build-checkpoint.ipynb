# %%
import pandas as pd
import numpy as np
import re
import requests
from bs4 import BeautifulSoup

# %%
from selenium import webdriver
 
path="C:\\Users\\wkdwj\\Downloads\\chromedriver_win32\\chromedriver"

# %%
'''문제!!! 실제 출구의 수와 웹에 나온 출구의 수가 맞지 않는 부분이 있습니다! 
실제 출구수*(빌딩 수/출구 수)로 가중치를 줄지 생각중입니다.. 
'''
# Out:
# '문제!!! 실제 출구의 수와 웹에 나온 출구의 수가 맞지 않는 부분이 있습니다! \n실제 출구수*(빌딩 수/출구 수)로 가중치를 줄지 생각중입니다.. \n'

# %%
#데이터 역명 불러오기
s=pd.read_csv('StationName.csv')
del s['Unnamed: 1']
s=s.dropna()

# %%
s=s['name']

# %%
s=list(s)

# %%
#한글만 추출하여 역명 전처리
'''문제!!! 역명에 숫자 있는 부분까지 처리되었습니다.. 수정하겠습니다..'''

for i in range(len(s)):
    parse = re.sub('[^가-힣]','', s[i])
    s[i]=parse

# %%
s
# Out:
# ['동대입구',
#  '송정',
#  '신길',
#  '고속터미널',
#  '잠원',
#  '마천',
#  '보문',
#  '군자',
#  '대청',
#  '상동',
#  '길동',
#  '망원',
#  '구의',
#  '장한평',
#  '잠실나루',
#  '시청',
#  '광흥창',
#  '신설동',
#  '청구',
#  '석계',
#  '신풍',
#  '가락시장',
#  '서울대입구',
#  '불광',
#  '이태원',
#  '송파',
#  '을지로가',
#  '왕십리',
#  '수유',
#  '상도',
#  '신설동',
#  '도곡',
#  '강동구청',
#  '석촌',
#  '부천종합운동장',
#  '신당',
#  '압구정',
#  '고속터미널',
#  '굴포천',
#  '중계',
#  '문정',
#  '남한산성입구',
#  '을지로가',
#  '성수',
#  '역삼',
#  '미아삼거리',
#  '월드컵경기장',
#  '먹골',
#  '공덕',
#  '신흥',
#  '시청',
#  '왕십리',
#  '동작',
#  '마곡',
#  '경찰병원',
#  '봉천',
#  '춘의',
#  '신도림',
#  '삼각지',
#  '대림',
#  '산성',
#  '안암',
#  '당고개',
#  '우장산',
#  '경복궁',
#  '광명사거리',
#  '중화',
#  '돌곶이',
#  '용두',
#  '천호',
#  '삼산체육관',
#  '부평구청',
#  '동대문역사문화공원',
#  '둔촌동',
#  '뚝섬',
#  '암사',
#  '태릉입구',
#  '대림',
#  '온수',
#  '충무로',
#  '지축',
#  '남부터미널',
#  '연신내',
#  '성신여대입구',
#  '여의나루',
#  '보라매',
#  '미아사거리',
#  '청구',
#  '불광',
#  '양평',
#  '상봉',
#  '선릉',
#  '용마산',
#  '남성',
#  '삼성',
#  '개화산',
#  '영등포시장',
#  '복정',
#  '영등포구청',
#  '행당',
#  '창신',
#  '이촌',
#  '마들',
#  '뚝섬유원지',
#  '양재',
#  '광화문',
#  '논현',
#  '방이',
#  '반포',
#  '신대방삼거리',
#  '대흥',
#  '노원',
#  '홍대입구',
#  '쌍문',
#  '왕십리성동구청',
#  '종로가',
#  '김포공항',
#  '사당',
#  '종합운동장',
#  '신대방',
#  '종로가',
#  '동대문운동장',
#  '응암',
#  '상일동',
#  '독바위',
#  '상계',
#  '동묘앞',
#  '방배',
#  '노원',
#  '동대문',
#  '거여',
#  '아현',
#  '구파발',
#  '부천시청',
#  '금호',
#  '마포구청',
#  '숭실대입구',
#  '용답',
#  '건대입구',
#  '하계',
#  '강동',
#  '낙성대',
#  '서초',
#  '수유강북구청',
#  '미아',
#  '건대입구',
#  '을지로입구',
#  '한성대입구',
#  '무악재',
#  '회현',
#  '발산',
#  '군자',
#  '고덕',
#  '새절',
#  '명동',
#  '수서',
#  '안국',
#  '혜화',
#  '모란',
#  '사가정',
#  '숙대입구',
#  '충정로',
#  '디지털미디어시티',
#  '학여울',
#  '애오개',
#  '양천구청',
#  '이수',
#  '연신내',
#  '공릉',
#  '신중동',
#  '창동',
#  '면목',
#  '몽촌토성',
#  '신용산',
#  '천호',
#  '길음',
#  '상수',
#  '상월곡',
#  '수락산',
#  '동대문',
#  '동대문역사문화공원',
#  '봉화산',
#  '버티고개',
#  '장지',
#  '아차산',
#  '학동',
#  '오금',
#  '중곡',
#  '영등포구청',
#  '신림',
#  '독립문',
#  '오목교',
#  '개롱',
#  '공덕',
#  '여의도',
#  '서울역',
#  '종로가',
#  '종각',
#  '홍제',
#  '강남구청',
#  '신금호',
#  '강변',
#  '역촌',
#  '서대문',
#  '충정로',
#  '태릉입구',
#  '합정',
#  '굽은다리',
#  '합정',
#  '효창공원앞',
#  '삼각지',
#  '신당',
#  '신천',
#  '청량리지하',
#  '구산',
#  '남태령',
#  '동대문운동장',
#  '마장',
#  '천왕',
#  '보문',
#  '녹사평',
#  '단대오거리',
#  '장승배기',
#  '교대',
#  '신정네거리',
#  '신사',
#  '대치',
#  '을지로가',
#  '올림픽공원',
#  '고려대',
#  '을지로가',
#  '수진',
#  '구로디지털단지',
#  '서울역',
#  '제기동',
#  '강남',
#  '화랑대',
#  '까치울',
#  '철산',
#  '옥수',
#  '도림천',
#  '마포',
#  '내방',
#  '종로가',
#  '한양대',
#  '사당',
#  '당산',
#  '월곡',
#  '가락시장',
#  '도봉산',
#  '남구로',
#  '어린이대공원',
#  '화곡',
#  '까치산',
#  '매봉',
#  '청담',
#  '상왕십리',
#  '가산디지털단지',
#  '방화',
#  '교대',
#  '약수',
#  '녹번',
#  '성내',
#  '신촌',
#  '잠실',
#  '동대문역사문화공원',
#  '일원',
#  '동묘앞',
#  '오금',
#  '이대',
#  '증산',
#  '광나루',
#  '잠실',
#  '신답',
#  '장암',
#  '답십리',
#  '약수',
#  '명일',
#  '목동',
#  '문래',
#  '한강진',
#  '잠실새내',
#  '신정',
#  '총신대입구']

# %%
#예시로 서울역 정보 끌어오기
url="http://swopenapi.seoul.go.kr/api/subway/444b484e466b6d723131324854716c4b/xml/gateInfo/0/5/서울"
result=requests.get(url)
bs_obj=BeautifulSoup(result.content,"html.parser")
print(bs_obj)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><gateinfo><result><code>INFO-000</code><developermessage></developermessage><link/><message>정상 처리되었습니다.</message><status>200</status><total>18</total></result><row><rownum>1</rownum><selectedcount>5</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>1</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>갤러리아백화점, 롯데마트, 서울역, 지상서울역, 시티투어버스정류장</cfrbuild></row><row><rownum>2</rownum><selectedcount>5</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>2</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>(구)서울역사, 국민고충처리위원회, 서소문공원, 역전우체국, 역전파출소, 철도청서울지역사무소, 한경신문사</cfrbuild></row><row><rownum>3</rownum><selectedcount>5</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>3</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>YTN방송국, 프랑스문화원, 한국산업안전공단, 호암아트홀 , 태평로우체국</cfrbuild></row><row><rownum>4</rownum><selectedcount>5</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>4</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>국제화재,대한화재, 남대문시장, 남대문시장방면, 연세빌딩, 외한은행, 청파도서관, 숭례문광장, 한국장학재단</cfrbuild></row><row><rownum>5</rownum><selectedcount>5</selectedcount><totalcount>18</totalcount><statnid>1001000133</statnid><statnnm>서울</statnnm><ectrcno>5</ectrcno><subwayid>1001</subwayid><subwaynm>1호선</subwaynm><ectrccnt>10</ectrccnt><cfrbuild>남산공원방면, 연세빌딩 , 우리은행</cfrbuild></row></gateinfo>

# %%
#출구근처 주변 빌딩 정보만 끌어오기
bd=bs_obj.find_all("cfrbuild")
bd
# Out:
# [<cfrbuild>갤러리아백화점, 롯데마트, 서울역, 지상서울역, 시티투어버스정류장</cfrbuild>,
#  <cfrbuild>(구)서울역사, 국민고충처리위원회, 서소문공원, 역전우체국, 역전파출소, 철도청서울지역사무소, 한경신문사</cfrbuild>,
#  <cfrbuild>YTN방송국, 프랑스문화원, 한국산업안전공단, 호암아트홀 , 태평로우체국</cfrbuild>,
#  <cfrbuild>국제화재,대한화재, 남대문시장, 남대문시장방면, 연세빌딩, 외한은행, 청파도서관, 숭례문광장, 한국장학재단</cfrbuild>,
#  <cfrbuild>남산공원방면, 연세빌딩 , 우리은행</cfrbuild>]

# %%
# ,로 쪼개서 개수
bd=str(bd)
bd.split(",")
len(bd.split(","))
# Out:
# 29

# %%
#for i in range(len(s)):
'''url 주소에 있는 역명이랑 dataset에서 끌어온 역명이랑 다른 부분은 1로 오류 나있어서 직접 찾거나 코드 수정하고 csv 파일로 만들겠습니다'''

for i in range(len(s)):
    url="http://swopenapi.seoul.go.kr/api/subway/444b484e466b6d723131324854716c4b/xml/gateInfo/0/5/"+s[i]
    result=requests.get(url)
    bs_obj=BeautifulSoup(result.content,"html.parser")
    bd=bs_obj.find_all("cfrbuild")
    bd=str(bd)
    bd.split(",")
    num=len(bd.split(","))
    print(s[i],num)
# Out:
# 동대입구 21
# 송정 18
# 신길 9
# 고속터미널 22
# 잠원 25
# 마천 7
# 보문 20
# 군자 12
# 대청 24
# 상동 13
# 길동 13
# 망원 19
# 구의 25
# 장한평 14
# 잠실나루 37
# 시청 82
# 광흥창 22
# 신설동 24
# 청구 13
# 석계 12
# 신풍 17
# 가락시장 46
# 서울대입구 46
# 불광 25
# 이태원 13
# 송파 23
# 을지로가 1
# 왕십리 18
# 수유 22
# 상도 22
# 신설동 24
# 도곡 27
# 강동구청 26
# 석촌 15
# 부천종합운동장 9
# 신당 29
# 압구정 16
# 고속터미널 22
# 굴포천 8
# 중계 23
# 문정 10
# 남한산성입구 21
# 을지로가 1
# 성수 61
# 역삼 30
# 미아삼거리 1
# 월드컵경기장 25
# 먹골 12
# 공덕 30
# 신흥 15
# 시청 82
# 왕십리 18
# 동작 12
# 마곡 2
# 경찰병원 9
# 봉천 35
# 춘의 10
# 신도림 56
# 삼각지 13
# 대림 27
# 산성 14
# 안암 12
# 당고개 13
# 우장산 20
# 경복궁 37
# 광명사거리 13
# 중화 21
# 돌곶이 13
# 용두 39
# 천호 14
# 삼산체육관 16
# 부평구청 17
# 동대문역사문화공원 15
# 둔촌동 20
# 뚝섬 31
# 암사 18
# 태릉입구 35
# 대림 27
# 온수 18
# 충무로 34
# 지축 4
# 남부터미널 20
# 연신내 24
# 성신여대입구 24
# 여의나루 18
# 보라매 20
# 미아사거리 39
# 청구 13
# 불광 25
# 양평 9
# 상봉 26
# 선릉 43
# 용마산 13
# 남성 9
# 삼성 24
# 개화산 9
# 영등포시장 17
# 복정 8
# 영등포구청 29
# 행당 12
# 창신 13
# 이촌 24
# 마들 19
# 뚝섬유원지 21
# 양재 26
# 광화문 29
# 논현 15
# 방이 18
# 반포 8
# 신대방삼거리 14
# 대흥 33
# 노원 30
# 홍대입구 19
# 쌍문 24
# 왕십리성동구청 1
# 종로가 1
# 김포공항 9
# 사당 34
# 종합운동장 21
# 신대방 22
# 종로가 1
# 동대문운동장 1
# 응암 13
# 상일동 19
# 독바위 5
# 상계 43
# 동묘앞 37
# 방배 30
# 노원 30
# 동대문 90
# 거여 12
# 아현 27
# 구파발 21
# 부천시청 19
# 금호 20
# 마포구청 22
# 숭실대입구 9
# 용답 13
# 건대입구 42
# 하계 19
# 강동 20
# 낙성대 51
# 서초 24
# 수유강북구청 1
# 미아 29
# 건대입구 42
# 을지로입구 43
# 한성대입구 18
# 무악재 22
# 회현 17
# 발산 20
# 군자 12
# 고덕 21
# 새절 18
# 명동 18
# 수서 25
# 안국 50
# 혜화 34
# 모란 14
# 사가정 19
# 숙대입구 19
# 충정로 28
# 디지털미디어시티 11
# 학여울 9
# 애오개 24
# 양천구청 36
# 이수 1
# 연신내 24
# 공릉 14
# 신중동 13
# 창동 27
# 면목 11
# 몽촌토성 17
# 신용산 32
# 천호 14
# 길음 24
# 상수 17
# 상월곡 17
# 수락산 28
# 동대문 90
# 동대문역사문화공원 15
# 봉화산 16
# 버티고개 8
# 장지 10
# 아차산 12
# 학동 21
# 오금 13
# 중곡 19
# 영등포구청 29
# 신림 35
# 독립문 34
# 오목교 20
# 개롱 23
# 공덕 30
# 여의도 10
# 서울역 1
# 종로가 1
# 종각 24
# 홍제 31
# 강남구청 29
# 신금호 15
# 강변 33
# 역촌 15
# 서대문 32
# 충정로 28
# 태릉입구 35
# 합정 16
# 굽은다리 11
# 합정 16
# 효창공원앞 29
# 삼각지 13
# 신당 29
# 신천 38
# 청량리지하 1
# 구산 16
# 남태령 5
# 동대문운동장 1
# 마장 20
# 천왕 9
# 보문 20
# 녹사평 17
# 단대오거리 17
# 장승배기 24
# 교대 24
# 신정네거리 35
# 신사 21
# 대치 15
# 을지로가 1
# 올림픽공원 18
# 고려대 20
# 을지로가 1
# 수진 15
# 구로디지털단지 34
# 서울역 1
# 제기동 39
# 강남 42
# 화랑대 15
# 까치울 6
# 철산 29
# 옥수 15
# 도림천 12
# 마포 20
# 내방 11
# 종로가 1
# 한양대 10
# 사당 34
# 당산 11
# 월곡 19
# 가락시장 46
# 도봉산 15
# 남구로 14
# 어린이대공원 25
# 화곡 23
# 까치산 8
# 매봉 16
# 청담 11
# 상왕십리 17
# 가산디지털단지 16
# 방화 37
# 교대 24
# 약수 11
# 녹번 19
# 성내 1
# 신촌 20
# 잠실 29
# 동대문역사문화공원 15
# 일원 25
# 동묘앞 37
# 오금 13
# 이대 17
# 증산 18
# 광나루 28
# 잠실 29
# 신답 8
# 장암 6
# 답십리 14
# 약수 11
# 명일 22
# 목동 22
# 문래 37
# 한강진 11
# 잠실새내 1
# 신정 19
# 총신대입구 1
