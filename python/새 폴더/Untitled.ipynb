# %%
import pandas as pd

# %%
df = pd.read_csv('1.csv')

# %%
df
# Out:
#                  날짜    역번호              역명    구분   05~06   06~07   07~08   \
# 0        2008-01-01     150       서울역(150)    승차     379     287     371
# 1        2008-01-01     150       서울역(150)    하차     145     707     689
# 2        2008-01-01     151        시청(151)    승차     131     131     101
# 3        2008-01-01     151        시청(151)    하차      35     158     203
# 4        2008-01-01     152        종각(152)    승차   1,287     867     400
# 5        2008-01-01     152        종각(152)    하차      74     147     261
# 6        2008-01-01     153      종로3가(153)    승차     484     290     192
# 7        2008-01-01     153      종로3가(153)    하차      28      80     116
# 8        2008-01-01     154      종로5가(154)    승차      89      77      86
# 9        2008-01-01     154      종로5가(154)    하차      14      76      93
# 10       2008-01-01     155       동대문(155)    승차     190     149     152
# 11       2008-01-01     155       동대문(155)    하차      23     111     120
# ...

# %%
df2 = pd.read_csv('2.csv')
df2
# Out:
#                 날짜   역번호              역명  구분   05~06   06~07   07~08   08~09  \
# 0       2013-01-01   150        서울역(150)  승차    417     484     549   1,058
# 1       2013-01-01   150        서울역(150)  하차    385   1,143   1,170   1,435
# 2       2013-01-01   151         시청(151)  승차     96     109     104     140
# 3       2013-01-01   151         시청(151)  하차     34     222     245     422
# 4       2013-01-01   152         종각(152)  승차  1,016     651     327     338
# 5       2013-01-01   152         종각(152)  하차     62     175     302     525
# 6       2013-01-01   153       종로3가(153)  승차    333     214     128     198
# 7       2013-01-01   153       종로3가(153)  하차     36      87     158     317
# 8       2013-01-01   154       종로5가(154)  승차     56      81      81     130
# 9       2013-01-01   154       종로5가(154)  하차     17      95     111     192
# 10      2013-01-01   155        동대문(155)  승차    130     104     166     219
# ...

# %%
df.append(df2)
# Out:
# D:\Anaconda3\envs\me\lib\site-packages\pandas\core\frame.py:6701: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#         05~06   06~07   07~08   08~09   09~10   10~11   11~12   12~13   \
# 0         379     287     371     876     965   1,389   1,989   2,375
# 1         145     707     689   1,037   1,170   1,376   1,451   1,743
# 2         131     131     101     152     191     202     275     361
# 3          35     158     203     393     375     460     591     841
# 4       1,287     867     400     330     345     338     595     791
# 5          74     147     261     473     597     698   1,074   1,719
# 6         484     290     192     218     281     429     566     943
# ...

# %%
df.to_csv('out.csv')

# %%
len(df)
# Out:
# 953704
