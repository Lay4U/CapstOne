# %%
import os.path
import pandas as pd
import matplotlib.pyplot as plt

folder = os.getcwd()

fileList = os.listdir(folder)

fileList
# Out:
# ['.ipynb_checkpoints',
#  'predict_csv',
#  'predict_csv.zip',
#  'Untitled.ipynb',
#  '가락시장.csv',
#  '가산디지털단지.csv',
#  '강남.csv',
#  '강남구청.csv',
#  '강동.csv',
#  '강동구청.csv',
#  '강변.csv',
#  '개롱.csv',
#  '개화산.csv',
#  '거여.csv',
#  '건대입구.csv',
#  '경복궁.csv',
#  '경찰병원.csv',
#  '고덕.csv',
#  '고려대.csv',
#  '고속터미널.csv',
#  '공덕.csv',
#  '공릉.csv',
#  '광나루.csv',
#  '광명사거리.csv',
#  '광화문.csv',
#  '광흥창.csv',
#  '교대.csv',
#  '구로디지털단지.csv',
#  '구산.csv',
#  '구의.csv',
#  '구파발.csv',
#  '군자.csv',
#  '굴포천.csv',
#  '굽은다리.csv',
#  '금호.csv',
#  '길동.csv',
#  '길음.csv',
#  '김포공항.csv',
#  '까치산.csv',
#  '까치울.csv',
#  '낙성대.csv',
#  '남구로.csv',
#  '남부터미널.csv',
#  '남성.csv',
#  '남태령.csv',
#  '남한산성입구.csv',
#  '내방.csv',
#  '노원.csv',
#  '녹번.csv',
#  '녹사평.csv',
#  '논현.csv',
#  '단대오거리.csv',
#  '답십리.csv',
#  '당고개.csv',
#  '당산.csv',
#  '대림.csv',
#  '대청.csv',
#  '대치.csv',
#  '대흥.csv',
#  '도곡.csv',
#  '도림천.csv',
#  '도봉산.csv',
#  '독립문.csv',
#  '독바위.csv',
#  '돌곶이.csv',
#  '동대문.csv',
#  '동대문역사문화공원.csv',
#  '동대입구.csv',
# ...

# %%
del fileList[0]
fileList
# Out:
# ['predict_csv.zip',
#  'Untitled.ipynb',
#  '가락시장.csv',
#  '가산디지털단지.csv',
#  '강남.csv',
#  '강남구청.csv',
#  '강동.csv',
#  '강동구청.csv',
#  '강변.csv',
#  '개롱.csv',
#  '개화산.csv',
#  '거여.csv',
#  '건대입구.csv',
#  '경복궁.csv',
#  '경찰병원.csv',
#  '고덕.csv',
#  '고려대.csv',
#  '고속터미널.csv',
#  '공덕.csv',
#  '공릉.csv',
#  '광나루.csv',
#  '광명사거리.csv',
#  '광화문.csv',
#  '광흥창.csv',
#  '교대.csv',
#  '구로디지털단지.csv',
#  '구산.csv',
#  '구의.csv',
#  '구파발.csv',
#  '군자.csv',
#  '굴포천.csv',
#  '굽은다리.csv',
#  '금호.csv',
#  '길동.csv',
#  '길음.csv',
#  '김포공항.csv',
#  '까치산.csv',
#  '까치울.csv',
#  '낙성대.csv',
#  '남구로.csv',
#  '남부터미널.csv',
#  '남성.csv',
#  '남태령.csv',
#  '남한산성입구.csv',
#  '내방.csv',
#  '노원.csv',
#  '녹번.csv',
#  '녹사평.csv',
#  '논현.csv',
#  '단대오거리.csv',
#  '답십리.csv',
#  '당고개.csv',
#  '당산.csv',
#  '대림.csv',
#  '대청.csv',
#  '대치.csv',
#  '대흥.csv',
#  '도곡.csv',
#  '도림천.csv',
#  '도봉산.csv',
#  '독립문.csv',
#  '독바위.csv',
#  '돌곶이.csv',
#  '동대문.csv',
#  '동대문역사문화공원.csv',
#  '동대입구.csv',
#  '동묘앞.csv',
#  '동작.csv',
#  '둔촌동.csv',
# ...

# %%
fileList.remove['새 폴더']
fileList
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-4af25e78e403> in <module>
# ----> 1 fileList.remove['새 폴더']
#       2 fileList
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
df = pd.read_csv('가락시장.csv')
df
# Out:
#        2.869203948974609375e+01
# 0                    -19.985193
# 1                     -1.324150
# 2                    -20.605690
# 3                     79.537971
# 4                    156.021530
# 5                   -174.026993
# 6                   -176.781921
# 7                   -139.966248
# 8                   -192.056488
# 9                   -133.468430
# 10                   -98.108673
# 11                   -21.418745
# 12                   -69.908669
# 13                  -147.496750
# 14                 -1222.143188
# 15                  -320.224457
# 16                   -48.947697
# 17                    17.004818
# 18                    -3.805309
# 19                   -12.911915
# 20                    -7.961754
# 21                    39.330826
# 22                    76.342384
# 23                   143.474014
# 24                   411.283325
# 25                   -22.195333
# 26                   -44.438183
# 27                    75.030945
# ...

# %%
# df = pd.read_csv('dataset.csv')

af = []
a = 0
for i in fileList:
    print(i, a)
    a=
    df = pd.read_csv(i, encoding='utf-8', index_col=None, header=None)
    af.append(df)
# Out:
# 가락시장.csv
# 가산디지털단지.csv
# 강남.csv
# 강남구청.csv
# 강동.csv
# 강동구청.csv
# 강변.csv
# 개롱.csv
# 개화산.csv
# 거여.csv
# 건대입구.csv
# 경복궁.csv
# 경찰병원.csv
# 고덕.csv
# 고려대.csv
# 고속터미널.csv
# 공덕.csv
# 공릉.csv
# 광나루.csv
# 광명사거리.csv
# 광화문.csv
# 광흥창.csv
# 교대.csv
# 구로디지털단지.csv
# 구산.csv
# 구의.csv
# 구파발.csv
# 군자.csv
# 굴포천.csv
# 굽은다리.csv
# 금호.csv
# 길동.csv
# 길음.csv
# 김포공항.csv
# 까치산.csv
# 까치울.csv
# 낙성대.csv
# 남구로.csv
# 남부터미널.csv
# 남성.csv
# 남태령.csv
# 남한산성입구.csv
# 내방.csv
# 노원.csv
# 녹번.csv
# 녹사평.csv
# 논현.csv
# 단대오거리.csv
# 답십리.csv
# 당고개.csv
# 당산.csv
# 대림.csv
# 대청.csv
# 대치.csv
# 대흥.csv
# 도곡.csv
# 도림천.csv
# 도봉산.csv
# 독립문.csv
# 독바위.csv
# 돌곶이.csv
# 동대문.csv
# 동대문역사문화공원.csv
# 동대입구.csv
# 동묘앞.csv
# 동작.csv
# 둔촌동.csv
# 디지털미디어시티.csv
# 뚝섬.csv
# 뚝섬유원지.csv
# 마곡.csv
# 마들.csv
# 마장.csv
# 마천.csv
# 마포.csv
# 마포구청.csv
# 망원.csv
# 매봉.csv
# 먹골.csv
# 면목.csv
# 명동.csv
# 명일.csv
# 모란.csv
# 목동.csv
# 몽촌토성.csv
# 무악재.csv
# 문래.csv
# 문정.csv
# 미아.csv
# 미아사거리.csv
# 반포.csv
# 발산.csv
# 방배.csv
# 방이.csv
# 방화.csv
# 버티고개.csv
# 보라매.csv
# 보문.csv
# 복정.csv
# 봉천.csv
# ...

# %%
import codecs
for i in fileList:
#read input file
    if i == '새 폴더' or '새 폴더 (2)':
        continue
    with codecs.open(i, 'r', encoding = 'utf8') as file:
        lines = file.read()

    #write output file
    with codecs.open(i, 'w', encoding = 'utf8') as file:
        file.write(lines)

# %%
df2 = pd.read_csv('가산디지털단지.csv')
df2
# Out:
#       -4.264186096191406250e+02
# 0                   -276.352844
# 1                     98.685791
# 2                    514.778564
# 3                   3067.691162
# 4                  12558.238281
# 5                   6368.281250
# 6                   4068.334961
# 7                   3152.305420
# 8                   1760.738770
# 9                    402.050812
# 10                  -561.157593
# 11                  -528.292542
# 12                 -1040.766724
# 13                 -4142.825195
# 14                -19643.523438
# 15                 -8355.041992
# 16                 -2229.775146
# 17                  -853.578186
# 18                  -706.038940
# 19                  -495.930542
# 20                  -129.271317
# 21                   239.701431
# 22                   635.015625
# 23                  3709.685791
# 24                 12447.498047
# 25                  6046.496582
# 26                  3727.817871
# 27                  3104.016357
# ...

# %%
df3 = pd.read_csv('강남.csv')
df3
# Out:
#       -9.331644897460937500e+02
# 0                   -332.174622
# 1                    855.497681
# 2                   1350.167358
# 3                   2037.542725
# 4                   4632.824219
# 5                   3950.276855
# 6                   4937.475586
# 7                   7817.282227
# 8                   8510.021484
# 9                   2378.723877
# 10                  -334.638062
# 11                 -1198.283691
# 12                 -3936.413818
# 13                 -7814.007812
# 14                -13313.314453
# 15                -12406.587891
# 16                 -4357.664551
# 17                 -2431.588135
# 18                 -1108.316650
# 19                  -797.973572
# 20                  -388.372498
# 21                   810.313782
# 22                  1233.939941
# 23                  2261.038574
# 24                  4704.142578
# 25                  3343.999268
# 26                  5087.206543
# 27                  8120.929688
# ...

# %%
va = df.values.astype('int')

# %%
plt.plot(va[:1000])

# %%
va2 = df2.values.astype('int')

# %%
plt.plot(va2[:1000])

# %%
va3 = df3.values.astype('int')

# %%
plt.plot(va3[:1000])
