# %%
import os.path
import pandas as pd
import matplotlib.pyplot as plt

folder = os.getcwd()

fileList = os.listdir(folder)

# %%
del fileList[0]
fileList
# Out:
# ['가락시장.csv', '가산디지털단지.csv']

# %%
# Out:
# ['Untitled.ipynb', '가산디지털단지.csv']

# %%
for i in fileList:
    df = pd.read_csv(i)

# %%
df
# Out:
#       -4.264186096191406250e+02
# 0                   -276.352844
# 1                     98.685791
# 2                    514.778564
# 3                   3067.691162
# 4                  12558.238281
# 5                   6368.281250
# 6                   4068.334961
# 7                   3152.305420
# 8                   1760.738770
# 9                    402.050812
# 10                  -561.157593
# 11                  -528.292542
# 12                 -1040.766724
# 13                 -4142.825195
# 14                -19643.523438
# 15                 -8355.041992
# 16                 -2229.775146
# 17                  -853.578186
# 18                  -706.038940
# 19                  -495.930542
# 20                  -129.271317
# 21                   239.701431
# 22                   635.015625
# 23                  3709.685791
# 24                 12447.498047
# 25                  6046.496582
# 26                  3727.817871
# 27                  3104.016357
# ...
