# 19220351  2017-09-30  2827.0     모란(8)  승차    21.0
# 19220352  2017-09-30  2827.0     모란(8)  승차   106.0
# 19220353  2017-09-30  2827.0     모란(8)  승차   -45.0
# 19220354  2017-09-30  2827.0     모란(8)  승차     7.0
# 19220355  2017-09-30  2827.0     모란(8)  승차   -36.0
# 19220356  2017-09-30  2827.0     모란(8)  승차   -37.0
# 19220357  2017-09-30  2827.0     모란(8)  승차   -38.0
# 19220358  2017-09-30  2827.0     모란(8)  승차   -57.0
# 19220359  2017-09-30  2827.0     모란(8)  승차   -19.0
#
# [19220360 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['date', 'number', 'name', 'div', 'a'], dtype='object')

# %%
df['name']
# Out:
# 0           서울역(150)
# 1           서울역(150)
# 2           서울역(150)
# 3           서울역(150)
# 4           서울역(150)
# 5           서울역(150)
# 6           서울역(150)
# 7           서울역(150)
# 8           서울역(150)
# 9           서울역(150)
# 10          서울역(150)
# 11          서울역(150)
# 12          서울역(150)
# 13          서울역(150)
# 14          서울역(150)
# 15          서울역(150)
# 16          서울역(150)
# 17          서울역(150)
# 18          서울역(150)
# 19          서울역(150)
# 20           시청(151)
# 21           시청(151)
# 22           시청(151)
# 23           시청(151)
# 24           시청(151)
# 25           시청(151)
# 26           시청(151)
# 27           시청(151)
# 28           시청(151)
# 29           시청(151)
#               ...
# 19220330          수진
# 19220331          수진
# 19220332          수진
# 19220333          수진
# 19220334          수진
# 19220335          수진
# 19220336          수진
# 19220337          수진
# 19220338          수진
# 19220339          수진
# 19220340       모란(8)
# 19220341       모란(8)
# 19220342       모란(8)
# 19220343       모란(8)
# 19220344       모란(8)
# 19220345       모란(8)
# 19220346       모란(8)
# 19220347       모란(8)
# 19220348       모란(8)
# 19220349       모란(8)
# 19220350       모란(8)
# 19220351       모란(8)
# 19220352       모란(8)
# 19220353       모란(8)
# 19220354       모란(8)
# 19220355       모란(8)
# 19220356       모란(8)
# 19220357       모란(8)
# 19220358       모란(8)
# 19220359       모란(8)
# Name: name, Length: 19220360, dtype: object

# %%
s = df['name']
s
# Out:
# 0           서울역(150)
# 1           서울역(150)
# 2           서울역(150)
# 3           서울역(150)
# 4           서울역(150)
# 5           서울역(150)
# 6           서울역(150)
# 7           서울역(150)
# 8           서울역(150)
# 9           서울역(150)
# 10          서울역(150)
# 11          서울역(150)
# 12          서울역(150)
# 13          서울역(150)
# 14          서울역(150)
# 15          서울역(150)
# 16          서울역(150)
# 17          서울역(150)
# 18          서울역(150)
# 19          서울역(150)
# 20           시청(151)
# 21           시청(151)
# 22           시청(151)
# 23           시청(151)
# 24           시청(151)
# 25           시청(151)
# 26           시청(151)
# 27           시청(151)
# 28           시청(151)
# 29           시청(151)
#               ...
# 19220330          수진
# 19220331          수진
# 19220332          수진
# 19220333          수진
# 19220334          수진
# 19220335          수진
# 19220336          수진
# 19220337          수진
# 19220338          수진
# 19220339          수진
# 19220340       모란(8)
# 19220341       모란(8)
# 19220342       모란(8)
# 19220343       모란(8)
# 19220344       모란(8)
# 19220345       모란(8)
# 19220346       모란(8)
# 19220347       모란(8)
# 19220348       모란(8)
# 19220349       모란(8)
# 19220350       모란(8)
# 19220351       모란(8)
# 19220352       모란(8)
# 19220353       모란(8)
# 19220354       모란(8)
# 19220355       모란(8)
# 19220356       모란(8)
# 19220357       모란(8)
# 19220358       모란(8)
# 19220359       모란(8)
# Name: name, Length: 19220360, dtype: object

# %%
s = list(set(s))
s
# Out:
# ['신설동(156)',
#  '영등포구청(236)',
#  '동대입구(322)',
#  '미아삼거리(416)',
#  '충정로(243)',
#  '양평(5)',
#  '상왕십리(207)',
#  '까치산(5)',
#  '성수(211)',
#  '대림(7)',
#  '옥수(325)',
#  '신흥',
#  '거여',
#  '남태령(434)',
#  '새절',
#  '가락시장(8)',
#  '용답(244)',
#  '석촌',
#  '복정(8)',
#  '광명사거리',
#  '수진',
#  '부평구청(7)',
#  '답십리',
#  '창동(412)',
#  '이대(241)',
#  '미아(415)',
#  '방배(225)',
#  '녹번(313)',
#  '상도',
#  '몽촌토성',
#  '잠실나루(215)',
#  '이수(7)',
#  '합정(6)',
#  '보라매',
#  '종로3가(153)',
#  '강남(222)',
#  '마포구청',
#  '방화',
#  '디지털미디어시티(6)',
#  '도곡(334)',
#  '신촌(240)',
#  '월드컵경기장',
#  '구로디지털단지(232)',
#  '녹사평',
#  '마장',
#  '청구(5)',
#  '망원',
#  '신중동',
#  '신답(245)',
#  '동대문운동장(422)',
#  '고려대',
#  '개롱',
#  '동대문역사문화공원(422)',
#  '남구로',
#  '양천구청(248)',
#  '중곡',
#  '종로3가(5)',
#  '강남구청',
#  '동묘앞(159)',
#  '철산',
#  '당고개(409)',
#  '가락시장(340)',
#  '남성',
#  '상월곡',
#  '마곡',
#  '광흥창',
#  '대치(335)',
#  '양재(332)',
#  '화랑대',
#  '을지로3가(320)',
#  '용마산',
#  '고속터미널(329)',
#  '강동',
#  '종각(152)',
#  '독바위',
#  '아현(242)',
#  '돌곶이',
#  '청량리(지하)(158)',
#  '독립문(316)',
#  '삼각지(428)',
#  '경복궁(317)',
#  '을지로입구(202)',
#  '명동(424)',
#  '천호(8)',
#  '낙성대(227)',
#  '공릉',
#  '신림(230)',
#  '건대입구(7)',
#  '석계(6)',
#  '혜화(420)',
#  '버티고개',
#  '영등포구청(5)',
#  '단대오거리',
#  '왕십리(성동구청)(208)',
#  '학동',
#  '지축(309)',
#  '이태원',
#  '효창공원앞',
#  '숙대입구(427)',
#  '신용산(429)',
#  '마천',
#  '안암',
#  '올림픽공원',
#  '역삼(221)',
#  '총신대입구(432)',
#  '먹골',
#  '신사(327)',
#  '장승배기',
#  '쌍문(413)',
#  '당산(237)',
#  '애오개',
#  '태릉입구(7)',
#  '잠실(8)',
#  '남부터미널(331)',
#  '신정네거리(249)',
#  '뚝섬(210)',
#  '잠실새내(217)',
#  '선릉(220)',
#  '마들',
#  '개화산',
#  '잠실(216)',
#  '중계',
#  '산성',
#  '청담',
#  '연신내(311)',
#  '공덕(6)',
#  '신길(5)',
#  '여의도(5)',
#  '약수(323)',
#  '장암',
#  '상계(410)',
#  '영등포시장',
#  '도봉산(7)',
#  '강동구청',
#  '미아사거리(416)',
#  '경찰병원(341)',
#  '굽은다리',
#  '오목교',
#  '중화',
#  '사당(433)',
#  '보문',
#  '가산디지털단지(7)',
#  '을지로4가(204)',
#  '송파',
#  '서울역(426)',
#  '노원(7)',
#  '수서(339)',
#  '봉화산',
#  '여의나루',
#  '신당(206)',
#  '오금',
#  '암사',
#  '서대문',
#  '신금호',
#  '고속터미널(7)',
#  '한성대입구(419)',
#  '대청(337)',
#  '압구정(326)',
#  '종로5가(154)',
#  '동묘앞(6)',
#  '신천(217)',
#  '마포',
#  '삼산체육관',
#  '목동',
#  '공덕(5)',
#  '봉천(229)',
#  '길음(417)',
#  '우장산',
#  '제기동(157)',
#  '금호(324)',
#  '동대문운동장(205)',
#  '천호(5)',
#  '교대(223)',
#  '행당',
#  '수유(414)',
#  '둔촌동',
#  '성내(215)',
#  '장지',
#  '상일동',
#  '월곡',
#  '면목',
#  '신대방삼거리',
#  '반포',
#  '동대문(155)',
#  '신정',
#  '남한산성입구',
#  '종합운동장(218)',
#  '회현(425)',
#  '연신내(6)',
#  '불광(312)',
#  '시청(201)',
#  '수유(강북구청)(414)',
#  '방이',
#  '역촌',
#  '어린이대공원',
#  '신도림(234)',
#  '온수(7)',
#  '부천종합운동장',
#  '서울대입구(228)',
#  '건대입구(212)',
#  '동작(431)',
#  '사당(226)',
#  '동대문역사문화공원5',
#  '뚝섬유원지',
#  '굴포천',
#  '서울역(150)',
#  '학여울(336)',
#  '부천시청',
#  '한강진',
#  '일원(338)',
#  '태릉입구(6)',
#  '노원(411)',
#  '길동',
#  '김포공항(5)',
#  '홍대입구(239)',
#  '신대방(231)',
#  '대림(233)',
#  '교대(330)',
#  '성신여대입구(418)',
#  '이촌(430)',
#  '논현',
#  '시청(151)',
#  '서초(224)',
#  '문래(235)',
#  '송정',
#  '명일',
#  '상동',
#  '을지로3가(203)',
#  '약수(6)',
#  '충무로(423)',
#  '발산',
#  '아차산',
#  '까치울',
#  '보문(6)',
#  '화곡',
#  '상봉(7)',
#  '왕십리(5)',
#  '신풍',
#  '용두(250)',
#  '증산',
#  '광나루',
#  '천왕',
#  '구파발(310)',
#  '군자(7)',
#  '강변(214)',
#  '구산',
#  '오금(342)',
#  '한양대(209)',
#  '불광(6)',
#  '동대문역사문화공원(205)',
#  '춘의',
#  '숭실대입구',
#  '잠원(328)',
#  '삼성(219)',
#  '안국(318)',
#  '충정로(5)',
#  '삼각지(6)',
#  '도림천(247)',
#  '신설동(246)',
#  '광화문',
#  '수락산',
#  '구의(213)',
#  '장한평',
#  '대흥',
#  '청구(6)',
#  '종로3가(319)',
#  '매봉(333)',
#  '홍제(314)',
#  '사가정',
#  '합정(238)',
#  '신당(6)',
#  '하계',
#  '응암',
#  '창신',
#  '동대문(421)',
#  '문정',
#  '군자(5)',
#  '고덕',
#  '내방',
#  '상수',
#  '무악재(315)',
#  '왕십리(208)',
#  '을지로4가(5)',
#  '모란(8)']

# %%
len(s)
# Out:
# 284

# %%
def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data) - look_back):
        dataX.append(signal_data[i:(i + look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

look_back = 7

# %%
s[1]
# Out:
# '영등포구청(236)'

# %%
# for i in range(len(s)):
#     print(s[i] ,':', len(df[df['name']==s[i]]))

# %%
20226480 - 19220360 # 71220 * 284 - rows
# Out:
# 1006120

# %%
data1 = df[df['name']=='강남(222)']
data1
# Out:
#                 date  number     name div        a
# 620       2008-01-01   222.0  강남(222)  승차    945.0
# 621       2008-01-01   222.0  강남(222)  승차    314.0
# 622       2008-01-01   222.0  강남(222)  승차    -64.0
# 623       2008-01-01   222.0  강남(222)  승차   -205.0
# 624       2008-01-01   222.0  강남(222)  승차   -806.0
# 625       2008-01-01   222.0  강남(222)  승차   -405.0
# 626       2008-01-01   222.0  강남(222)  승차   -336.0
# 627       2008-01-01   222.0  강남(222)  승차   -474.0
# 628       2008-01-01   222.0  강남(222)  승차   -628.0
# 629       2008-01-01   222.0  강남(222)  승차   -584.0
# 630       2008-01-01   222.0  강남(222)  승차   -661.0
# 631       2008-01-01   222.0  강남(222)  승차   -751.0
# 632       2008-01-01   222.0  강남(222)  승차   -839.0
# 633       2008-01-01   222.0  강남(222)  승차   -723.0
# 634       2008-01-01   222.0  강남(222)  승차   -198.0
# 635       2008-01-01   222.0  강남(222)  승차    800.0
# 636       2008-01-01   222.0  강남(222)  승차   1650.0
# 637       2008-01-01   222.0  강남(222)  승차   1725.0
# 638       2008-01-01   222.0  강남(222)  승차    507.0
# 639       2008-01-01   222.0  강남(222)  승차    -58.0
# 5860      2008-01-02   222.0  강남(222)  승차   -126.0
# 5861      2008-01-02   222.0  강남(222)  승차  -2936.0
# 5862      2008-01-02   222.0  강남(222)  승차  -6503.0
# 5863      2008-01-02   222.0  강남(222)  승차 -16890.0
# 5864      2008-01-02   222.0  강남(222)  승차 -10895.0
# 5865      2008-01-02   222.0  강남(222)  승차  -3198.0
# 5866      2008-01-02   222.0  강남(222)  승차  -1487.0
# 5867      2008-01-02   222.0  강남(222)  승차     79.0
# 5868      2008-01-02   222.0  강남(222)  승차   -858.0
# 5869      2008-01-02   222.0  강남(222)  승차    364.0
# ...              ...     ...      ...  ..      ...
# 19209990  2017-09-29   222.0  강남(222)  승차   1807.0
# 19209991  2017-09-29   222.0  강남(222)  승차   2009.0
# 19209992  2017-09-29   222.0  강남(222)  승차   3212.0
# 19209993  2017-09-29   222.0  강남(222)  승차   3768.0
# 19209994  2017-09-29   222.0  강남(222)  승차    347.0
# 19209995  2017-09-29   222.0  강남(222)  승차   3698.0
# 19209996  2017-09-29   222.0  강남(222)  승차   6670.0
# 19209997  2017-09-29   222.0  강남(222)  승차   7869.0
# 19209998  2017-09-29   222.0  강남(222)  승차   4514.0
# 19209999  2017-09-29   222.0  강남(222)  승차   1020.0
# 19215480  2017-09-30   222.0  강남(222)  승차    505.0
# 19215481  2017-09-30   222.0  강남(222)  승차   -266.0
# 19215482  2017-09-30   222.0  강남(222)  승차  -1094.0
# 19215483  2017-09-30   222.0  강남(222)  승차  -3007.0
# 19215484  2017-09-30   222.0  강남(222)  승차  -5567.0
# 19215485  2017-09-30   222.0  강남(222)  승차  -3318.0
# 19215486  2017-09-30   222.0  강남(222)  승차  -2564.0
# 19215487  2017-09-30   222.0  강남(222)  승차  -2017.0
# 19215488  2017-09-30   222.0  강남(222)  승차  -2499.0
# 19215489  2017-09-30   222.0  강남(222)  승차  -1175.0
# 19215490  2017-09-30   222.0  강남(222)  승차    644.0
# 19215491  2017-09-30   222.0  강남(222)  승차   1618.0
# 19215492  2017-09-30   222.0  강남(222)  승차   1984.0
# 19215493  2017-09-30   222.0  강남(222)  승차   1074.0
# 19215494  2017-09-30   222.0  강남(222)  승차    934.0
# 19215495  2017-09-30   222.0  강남(222)  승차   1327.0
# 19215496  2017-09-30   222.0  강남(222)  승차   2817.0
# 19215497  2017-09-30   222.0  강남(222)  승차   4176.0
# 19215498  2017-09-30   222.0  강남(222)  승차   1975.0
# 19215499  2017-09-30   222.0  강남(222)  승차   -159.0
#
# [71220 rows x 5 columns]

# %%
name = data1.iloc[:1,2,]
name
# Out:
# 620    강남(222)
# Name: name, dtype: object

# %%
name = name.to_string(index=False)

# %%
name
# Out:
# ' 강남(222)'

# %%
plt.savefig(name)

# %%
len(data1)
# Out:
# 71220

# %%
data1.shape
# Out:
# (71220, 5)

# %%
data1 = df[df['name']=='강남(222)']
print(data1)
data = data1['a']
#     data = data.value
data = data.values.astype('float32')
data = data.reshape(len(data), 1)

scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

train_size = int(len(data) * 0.80)
test_size = len(data) - train_size

train = data[0:train_size]
test = data[train_size:len(data)]
x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
# 모델 구성하기

model = Sequential()
model.add(LSTM(512, input_shape=(None, 1), return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(512, input_shape=(None, 1)))
model.add(Dropout(0.3))
# model.add(LSTM(i, input_shape=(None, 1)))

# model.add(Dense(i))
# model.add(Dropout(0.3))
# model.add(Dropout(0.3))
# model.add(Dense(64))

model.add(Dense(1))
name = "tt.jpg"
# 모델 학습과정 설정하기
model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['accuracy'])
model.summary()
hist = model.fit(x_train, y_train, epochs=10, batch_size=64)
p = model.predict(x_test)

plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))
# plt.savefig(datetime.datetime.now())
plt.savefig(name)
plt.clf()
print(mean_squared_error(y_test, p))
# Out:
#                 date  number     name div        a
# 620       2008-01-01   222.0  강남(222)  승차    945.0
# 621       2008-01-01   222.0  강남(222)  승차    314.0
# 622       2008-01-01   222.0  강남(222)  승차    -64.0
# 623       2008-01-01   222.0  강남(222)  승차   -205.0
# 624       2008-01-01   222.0  강남(222)  승차   -806.0
# 625       2008-01-01   222.0  강남(222)  승차   -405.0
# 626       2008-01-01   222.0  강남(222)  승차   -336.0
# 627       2008-01-01   222.0  강남(222)  승차   -474.0
# 628       2008-01-01   222.0  강남(222)  승차   -628.0
# 629       2008-01-01   222.0  강남(222)  승차   -584.0
# 630       2008-01-01   222.0  강남(222)  승차   -661.0
# 631       2008-01-01   222.0  강남(222)  승차   -751.0
# 632       2008-01-01   222.0  강남(222)  승차   -839.0
# 633       2008-01-01   222.0  강남(222)  승차   -723.0
# 634       2008-01-01   222.0  강남(222)  승차   -198.0
# 635       2008-01-01   222.0  강남(222)  승차    800.0
# 636       2008-01-01   222.0  강남(222)  승차   1650.0
# 637       2008-01-01   222.0  강남(222)  승차   1725.0
# 638       2008-01-01   222.0  강남(222)  승차    507.0
# 639       2008-01-01   222.0  강남(222)  승차    -58.0
# 5860      2008-01-02   222.0  강남(222)  승차   -126.0
# Epoch 6/10
# 56969/56969 [==============================] - 23s 410us/step - loss: 0.0017 - acc: 3.5107e-05
# Epoch 7/10
# 56969/56969 [==============================] - 29s 512us/step - loss: 0.0014 - acc: 3.5107e-05
# Epoch 8/10
# 56969/56969 [==============================] - 26s 463us/step - loss: 0.0013 - acc: 3.5107e-05
# Epoch 9/10
# 56969/56969 [==============================] - 24s 415us/step - loss: 0.0011 - acc: 3.5107e-05
# Epoch 10/10
# 56969/56969 [==============================] - 22s 385us/step - loss: 0.0010 - acc: 3.5107e-05
# 0.0011476594

# %%
# # Plot training & validation loss values
# plt.plot(hist.history['loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()

# %%
plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'prediction'], loc='best')
plt.title('LSTM(512)+LSTM(1024)')
plt.ylabel('embarked personnel')
plt.xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %%
trainPredict = model.predict(x_train)
testPredict = model.predict(x_test)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([y_test])

# shift train predictions for plotting
trainPredictPlot = np.empty_like(data)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(data)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(data)+2, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(data))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.legend(['data', 'train','predict'], loc='best')
plt.show()

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (45575, 1)
# (11394, 1)

# %%
yhat = y_test
yhat = yhat.reshape(len(yhat), 1, 1)

# %%
y = model.predict(yhat)
y
# Out:
# array([[10.248852  ],
#        [-0.19188583],
#        [10.26259   ],
#        ...,
#        [10.257338  ],
#        [10.288124  ],
#        [-0.20998567]], dtype=float32)

# %%
data = y

data = data.reshape(len(data), 1)

scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

train_size = int(len(data) * 0.80)
test_size = len(data) - train_size

train = data[0:train_size]
test = data[train_size:len(data)]
x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

from xgboost import XGBRegressor
XGBModel = XGBRegressor()
XGBModel.fit(x_train,y_train, verbose=False)

p = XGBModel.predict(x_test)
plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))

plt.show()
print(mean_squared_error(y_test, p))
# Out:
# 0.21007577

# %%
plt.plot(y_test)
plt.xlim(0, 100)
# Out:
# (0, 100)

# %%
plt.plot(p)
plt.xlim(0, 100)
# Out:
# (0, 100)

# %%
print(y_test[:100])
# Out:
# [0.08142704 0.99258244 0.99339616 0.08382815 0.08122522 0.9925421
#  0.9925622  0.08295364 0.9933533  0.08250913 0.08140688 0.99250704
#  0.9936539  0.08131242 0.08376262 0.99257994 0.08388099 0.9920389
#  0.08400729 0.9931411  0.08400633 0.9937506  0.992551   0.08124489
#  0.08382773 0.08266457 0.993501   0.08261187 0.99249154 0.08399828
#  0.9920971  0.08332628 0.9957417  0.08286321 0.99538547 0.08256763
#  0.08384442 0.9934392  0.9937275  0.99259377 0.08379993 0.08400723
#  0.08203877 0.08378012 0.08364276 0.99381703 0.08400729 0.9966405
#  0.08188839 0.99649477 0.08375807 0.08156737 0.9922463  0.08209939
#  0.99260706 0.08399623 0.9936368  0.99338883 0.08330417 0.08182627
#  0.99260104 0.08392937 0.99279064 0.992637   0.08399545 0.08400264
#  0.9927466  0.9924632  0.08154283 0.9926512  0.08397879 0.9923091
#  0.08400729 0.08400723 0.9940163  0.99233305 0.08400729 0.99256486
#  0.9949644  0.08398898 0.08120722 0.08281489 0.08400729 0.99257964
#  0.08400729 0.08391608 0.9933103  0.99661726 0.08141424 0.08400422
#  0.08400723 0.08399262 0.08377349 0.08326544 0.08462493 0.08398444
#  0.08274029 0.08378074 0.99375606 0.0839938 ]

# %%
print(p[:100])
# Out:
# [0.5387277  0.52194333 0.49425855 0.528529   0.49354044 0.46850538
#  0.43941227 0.53110987 0.44656137 0.48021665 0.5317294  0.45752484
#  0.47062594 0.5039194  0.5024517  0.5518639  0.55455285 0.5162487
#  0.49570763 0.4898587  0.4554514  0.48575938 0.49884227 0.50914425
#  0.50752944 0.5685781  0.5150227  0.49624586 0.4951996  0.56941867
#  0.48336464 0.51834637 0.4889319  0.46060047 0.48762754 0.5210226
#  0.50627774 0.47498956 0.4481102  0.5850711  0.5011152  0.518041
#  0.48039478 0.4664247  0.44241646 0.46182272 0.5118392  0.49996692
#  0.5728696  0.50422245 0.45442697 0.5124543  0.5198721  0.45483825
#  0.53247094 0.49220327 0.54234624 0.513553   0.5286475  0.53114974
#  0.4818048  0.48309836 0.4742962  0.5147954  0.533677   0.5058147
#  0.48044002 0.49888843 0.49350584 0.4755906  0.47724062 0.52355623
#  0.50985193 0.48159727 0.5083441  0.5007003  0.51346654 0.49171132
#  0.502498   0.6034244  0.4823899  0.4964261  0.6070699  0.6370155
#  0.45142648 0.50952625 0.5437504  0.5356313  0.48418006 0.4864707
#  0.49959368 0.51476264 0.5153092  0.4900507  0.43940532 0.56600225
#  0.49168384 0.49512732 0.4792598  0.5088423 ]

# %%
plt.scatter(len(y_test), y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-0836debafdf8> in <module>
# ----> 1 plt.scatter(len(y_test), y_test)
#
# D:\Anaconda3\envs\me\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2860         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2861         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2862         is not None else {}), **kwargs)
#    2863     sci(__ret)
#    2864     return __ret
#
# D:\Anaconda3\envs\me\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# D:\Anaconda3\envs\me\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4180         y = np.ma.ravel(y)
#    4181         if x.size != y.size:
# -> 4182             raise ValueError("x and y must be the same size")
#    4183
#    4184         if s is None:
#
# ValueError: x and y must be the same size

# %%
data = y
#     data = data.value
data = data.values.astype('float32')
data = data.reshape(len(data), 1)

scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

train_size = int(len(data) * 0.80)
test_size = len(data) - train_size

train = data[0:train_size]
test = data[train_size:len(data)]
# x_train, y_train = create_dataset(train, look_back)
# x_test, y_test = create_dataset(test, look_back)

# x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
# x = range(0,len(y))
x = np.arange(0, len(y))
x=x.reshape(len(x),1)

# %%
print(len(x))
print(len(y))
print(x.shape)
print(y.shape)
print(type(y))
print(type(x))
# Out:
# 56969
# 56969
# (56969, 1)
# (56969, 1)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
x=x.reshape(len(x),1)
x.shape
# Out:
# (56969, 1)

# %%
data = y

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

XGBModel = XGBRegressor()
XGBModel.fit(x_train,y_train, verbose=False)

p = XGBModel.predict(x_test)
plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))

plt.show()
print(mean_squared_error(y_test, p))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-abcbbc0f179b> in <module>
#       4 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
#       5
# ----> 6 XGBModel = XGBRegressor()
#       7 XGBModel.fit(x_train,y_train, verbose=False)
#       8
#
# NameError: name 'XGBRegressor' is not defined

# %%
plt.plot(x_train)
plt.plot(y_train)
plt.show()

# %%
plt.plot(x_train)

# %%
plt.plot(y_train)

# %%
plt.plot(p)

# %%
from xgboost import XGBRegressor
# import xgboost as xgb
# from xgboost.sklearn import XGBRegressor
XGBModel = XGBRegressor()
XGBModel.fit(x,y, verbose=False)

# Get the mean absolute error on the validation data :
# XGBpredictions = XGBModel.predict(val_X)
# MAE = mean_absolute_error(val_y , XGBpredictions)
# print('XGBoost validation MAE = ',MAE)

# %%
from xgboost import plot_tree
plot_tree(XGBModel)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x,y)

# Get the mean absolute error on the validation data
predicted_prices = model.predict(val_X)
MAE = mean_absolute_error(val_y , predicted_prices)
print('Random forest validation MAE = ', MAE)

# %%
# 저장
model_json = model.to_json()
with open("s[0].json", "w") as json_file :
    json_file.write(model_json)
model.save_weights("s[0].h5")
print("Saved model to disk")

# %%
# # 모델 불러오기
# from keras.models import model_from_json
# json_file = open("model1.json", "r")
# model_json = json_file.read()
# json_file.close()
# model = model_from_json(loaded_model_json)
# model.load_weights("model1.h5")
# model.compile(loss="mean_squared_error", optimizer="rmsprop", metrics=['accuracy'])

# %%
from keras.utils import plot_model
plot_model(loaded_model, to_file='model.png')
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(loaded_model).create(prog='dot', format='svg'))
plot_model(loaded_model, to_file='model_plot.png')

# %%
SVG(model_to_dot(loaded_model).create(prog='dot', format='svg'))

# %%
plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))
# plt.savefig(datetime.datetime.now())
plt.show()
print(mean_squared_error(y_test, p))

# %%
p = model.predict(x_test)

plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))
# plt.savefig(datetime.datetime.now())
plt.savefig(name)
plt.show()
print(mean_squared_error(y_test, p))

# %%
data = y # p
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
x = np.arange(0, len(y))
x=x.reshape(len(x),1)
x = scaler.fit_transform(x)

train_size = int(len(data) * 0.80)
test_size = len(data) - train_size

y_train = data[0:train_size]
y_test = data[train_size:len(data)]
x_train = x[0:train_size]
x_test = x[train_size:len(x)]
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.8, random_state=42)

XGBModel = XGBRegressor()
XGBModel.fit(x_train,y_train, verbose=False)

p = XGBModel.predict(x_test)
plt.plot(y_test)
plt.plot(p)
plt.legend(['y_test', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))

plt.show()
print(mean_squared_error(y_test, p))

# %%
plt.plot(p)

# %%
plt.plot(y_test)
