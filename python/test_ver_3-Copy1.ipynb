# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.layers.core import Dense, Activation, Dropout
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

import winsound

# %%
df = pd.read_csv('dataset.csv')
del df['Unnamed: 0']

# %%
df
# Out:
#                 date  number      name div       a
# 0         2008-01-01   150.0  서울역(150)  승차   234.0
# 1         2008-01-01   150.0  서울역(150)  승차  -420.0
# 2         2008-01-01   150.0  서울역(150)  승차  -318.0
# 3         2008-01-01   150.0  서울역(150)  승차  -161.0
# 4         2008-01-01   150.0  서울역(150)  승차  -205.0
# 5         2008-01-01   150.0  서울역(150)  승차    13.0
# 6         2008-01-01   150.0  서울역(150)  승차   538.0
# 7         2008-01-01   150.0  서울역(150)  승차   632.0
# 8         2008-01-01   150.0  서울역(150)  승차   604.0
# 9         2008-01-01   150.0  서울역(150)  승차   808.0
# 10        2008-01-01   150.0  서울역(150)  승차   565.0
# 11        2008-01-01   150.0  서울역(150)  승차   774.0
# 12        2008-01-01   150.0  서울역(150)  승차  1292.0
# 13        2008-01-01   150.0  서울역(150)  승차   927.0
# 14        2008-01-01   150.0  서울역(150)  승차  1205.0
# 15        2008-01-01   150.0  서울역(150)  승차  1133.0
# 16        2008-01-01   150.0  서울역(150)  승차  2229.0
# 17        2008-01-01   150.0  서울역(150)  승차  1840.0
# 18        2008-01-01   150.0  서울역(150)  승차   653.0
# 19        2008-01-01   150.0  서울역(150)  승차  -294.0
# 20        2008-01-01   151.0   시청(151)  승차    96.0
# 21        2008-01-01   151.0   시청(151)  승차   -27.0
# 22        2008-01-01   151.0   시청(151)  승차  -102.0
# 23        2008-01-01   151.0   시청(151)  승차  -241.0
# 24        2008-01-01   151.0   시청(151)  승차  -184.0
# 25        2008-01-01   151.0   시청(151)  승차  -258.0
# 26        2008-01-01   151.0   시청(151)  승차  -316.0
# 27        2008-01-01   151.0   시청(151)  승차  -480.0
# 28        2008-01-01   151.0   시청(151)  승차  -645.0
# 29        2008-01-01   151.0   시청(151)  승차  -470.0
# ...              ...     ...       ...  ..     ...
# 19220330  2017-09-30  2826.0        수진  승차    34.0
# 19220331  2017-09-30  2826.0        수진  승차    78.0
# 19220332  2017-09-30  2826.0        수진  승차    60.0
# 19220333  2017-09-30  2826.0        수진  승차   -25.0
# 19220334  2017-09-30  2826.0        수진  승차  -104.0
# 19220335  2017-09-30  2826.0        수진  승차   -57.0
# 19220336  2017-09-30  2826.0        수진  승차  -175.0
# 19220337  2017-09-30  2826.0        수진  승차  -139.0
# 19220338  2017-09-30  2826.0        수진  승차  -146.0
# 19220339  2017-09-30  2826.0        수진  승차   -37.0
# 19220340  2017-09-30  2827.0     모란(8)  승차    58.0
# 19220341  2017-09-30  2827.0     모란(8)  승차     1.0
# 19220342  2017-09-30  2827.0     모란(8)  승차    11.0
# 19220343  2017-09-30  2827.0     모란(8)  승차    42.0
# 19220344  2017-09-30  2827.0     모란(8)  승차    22.0
# 19220345  2017-09-30  2827.0     모란(8)  승차    33.0
# 19220346  2017-09-30  2827.0     모란(8)  승차    99.0
# 19220347  2017-09-30  2827.0     모란(8)  승차   178.0
# 19220348  2017-09-30  2827.0     모란(8)  승차   175.0
# 19220349  2017-09-30  2827.0     모란(8)  승차   123.0
# 19220350  2017-09-30  2827.0     모란(8)  승차    61.0
# 19220351  2017-09-30  2827.0     모란(8)  승차    21.0
# 19220352  2017-09-30  2827.0     모란(8)  승차   106.0
# 19220353  2017-09-30  2827.0     모란(8)  승차   -45.0
# 19220354  2017-09-30  2827.0     모란(8)  승차     7.0
# 19220355  2017-09-30  2827.0     모란(8)  승차   -36.0
# 19220356  2017-09-30  2827.0     모란(8)  승차   -37.0
# 19220357  2017-09-30  2827.0     모란(8)  승차   -38.0
# 19220358  2017-09-30  2827.0     모란(8)  승차   -57.0
# 19220359  2017-09-30  2827.0     모란(8)  승차   -19.0
#
# [19220360 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['date', 'number', 'name', 'div', 'a'], dtype='object')

# %%
df['name']
# Out:
# 0           서울역(150)
# 1           서울역(150)
# 2           서울역(150)
# 3           서울역(150)
# 4           서울역(150)
# 5           서울역(150)
# 6           서울역(150)
# 7           서울역(150)
# 8           서울역(150)
# 9           서울역(150)
# 10          서울역(150)
# 11          서울역(150)
# 12          서울역(150)
# 13          서울역(150)
# 14          서울역(150)
# 15          서울역(150)
# 16          서울역(150)
# 17          서울역(150)
# 18          서울역(150)
# 19          서울역(150)
# 20           시청(151)
# 21           시청(151)
# 22           시청(151)
# 23           시청(151)
# 24           시청(151)
# 25           시청(151)
# 26           시청(151)
# 27           시청(151)
# 28           시청(151)
# 29           시청(151)
#               ...
# 19220330          수진
# 19220331          수진
# 19220332          수진
# 19220333          수진
# 19220334          수진
# 19220335          수진
# 19220336          수진
# 19220337          수진
# 19220338          수진
# 19220339          수진
# 19220340       모란(8)
# 19220341       모란(8)
# 19220342       모란(8)
# 19220343       모란(8)
# 19220344       모란(8)
# 19220345       모란(8)
# 19220346       모란(8)
# 19220347       모란(8)
# 19220348       모란(8)
# 19220349       모란(8)
# 19220350       모란(8)
# 19220351       모란(8)
# 19220352       모란(8)
# 19220353       모란(8)
# 19220354       모란(8)
# 19220355       모란(8)
# 19220356       모란(8)
# 19220357       모란(8)
# 19220358       모란(8)
# 19220359       모란(8)
# Name: name, Length: 19220360, dtype: object

# %%
s = df['name']
s
# Out:
# 0           서울역(150)
# 1           서울역(150)
# 2           서울역(150)
# 3           서울역(150)
# 4           서울역(150)
# 5           서울역(150)
# 6           서울역(150)
# 7           서울역(150)
# 8           서울역(150)
# 9           서울역(150)
# 10          서울역(150)
# 11          서울역(150)
# 12          서울역(150)
# 13          서울역(150)
# 14          서울역(150)
# 15          서울역(150)
# 16          서울역(150)
# 17          서울역(150)
# 18          서울역(150)
# 19          서울역(150)
# 20           시청(151)
# 21           시청(151)
# 22           시청(151)
# 23           시청(151)
# 24           시청(151)
# 25           시청(151)
# 26           시청(151)
# 27           시청(151)
# 28           시청(151)
# 29           시청(151)
#               ...
# 19220330          수진
# 19220331          수진
# 19220332          수진
# 19220333          수진
# 19220334          수진
# 19220335          수진
# 19220336          수진
# 19220337          수진
# 19220338          수진
# 19220339          수진
# 19220340       모란(8)
# 19220341       모란(8)
# 19220342       모란(8)
# 19220343       모란(8)
# 19220344       모란(8)
# 19220345       모란(8)
# 19220346       모란(8)
# 19220347       모란(8)
# 19220348       모란(8)
# 19220349       모란(8)
# 19220350       모란(8)
# 19220351       모란(8)
# 19220352       모란(8)
# 19220353       모란(8)
# 19220354       모란(8)
# 19220355       모란(8)
# 19220356       모란(8)
# 19220357       모란(8)
# 19220358       모란(8)
# 19220359       모란(8)
# Name: name, Length: 19220360, dtype: object

# %%
s = list(set(s))
s
# Out:
# ['서초(224)',
#  '답십리',
#  '방배(225)',
#  '한강진',
#  '상월곡',
#  '문래(235)',
#  '상왕십리(207)',
#  '영등포시장',
#  '김포공항(5)',
#  '굴포천',
#  '도봉산(7)',
#  '을지로3가(203)',
#  '산성',
#  '온수(7)',
#  '개화산',
#  '송파',
#  '신설동(156)',
#  '을지로4가(204)',
#  '일원(338)',
#  '독립문(316)',
#  '발산',
#  '명일',
#  '구산',
#  '삼각지(6)',
#  '녹사평',
#  '광화문',
#  '신사(327)',
#  '천왕',
#  '양천구청(248)',
#  '천호(8)',
#  '잠실새내(217)',
#  '중계',
#  '동묘앞(6)',
#  '종각(152)',
#  '사가정',
#  '봉천(229)',
#  '상수',
#  '당고개(409)',
#  '청담',
#  '잠원(328)',
#  '디지털미디어시티(6)',
#  '대림(233)',
#  '여의나루',
#  '안암',
#  '동대문역사문화공원(205)',
#  '신중동',
#  '신도림(234)',
#  '청구(5)',
#  '구파발(310)',
#  '신림(230)',
#  '공덕(5)',
#  '약수(6)',
#  '보문',
#  '합정(6)',
#  '남성',
#  '모란(8)',
#  '태릉입구(7)',
#  '녹번(313)',
#  '영등포구청(5)',
#  '길음(417)',
#  '아현(242)',
#  '연신내(311)',
#  '종로3가(319)',
#  '행당',
#  '강남구청',
#  '문정',
#  '구의(213)',
#  '용답(244)',
#  '경복궁(317)',
#  '고속터미널(329)',
#  '태릉입구(6)',
#  '남구로',
#  '화랑대',
#  '동대문역사문화공원(422)',
#  '동대문역사문화공원5',
#  '숭실대입구',
#  '남부터미널(331)',
#  '고덕',
#  '장승배기',
#  '신촌(240)',
#  '중곡',
#  '미아사거리(416)',
#  '뚝섬유원지',
#  '효창공원앞',
#  '철산',
#  '대치(335)',
#  '군자(5)',
#  '부평구청(7)',
#  '부천종합운동장',
#  '압구정(326)',
#  '왕십리(5)',
#  '월곡',
#  '부천시청',
#  '숙대입구(427)',
#  '내방',
#  '수유(414)',
#  '뚝섬(210)',
#  '아차산',
#  '왕십리(성동구청)(208)',
#  '무악재(315)',
#  '마장',
#  '월드컵경기장',
#  '남한산성입구',
#  '신정네거리(249)',
#  '광명사거리',
#  '마포구청',
#  '서울역(426)',
#  '신풍',
#  '방이',
#  '안국(318)',
#  '이촌(430)',
#  '복정(8)',
#  '도곡(334)',
#  '강남(222)',
#  '이대(241)',
#  '잠실나루(215)',
#  '도림천(247)',
#  '동대입구(322)',
#  '교대(330)',
#  '동대문운동장(205)',
#  '충정로(5)',
#  '왕십리(208)',
#  '군자(7)',
#  '건대입구(212)',
#  '보문(6)',
#  '암사',
#  '가락시장(8)',
#  '교대(223)',
#  '금호(324)',
#  '창동(412)',
#  '마천',
#  '역촌',
#  '불광(312)',
#  '사당(433)',
#  '반포',
#  '동대문운동장(422)',
#  '수락산',
#  '청량리(지하)(158)',
#  '잠실(8)',
#  '동대문(155)',
#  '건대입구(7)',
#  '한양대(209)',
#  '낙성대(227)',
#  '홍대입구(239)',
#  '논현',
#  '대청(337)',
#  '하계',
#  '공릉',
#  '창신',
#  '새절',
#  '합정(238)',
#  '거여',
#  '길동',
#  '상일동',
#  '시청(151)',
#  '사당(226)',
#  '오금(342)',
#  '강변(214)',
#  '성수(211)',
#  '양재(332)',
#  '옥수(325)',
#  '충정로(243)',
#  '돌곶이',
#  '성신여대입구(418)',
#  '신답(245)',
#  '우장산',
#  '가락시장(340)',
#  '개롱',
#  '신설동(246)',
#  '을지로3가(320)',
#  '대흥',
#  '보라매',
#  '봉화산',
#  '당산(237)',
#  '신길(5)',
#  '광나루',
#  '학여울(336)',
#  '애오개',
#  '학동',
#  '공덕(6)',
#  '증산',
#  '지축(309)',
#  '가산디지털단지(7)',
#  '삼산체육관',
#  '미아삼거리(416)',
#  '목동',
#  '강동구청',
#  '어린이대공원',
#  '신정',
#  '단대오거리',
#  '면목',
#  '마곡',
#  '경찰병원(341)',
#  '을지로4가(5)',
#  '신대방(231)',
#  '신금호',
#  '영등포구청(236)',
#  '천호(5)',
#  '종로3가(153)',
#  '시청(201)',
#  '독바위',
#  '장암',
#  '노원(7)',
#  '상봉(7)',
#  '양평(5)',
#  '대림(7)',
#  '까치울',
#  '매봉(333)',
#  '수서(339)',
#  '동대문(421)',
#  '충무로(423)',
#  '명동(424)',
#  '남태령(434)',
#  '마포',
#  '송정',
#  '총신대입구(432)',
#  '올림픽공원',
#  '이태원',
#  '성내(215)',
#  '삼각지(428)',
#  '버티고개',
#  '고려대',
#  '장지',
#  '제기동(157)',
#  '미아(415)',
#  '쌍문(413)',
#  '광흥창',
#  '상동',
#  '약수(323)',
#  '신용산(429)',
#  '동작(431)',
#  '석촌',
#  '석계(6)',
#  '상도',
#  '혜화(420)',
#  '강동',
#  '방화',
#  '여의도(5)',
#  '종로3가(5)',
#  '서울대입구(228)',
#  '을지로입구(202)',
#  '먹골',
#  '망원',
#  '마들',
#  '신흥',
#  '춘의',
#  '연신내(6)',
#  '장한평',
#  '용두(250)',
#  '응암',
#  '몽촌토성',
#  '수진',
#  '구로디지털단지(232)',
#  '역삼(221)',
#  '상계(410)',
#  '수유(강북구청)(414)',
#  '둔촌동',
#  '신당(206)',
#  '신당(6)',
#  '굽은다리',
#  '신천(217)',
#  '고속터미널(7)',
#  '회현(425)',
#  '선릉(220)',
#  '까치산(5)',
#  '잠실(216)',
#  '서대문',
#  '청구(6)',
#  '중화',
#  '용마산',
#  '오금',
#  '서울역(150)',
#  '화곡',
#  '오목교',
#  '한성대입구(419)',
#  '종로5가(154)',
#  '신대방삼거리',
#  '불광(6)',
#  '종합운동장(218)',
#  '홍제(314)',
#  '이수(7)',
#  '노원(411)',
#  '삼성(219)',
#  '동묘앞(159)']

# %%
len(s)
# Out:
# 284

# %%
def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data) - look_back):
        dataX.append(signal_data[i:(i + look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

look_back = 7

# %%
s[1]
# Out:
# '답십리'

# %%
# for i in range(len(s)):
#     print(s[i] ,':', len(df[df['name']==s[i]]))

# %%
20226480 - 19220360 # 71220 * 284 - rows
# Out:
# 1006120

# %%
data1 = df[df['name']==s[1]]

# %%
data1.columns
# Out:
# Index(['date', 'number', 'name', 'div', 'a'], dtype='object')

# %%
data1
# Out:
#                 date  number name div       a
# 2940      2008-01-01  2543.0  답십리  승차    83.0
# 2941      2008-01-01  2543.0  답십리  승차   141.0
# 2942      2008-01-01  2543.0  답십리  승차    78.0
# 2943      2008-01-01  2543.0  답십리  승차    65.0
# 2944      2008-01-01  2543.0  답십리  승차    -9.0
# 2945      2008-01-01  2543.0  답십리  승차   139.0
# 2946      2008-01-01  2543.0  답십리  승차   259.0
# 2947      2008-01-01  2543.0  답십리  승차   199.0
# 2948      2008-01-01  2543.0  답십리  승차   130.0
# 2949      2008-01-01  2543.0  답십리  승차    55.0
# 2950      2008-01-01  2543.0  답십리  승차    58.0
# 2951      2008-01-01  2543.0  답십리  승차    -3.0
# 2952      2008-01-01  2543.0  답십리  승차    28.0
# 2953      2008-01-01  2543.0  답십리  승차  -160.0
# 2954      2008-01-01  2543.0  답십리  승차  -148.0
# 2955      2008-01-01  2543.0  답십리  승차  -210.0
# 2956      2008-01-01  2543.0  답십리  승차  -158.0
# 2957      2008-01-01  2543.0  답십리  승차  -252.0
# 2958      2008-01-01  2543.0  답십리  승차  -198.0
# 2959      2008-01-01  2543.0  답십리  승차   -10.0
# 8180      2008-01-02  2543.0  답십리  승차   298.0
# 8181      2008-01-02  2543.0  답십리  승차   410.0
# 8182      2008-01-02  2543.0  답십리  승차  1690.0
# 8183      2008-01-02  2543.0  답십리  승차  1466.0
# 8184      2008-01-02  2543.0  답십리  승차   440.0
# 8185      2008-01-02  2543.0  답십리  승차   109.0
# 8186      2008-01-02  2543.0  답십리  승차   118.0
# 8187      2008-01-02  2543.0  답십리  승차   221.0
# 8188      2008-01-02  2543.0  답십리  승차    26.0
# 8189      2008-01-02  2543.0  답십리  승차    10.0
# ...              ...     ...  ...  ..     ...
# 19212390  2017-09-29  2543.0  답십리  승차   409.0
# 19212391  2017-09-29  2543.0  답십리  승차   552.0
# 19212392  2017-09-29  2543.0  답십리  승차   758.0
# 19212393  2017-09-29  2543.0  답십리  승차  1290.0
# 19212394  2017-09-29  2543.0  답십리  승차   641.0
# 19212395  2017-09-29  2543.0  답십리  승차   321.0
# 19212396  2017-09-29  2543.0  답십리  승차   230.0
# 19212397  2017-09-29  2543.0  답십리  승차   227.0
# 19212398  2017-09-29  2543.0  답십리  승차    89.0
# 19212399  2017-09-29  2543.0  답십리  승차   -24.0
# 19217880  2017-09-30  2543.0  답십리  승차   334.0
# 19217881  2017-09-30  2543.0  답십리  승차   327.0
# 19217882  2017-09-30  2543.0  답십리  승차   499.0
# 19217883  2017-09-30  2543.0  답십리  승차   858.0
# 19217884  2017-09-30  2543.0  답십리  승차   844.0
# 19217885  2017-09-30  2543.0  답십리  승차   637.0
# 19217886  2017-09-30  2543.0  답십리  승차   597.0
# 19217887  2017-09-30  2543.0  답십리  승차   687.0
# 19217888  2017-09-30  2543.0  답십리  승차   586.0
# 19217889  2017-09-30  2543.0  답십리  승차   542.0
# 19217890  2017-09-30  2543.0  답십리  승차   684.0
# 19217891  2017-09-30  2543.0  답십리  승차   754.0
# 19217892  2017-09-30  2543.0  답십리  승차   995.0
# 19217893  2017-09-30  2543.0  답십리  승차   810.0
# 19217894  2017-09-30  2543.0  답십리  승차   349.0
# 19217895  2017-09-30  2543.0  답십리  승차   187.0
# 19217896  2017-09-30  2543.0  답십리  승차    96.0
# 19217897  2017-09-30  2543.0  답십리  승차     3.0
# 19217898  2017-09-30  2543.0  답십리  승차   -24.0
# 19217899  2017-09-30  2543.0  답십리  승차   -16.0
#
# [71220 rows x 5 columns]

# %%
len(data1)
# Out:
# 71220

# %%
data1.shape
# Out:
# (71220, 5)

# %%
data1 = df[df['name']=='강남(222)']
print(data1)
data = data1['a']
#     data = data.value
data = data.values.astype('float32')
data = data.reshape(len(data), 1)
# Out:
#                 date  number     name div        a
# 620       2008-01-01   222.0  강남(222)  승차    945.0
# 621       2008-01-01   222.0  강남(222)  승차    314.0
# 622       2008-01-01   222.0  강남(222)  승차    -64.0
# 623       2008-01-01   222.0  강남(222)  승차   -205.0
# 624       2008-01-01   222.0  강남(222)  승차   -806.0
# 625       2008-01-01   222.0  강남(222)  승차   -405.0
# 626       2008-01-01   222.0  강남(222)  승차   -336.0
# 627       2008-01-01   222.0  강남(222)  승차   -474.0
# 628       2008-01-01   222.0  강남(222)  승차   -628.0
# 629       2008-01-01   222.0  강남(222)  승차   -584.0
# 630       2008-01-01   222.0  강남(222)  승차   -661.0
# 631       2008-01-01   222.0  강남(222)  승차   -751.0
# 632       2008-01-01   222.0  강남(222)  승차   -839.0
# 633       2008-01-01   222.0  강남(222)  승차   -723.0
# 634       2008-01-01   222.0  강남(222)  승차   -198.0
# 635       2008-01-01   222.0  강남(222)  승차    800.0
# 636       2008-01-01   222.0  강남(222)  승차   1650.0
# 637       2008-01-01   222.0  강남(222)  승차   1725.0
# 638       2008-01-01   222.0  강남(222)  승차    507.0
# 639       2008-01-01   222.0  강남(222)  승차    -58.0
# 5860      2008-01-02   222.0  강남(222)  승차   -126.0
# 5861      2008-01-02   222.0  강남(222)  승차  -2936.0
# 5862      2008-01-02   222.0  강남(222)  승차  -6503.0
# 5863      2008-01-02   222.0  강남(222)  승차 -16890.0
# 5864      2008-01-02   222.0  강남(222)  승차 -10895.0
# 5865      2008-01-02   222.0  강남(222)  승차  -3198.0
# 5866      2008-01-02   222.0  강남(222)  승차  -1487.0
# 5867      2008-01-02   222.0  강남(222)  승차     79.0
# 5868      2008-01-02   222.0  강남(222)  승차   -858.0
# 5869      2008-01-02   222.0  강남(222)  승차    364.0
# ...              ...     ...      ...  ..      ...
# 19209990  2017-09-29   222.0  강남(222)  승차   1807.0
# 19209991  2017-09-29   222.0  강남(222)  승차   2009.0
# 19209992  2017-09-29   222.0  강남(222)  승차   3212.0
# 19209993  2017-09-29   222.0  강남(222)  승차   3768.0
# 19209994  2017-09-29   222.0  강남(222)  승차    347.0
# 19209995  2017-09-29   222.0  강남(222)  승차   3698.0
# 19209996  2017-09-29   222.0  강남(222)  승차   6670.0
# 19209997  2017-09-29   222.0  강남(222)  승차   7869.0
# 19209998  2017-09-29   222.0  강남(222)  승차   4514.0
# 19209999  2017-09-29   222.0  강남(222)  승차   1020.0
# 19215480  2017-09-30   222.0  강남(222)  승차    505.0
# 19215481  2017-09-30   222.0  강남(222)  승차   -266.0
# 19215482  2017-09-30   222.0  강남(222)  승차  -1094.0
# 19215483  2017-09-30   222.0  강남(222)  승차  -3007.0
# 19215484  2017-09-30   222.0  강남(222)  승차  -5567.0
# 19215485  2017-09-30   222.0  강남(222)  승차  -3318.0
# 19215486  2017-09-30   222.0  강남(222)  승차  -2564.0
# 19215487  2017-09-30   222.0  강남(222)  승차  -2017.0
# 19215488  2017-09-30   222.0  강남(222)  승차  -2499.0
# 19215489  2017-09-30   222.0  강남(222)  승차  -1175.0
# 19215490  2017-09-30   222.0  강남(222)  승차    644.0
# 19215491  2017-09-30   222.0  강남(222)  승차   1618.0
# 19215492  2017-09-30   222.0  강남(222)  승차   1984.0
# 19215493  2017-09-30   222.0  강남(222)  승차   1074.0
# 19215494  2017-09-30   222.0  강남(222)  승차    934.0
# 19215495  2017-09-30   222.0  강남(222)  승차   1327.0
# 19215496  2017-09-30   222.0  강남(222)  승차   2817.0
# 19215497  2017-09-30   222.0  강남(222)  승차   4176.0
# 19215498  2017-09-30   222.0  강남(222)  승차   1975.0
# 19215499  2017-09-30   222.0  강남(222)  승차   -159.0
#
# [71220 rows x 5 columns]

# %%
data
# Out:
# array([[ 945.],
#        [ 314.],
#        [ -64.],
#        ...,
#        [4176.],
#        [1975.],
#        [-159.]], dtype=float32)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

train_size = int(len(data) * 0.80)
test_size = len(data) - train_size

train = data[0:train_size]
test = data[train_size:len(data)]
x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
# 모델 구성하기

model = Sequential()
model.add(LSTM(512, input_shape=(None, 1), return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(1024, input_shape=(None, 1)))
model.add(Dropout(0.3))
# model.add(LSTM(i, input_shape=(None, 1)))

# model.add(Dense(i))
# model.add(Dropout(0.3))
# model.add(Dropout(0.3))
# model.add(Dense(64))

model.add(Dense(1))
name = "tt.jpg"
# 모델 학습과정 설정하기
model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['accuracy'])
model.summary()
hist = model.fit(x_train, y_train, epochs=10, batch_size=16)
p = model.predict(x_test)

plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))
# plt.savefig(datetime.datetime.now())
plt.savefig(name)
plt.clf()
print(mean_squared_error(y_test, p))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, None, 512)         1052672
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 512)         0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1024)              6295552
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 7,349,249
# Trainable params: 7,349,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 56969/56969 [==============================] - 1514s 27ms/step - loss: 0.0076 - acc: 3.5107e-05
# Epoch 2/10
# 56969/56969 [==============================] - 1513s 27ms/step - loss: 0.0025 - acc: 3.5107e-05
# Epoch 3/10
# 56969/56969 [==============================] - 1537s 27ms/step - loss: 0.0018 - acc: 3.5107e-05
# Epoch 4/10
# 56969/56969 [==============================] - 1552s 27ms/step - loss: 0.0014 - acc: 3.5107e-05
# Epoch 5/10
# 56969/56969 [==============================] - 1576s 28ms/step - loss: 0.0012 - acc: 3.5107e-05
# Epoch 6/10
# 56969/56969 [==============================] - 1545s 27ms/step - loss: 0.0011 - acc: 3.5107e-05
# Epoch 7/10
# 56969/56969 [==============================] - 1776s 31ms/step - loss: 0.0010 - acc: 3.5107e-05
# Epoch 8/10
# 56969/56969 [==============================] - 1568s 28ms/step - loss: 9.3499e-04 - acc: 3.5107e-05
# Epoch 9/10
# 56969/56969 [==============================] - 1576s 28ms/step - loss: 8.8544e-04 - acc: 3.5107e-05
# Epoch 10/10
# 56969/56969 [==============================] - 1584s 28ms/step - loss: 8.2845e-04 - acc: 3.5107e-05
# 0.00081945

# %%
# Plot training & validation loss values
plt.plot(hist.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file : 
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from keras.models import model_from_json
json_file = open("model.json", "r")
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
model.load_weights("model.h5")
model.compile(loss="mean_squared_error", optimizer="rmsprop", metrics=['accuracy'])

# %%
plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'prediction'], loc='best')
plt.title('LSTM(512)+LSTM(1024)')
plt.ylabel('embarked personnel')
plt.xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %%
trainPredict = model.predict(x_train)
testPredict = model.predict(x_test)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([y_test])

# shift train predictions for plotting
trainPredictPlot = np.empty_like(data)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(data)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(data)+2, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(data))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-31ca1bc60c5b> in <module>
#       1 # make predictions
# ----> 2 trainPredict = model.predict(x_train)
#       3 testPredict = model.predict(x_test)
#       4 # invert predictions
#       5 trainPredict = scaler.inverse_transform(trainPredict)
#
# ~\Anaconda3\envs\me\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~\Anaconda3\envs\me\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~\Anaconda3\envs\me\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\envs\me\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\Anaconda3\envs\me\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
import math
# make predictions
trainPredict = model.predict(x_train)
testPredict = model.predict(x_test)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([y_test])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# 마지막으로 모델의 기술을 시각적으로 표시하기 위해 열차 및 테스트 데이터 세트 모두에 대해 모델을 사용하여 예측을 생성 할 수 있습니다.

# 데이터 세트가 준비되었으므로, x 축에서 원래 데이터 세트와 정렬되도록 예측을 이동해야합니다. 준비가 완료되면 데이터가 그려져 원본 데이터 세트가 파란색으로 표시되고 교육 데이터 세트의 녹색 예측이 표시되며 보이지 않는 테스트 데이터 세트의 예측은 빨간색으로 표시됩니다.

# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-fbe989fc0d4e> in <module>
#       5 # invert predictions
#       6 trainPredict = scaler.inverse_transform(trainPredict)
# ----> 7 trainY = scaler.inverse_transform([y_train])
#       8 testPredict = scaler.inverse_transform(testPredict)
#       9 testY = scaler.inverse_transform([y_test])
#
# ~\Anaconda3\envs\me\lib\site-packages\sklearn\preprocessing\data.py in inverse_transform(self, X)
#     411
#     412         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES,
# --> 413                         force_all_finite="allow-nan")
#     414
#     415         X -= self.min_
#
# ~\Anaconda3\envs\me\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     568         if not allow_nd and array.ndim >= 3:
#     569             raise ValueError("Found array with dim %d. %s expected <= 2."
# --> 570                              % (array.ndim, estimator_name))
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
#
# ValueError: Found array with dim 3. Estimator expected <= 2.

# %%
plt.plot(testPredictPlot)
plt.show()

# %%
from keras.utils import plot_model
plot_model(loaded_model, to_file='model.png')
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(loaded_model).create(prog='dot', format='svg'))
plot_model(loaded_model, to_file='model_plot.png')

# %%
SVG(model_to_dot(loaded_model).create(prog='dot', format='svg'))

# %%
plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))
# plt.savefig(datetime.datetime.now())
plt.show()
print(mean_squared_error(y_test, p))
