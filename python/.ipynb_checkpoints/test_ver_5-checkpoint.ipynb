# 19220352  2017-09-30  2827.0     모란(8)  승차   106.0
# 19220353  2017-09-30  2827.0     모란(8)  승차   -45.0
# 19220354  2017-09-30  2827.0     모란(8)  승차     7.0
# 19220355  2017-09-30  2827.0     모란(8)  승차   -36.0
# 19220356  2017-09-30  2827.0     모란(8)  승차   -37.0
# 19220357  2017-09-30  2827.0     모란(8)  승차   -38.0
# 19220358  2017-09-30  2827.0     모란(8)  승차   -57.0
# 19220359  2017-09-30  2827.0     모란(8)  승차   -19.0
#
# [19220360 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['date', 'number', 'name', 'div', 'a'], dtype='object')

# %%
df['name']
# Out:
# 0           서울역(150)
# 1           서울역(150)
# 2           서울역(150)
# 3           서울역(150)
# 4           서울역(150)
# 5           서울역(150)
# 6           서울역(150)
# 7           서울역(150)
# 8           서울역(150)
# 9           서울역(150)
# 10          서울역(150)
# 11          서울역(150)
# 12          서울역(150)
# 13          서울역(150)
# 14          서울역(150)
# 15          서울역(150)
# 16          서울역(150)
# 17          서울역(150)
# 18          서울역(150)
# 19          서울역(150)
# 20           시청(151)
# 21           시청(151)
# 22           시청(151)
# 23           시청(151)
# 24           시청(151)
# 25           시청(151)
# 26           시청(151)
# 27           시청(151)
# 28           시청(151)
# 29           시청(151)
#               ...
# 19220330          수진
# 19220331          수진
# 19220332          수진
# 19220333          수진
# 19220334          수진
# 19220335          수진
# 19220336          수진
# 19220337          수진
# 19220338          수진
# 19220339          수진
# 19220340       모란(8)
# 19220341       모란(8)
# 19220342       모란(8)
# 19220343       모란(8)
# 19220344       모란(8)
# 19220345       모란(8)
# 19220346       모란(8)
# 19220347       모란(8)
# 19220348       모란(8)
# 19220349       모란(8)
# 19220350       모란(8)
# 19220351       모란(8)
# 19220352       모란(8)
# 19220353       모란(8)
# 19220354       모란(8)
# 19220355       모란(8)
# 19220356       모란(8)
# 19220357       모란(8)
# 19220358       모란(8)
# 19220359       모란(8)
# Name: name, Length: 19220360, dtype: object

# %%
s = df['name']
s
# Out:
# 0           서울역(150)
# 1           서울역(150)
# 2           서울역(150)
# 3           서울역(150)
# 4           서울역(150)
# 5           서울역(150)
# 6           서울역(150)
# 7           서울역(150)
# 8           서울역(150)
# 9           서울역(150)
# 10          서울역(150)
# 11          서울역(150)
# 12          서울역(150)
# 13          서울역(150)
# 14          서울역(150)
# 15          서울역(150)
# 16          서울역(150)
# 17          서울역(150)
# 18          서울역(150)
# 19          서울역(150)
# 20           시청(151)
# 21           시청(151)
# 22           시청(151)
# 23           시청(151)
# 24           시청(151)
# 25           시청(151)
# 26           시청(151)
# 27           시청(151)
# 28           시청(151)
# 29           시청(151)
#               ...
# 19220330          수진
# 19220331          수진
# 19220332          수진
# 19220333          수진
# 19220334          수진
# 19220335          수진
# 19220336          수진
# 19220337          수진
# 19220338          수진
# 19220339          수진
# 19220340       모란(8)
# 19220341       모란(8)
# 19220342       모란(8)
# 19220343       모란(8)
# 19220344       모란(8)
# 19220345       모란(8)
# 19220346       모란(8)
# 19220347       모란(8)
# 19220348       모란(8)
# 19220349       모란(8)
# 19220350       모란(8)
# 19220351       모란(8)
# 19220352       모란(8)
# 19220353       모란(8)
# 19220354       모란(8)
# 19220355       모란(8)
# 19220356       모란(8)
# 19220357       모란(8)
# 19220358       모란(8)
# 19220359       모란(8)
# Name: name, Length: 19220360, dtype: object

# %%
s = list(set(s))
s
# Out:
# ['삼각지(6)',
#  '총신대입구(432)',
#  '보라매',
#  '신용산(429)',
#  '중화',
#  '대림(7)',
#  '발산',
#  '연신내(311)',
#  '수서(339)',
#  '둔촌동',
#  '남구로',
#  '청량리(지하)(158)',
#  '종로3가(319)',
#  '창동(412)',
#  '상동',
#  '독바위',
#  '성수(211)',
#  '신천(217)',
#  '신답(245)',
#  '매봉(333)',
#  '도곡(334)',
#  '안암',
#  '신정네거리(249)',
#  '광화문',
#  '방배(225)',
#  '오금(342)',
#  '용두(250)',
#  '신사(327)',
#  '낙성대(227)',
#  '동대문운동장(205)',
#  '수유(414)',
#  '강동',
#  '충정로(5)',
#  '미아사거리(416)',
#  '철산',
#  '을지로4가(204)',
#  '공덕(6)',
#  '문정',
#  '여의나루',
#  '신촌(240)',
#  '동대문(155)',
#  '청구(6)',
#  '한강진',
#  '명일',
#  '신금호',
#  '마천',
#  '하계',
#  '을지로3가(203)',
#  '김포공항(5)',
#  '부천종합운동장',
#  '노원(7)',
#  '굴포천',
#  '새절',
#  '마포',
#  '경찰병원(341)',
#  '회현(425)',
#  '역삼(221)',
#  '길동',
#  '월곡',
#  '신도림(234)',
#  '서울대입구(228)',
#  '복정(8)',
#  '상일동',
#  '중곡',
#  '을지로3가(320)',
#  '시청(151)',
#  '삼성(219)',
#  '용마산',
#  '무악재(315)',
#  '건대입구(212)',
#  '광명사거리',
#  '뚝섬(210)',
#  '학여울(336)',
#  '동대문역사문화공원(422)',
#  '사가정',
#  '신대방삼거리',
#  '교대(330)',
#  '고속터미널(329)',
#  '천왕',
#  '버티고개',
#  '장지',
#  '신설동(156)',
#  '이촌(430)',
#  '압구정(326)',
#  '영등포구청(236)',
#  '상계(410)',
#  '동대문운동장(422)',
#  '도림천(247)',
#  '여의도(5)',
#  '응암',
#  '태릉입구(6)',
#  '개화산',
#  '왕십리(5)',
#  '잠실나루(215)',
#  '보문',
#  '종로5가(154)',
#  '청구(5)',
#  '가락시장(8)',
#  '왕십리(성동구청)(208)',
#  '공덕(5)',
#  '암사',
#  '태릉입구(7)',
#  '고속터미널(7)',
#  '잠실(216)',
#  '산성',
#  '경복궁(317)',
#  '대청(337)',
#  '신당(206)',
#  '아차산',
#  '구산',
#  '수진',
#  '장암',
#  '영등포시장',
#  '양천구청(248)',
#  '모란(8)',
#  '동묘앞(6)',
#  '구의(213)',
#  '합정(238)',
#  '한성대입구(419)',
#  '왕십리(208)',
#  '잠원(328)',
#  '신중동',
#  '목동',
#  '종로3가(5)',
#  '안국(318)',
#  '종로3가(153)',
#  '미아(415)',
#  '수유(강북구청)(414)',
#  '남한산성입구',
#  '아현(242)',
#  '역촌',
#  '대흥',
#  '장한평',
#  '석계(6)',
#  '돌곶이',
#  '가락시장(340)',
#  '동대입구(322)',
#  '고덕',
#  '마곡',
#  '신당(6)',
#  '을지로입구(202)',
#  '약수(323)',
#  '신설동(246)',
#  '숙대입구(427)',
#  '이태원',
#  '영등포구청(5)',
#  '천호(8)',
#  '신풍',
#  '보문(6)',
#  '서초(224)',
#  '방화',
#  '올림픽공원',
#  '서울역(150)',
#  '서대문',
#  '천호(5)',
#  '동대문(421)',
#  '금호(324)',
#  '오목교',
#  '강동구청',
#  '독립문(316)',
#  '행당',
#  '송파',
#  '녹사평',
#  '디지털미디어시티(6)',
#  '제기동(157)',
#  '신정',
#  '미아삼거리(416)',
#  '구파발(310)',
#  '상봉(7)',
#  '춘의',
#  '동대문역사문화공원(205)',
#  '교대(223)',
#  '수락산',
#  '신대방(231)',
#  '학동',
#  '단대오거리',
#  '구로디지털단지(232)',
#  '까치울',
#  '합정(6)',
#  '일원(338)',
#  '논현',
#  '까치산(5)',
#  '홍제(314)',
#  '개롱',
#  '불광(312)',
#  '봉화산',
#  '망원',
#  '동대문역사문화공원5',
#  '내방',
#  '면목',
#  '군자(5)',
#  '성내(215)',
#  '녹번(313)',
#  '충무로(423)',
#  '용답(244)',
#  '신흥',
#  '을지로4가(5)',
#  '시청(201)',
#  '한양대(209)',
#  '성신여대입구(418)',
#  '동작(431)',
#  '장승배기',
#  '어린이대공원',
#  '건대입구(7)',
#  '옥수(325)',
#  '상도',
#  '부평구청(7)',
#  '화랑대',
#  '지축(309)',
#  '군자(7)',
#  '온수(7)',
#  '삼산체육관',
#  '상월곡',
#  '창신',
#  '강남구청',
#  '월드컵경기장',
#  '도봉산(7)',
#  '증산',
#  '마장',
#  '종합운동장(218)',
#  '서울역(426)',
#  '명동(424)',
#  '상왕십리(207)',
#  '이수(7)',
#  '대림(233)',
#  '양평(5)',
#  '거여',
#  '강변(214)',
#  '문래(235)',
#  '종각(152)',
#  '당고개(409)',
#  '신길(5)',
#  '굽은다리',
#  '마들',
#  '송정',
#  '청담',
#  '가산디지털단지(7)',
#  '몽촌토성',
#  '고려대',
#  '당산(237)',
#  '충정로(243)',
#  '사당(433)',
#  '대치(335)',
#  '먹골',
#  '잠실(8)',
#  '동묘앞(159)',
#  '중계',
#  '답십리',
#  '화곡',
#  '홍대입구(239)',
#  '우장산',
#  '혜화(420)',
#  '사당(226)',
#  '불광(6)',
#  '남부터미널(331)',
#  '효창공원앞',
#  '반포',
#  '쌍문(413)',
#  '잠실새내(217)',
#  '노원(411)',
#  '길음(417)',
#  '광나루',
#  '강남(222)',
#  '방이',
#  '뚝섬유원지',
#  '공릉',
#  '석촌',
#  '마포구청',
#  '부천시청',
#  '봉천(229)',
#  '이대(241)',
#  '남태령(434)',
#  '선릉(220)',
#  '애오개',
#  '광흥창',
#  '오금',
#  '연신내(6)',
#  '삼각지(428)',
#  '약수(6)',
#  '양재(332)',
#  '상수',
#  '숭실대입구',
#  '남성',
#  '신림(230)']

# %%
len(s)
# Out:
# 284

# %%
def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data) - look_back):
        dataX.append(signal_data[i:(i + look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

look_back = 20

# %%
s[1]
# Out:
# '총신대입구(432)'

# %%
# for i in range(len(s)):
#     print(s[i] ,':', len(df[df['name']==s[i]]))

# %%
20226480 - 19220360 # 71220 * 284 - rows
# Out:
# 1006120

# %%
data1 = df[df['name']==s[1]]

# %%
data1.columns
# Out:
# Index(['date', 'number', 'name', 'div', 'a'], dtype='object')

# %%
data1
# Out:
#                 date  number        name div       a
# 2260      2008-01-01   432.0  총신대입구(432)  승차   126.0
# 2261      2008-01-01   432.0  총신대입구(432)  승차   -11.0
# 2262      2008-01-01   432.0  총신대입구(432)  승차    66.0
# 2263      2008-01-01   432.0  총신대입구(432)  승차    89.0
# 2264      2008-01-01   432.0  총신대입구(432)  승차   125.0
# 2265      2008-01-01   432.0  총신대입구(432)  승차   197.0
# 2266      2008-01-01   432.0  총신대입구(432)  승차   220.0
# 2267      2008-01-01   432.0  총신대입구(432)  승차   191.0
# 2268      2008-01-01   432.0  총신대입구(432)  승차   202.0
# 2269      2008-01-01   432.0  총신대입구(432)  승차    88.0
# 2270      2008-01-01   432.0  총신대입구(432)  승차   -31.0
# 2271      2008-01-01   432.0  총신대입구(432)  승차   -93.0
# 2272      2008-01-01   432.0  총신대입구(432)  승차  -227.0
# 2273      2008-01-01   432.0  총신대입구(432)  승차  -440.0
# 2274      2008-01-01   432.0  총신대입구(432)  승차  -335.0
# 2275      2008-01-01   432.0  총신대입구(432)  승차  -445.0
# 2276      2008-01-01   432.0  총신대입구(432)  승차  -378.0
# 2277      2008-01-01   432.0  총신대입구(432)  승차  -310.0
# 2278      2008-01-01   432.0  총신대입구(432)  승차  -265.0
# 19215492  2017-09-30   222.0  강남(222)  승차   1984.0
# 19215493  2017-09-30   222.0  강남(222)  승차   1074.0
# 19215494  2017-09-30   222.0  강남(222)  승차    934.0
# 19215495  2017-09-30   222.0  강남(222)  승차   1327.0
# 19215496  2017-09-30   222.0  강남(222)  승차   2817.0
# 19215497  2017-09-30   222.0  강남(222)  승차   4176.0
# 19215498  2017-09-30   222.0  강남(222)  승차   1975.0
# 19215499  2017-09-30   222.0  강남(222)  승차   -159.0
#
# [71220 rows x 5 columns]

# %%
data
# Out:
# array([[ 945.],
#        [ 314.],
#        [ -64.],
#        ...,
#        [4176.],
#        [1975.],
#        [-159.]], dtype=float32)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

train_size = int(len(data) * 0.80)
test_size = len(data) - train_size

train = data[0:train_size]
test = data[train_size:len(data)]
x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
# 모델 구성하기

# %%
# model = Sequential()
# model.add(LSTM(512, input_shape=(None, 1), return_sequences=True))
# model.add(Dropout(0.3))

# model.add(LSTM(512, input_shape=(None, 1)))
# model.add(Dropout(0.3))
# # model.add(LSTM(i, input_shape=(None, 1)))

# # model.add(Dense(i))
# # model.add(Dropout(0.3))
# # model.add(Dropout(0.3))
# # model.add(Dense(64))

# model.add(Dense(1))
# name = "tt.jpg"
# # 모델 학습과정 설정하기
# model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['accuracy'])
# model.summary()
# hist = model.fit(x_train, y_train, epochs=10, batch_size=64)
from keras.models import load_model
model = load_model('trythis.h5')

# %%
p = model.predict(x_test)
plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))
# plt.savefig(datetime.datetime.now())
plt.show()
print(mean_squared_error(y_test, p))
# Out:
# 0.0040040626

# %%
plt.plot(y_test[:200])

# %%
plt.plot(p[:200])

# %%
# model_json = model.to_json()
# with open("model.json", "w") as json_file : 
#     json_file.write(model_json)
# model.save_weights("model.h5")
# print("Saved model to disk")

# %%
from keras.models import model_from_json
json_file = open("model.json", "r")
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
model.load_weights("model.h5")
model.compile(loss="mean_squared_error", optimizer="rmsprop", metrics=['accuracy'])

# %%
# # Plot training & validation loss values

# plt.plot(hist.history['loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()

# %%
# # Plot training & validation loss values
# plt.plot(hist.history['loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Test'], loc='upper left')
# plt.show()

# %%
p = model.predict(x_test)
plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'prediction'], loc='best')
plt.title('LSTM(512)+LSTM(1024)')
plt.ylabel('embarked personnel')
plt.xlabel('Time')

# %%
plt.plot(p)

# %%
trainPredict = model.predict(x_train)
testPredict = model.predict(x_test)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([y_test])

# shift train predictions for plotting
trainPredictPlot = np.empty_like(data)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(data)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(data)+2, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(data))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
plt.plot(p)
p.shape
# Out:
# (14224, 1)

# %%
y = p
x = list(range(len(p)))
x = np.reshape(x, (-1, 1))
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=.8)
from sklearn.linear_model import LinearRegression

model = LinearRegression() 
model.fit(X_train, y_train)
# Out:
# C:\Users\ML\Anaconda3\envs\me\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
p = model.predict(X_test)
plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))
# plt.savefig(datetime.datetime.now())
plt.show()
print(mean_squared_error(y_test, p))
# Out:
# 0.02169775431742546

# %%
import math
# make predictions
trainPredict = model.predict(x_train)
testPredict = model.predict(x_test)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([y_test])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# 마지막으로 모델의 기술을 시각적으로 표시하기 위해 열차 및 테스트 데이터 세트 모두에 대해 모델을 사용하여 예측을 생성 할 수 있습니다.

# 데이터 세트가 준비되었으므로, x 축에서 원래 데이터 세트와 정렬되도록 예측을 이동해야합니다. 준비가 완료되면 데이터가 그려져 원본 데이터 세트가 파란색으로 표시되고 교육 데이터 세트의 녹색 예측이 표시되며 보이지 않는 테스트 데이터 세트의 예측은 빨간색으로 표시됩니다.

# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-fbe989fc0d4e> in <module>
#       1 import math
#       2 # make predictions
# ----> 3 trainPredict = model.predict(x_train)
#       4 testPredict = model.predict(x_test)
#       5 # invert predictions
#
# ~\Anaconda3\envs\me\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~\Anaconda3\envs\me\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~\Anaconda3\envs\me\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\envs\me\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\Anaconda3\envs\me\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
plt.plot(testPredictPlot)
plt.show()

# %%
from keras.utils import plot_model
plot_model(loaded_model, to_file='model.png')
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(loaded_model).create(prog='dot', format='svg'))
plot_model(loaded_model, to_file='model_plot.png')

# %%
SVG(model_to_dot(loaded_model).create(prog='dot', format='svg'))

# %%
plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.title(mean_squared_error(y_test, p))
# plt.savefig(datetime.datetime.now())
plt.show()
print(mean_squared_error(y_test, p))

# %%
p
