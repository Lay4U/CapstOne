# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.layers.core import Dense, Activation, Dropout
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#             날짜    역번호          역명    구분   05~06   06~07   07~08   08~09   \
# 0   2008-01-01     150   서울역(150)    승차     379     287     371     876
# 1   2008-01-01     150   서울역(150)    하차     145     707     689   1,037
# 2   2008-01-01     151    시청(151)    승차     131     131     101     152
# 3   2008-01-01     151    시청(151)    하차      35     158     203     393
# 4   2008-01-01     152    종각(152)    승차   1,287     867     400     330
#
#    09~10   10~11    ...    15~16   16~17   17~18   18~19   19~20   20~21   \
# 0    965   1,389    ...    2,520   3,078   3,495   3,055   2,952   2,726
# 1  1,170   1,376    ...    1,955   2,304   2,203   2,128   1,747   1,593
# 2    191     202    ...      892     900   1,154   1,706   1,444   1,267
# 3    375     460    ...    1,157   1,153   1,303   1,190     830     454
# 4    345     338    ...    1,867   2,269   2,777   2,834   2,646   2,784
#
#    21~22   22~23   23~24     24~
# 0  3,307   2,584   1,059     264
# 1  1,078     744     406     558
# 2    928     531     233     974
# 3    284     141     107     185
# 4  2,920   2,290     802   1,559
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index([' 날짜 ', ' 역번호 ', ' 역명 ', ' 구분 ', ' 05~06 ', ' 06~07 ', ' 07~08 ',
#        ' 08~09 ', ' 09~10 ', ' 10~11 ', ' 11~12 ', ' 12~13 ', ' 13~14 ',
#        ' 14~15 ', ' 15~16 ', ' 16~17 ', ' 17~18 ', ' 18~19 ', ' 19~20 ',
#        ' 20~21 ', ' 21~22 ', ' 22~23 ', ' 23~24 ', ' 24~ '],
#       dtype='object')

# %%
df[' 역명 ']
# Out:
# 0               서울역(150)
# 1               서울역(150)
# 2                시청(151)
# 3                시청(151)
# 4                종각(152)
# 5                종각(152)
# 6              종로3가(153)
# 7              종로3가(153)
# 8              종로5가(154)
# 9              종로5가(154)
# 10              동대문(155)
# 11              동대문(155)
# 12              신설동(156)
# 13              신설동(156)
# 14              제기동(157)
# 15              제기동(157)
# 16          청량리(지하)(158)
# 17          청량리(지하)(158)
# 18              동묘앞(159)
# 19              동묘앞(159)
# 20               시청(201)
# 21               시청(201)
# 22            을지로입구(202)
# 23            을지로입구(202)
# 24            을지로3가(203)
# 25            을지로3가(203)
# 26            을지로4가(204)
# 27            을지로4가(204)
# 28           동대문운동장(205)
# 29           동대문운동장(205)
#                 ...
# 1922006              강동구청
# 1922007              강동구청
# 1922008              몽촌토성
# 1922009              몽촌토성
# 1922010             잠실(8)
# 1922011             잠실(8)
# 1922012                석촌
# 1922013                석촌
# 1922014                송파
# 1922015                송파
# 1922016           가락시장(8)
# 1922017           가락시장(8)
# 1922018                문정
# 1922019                문정
# 1922020                장지
# 1922021                장지
# 1922022             복정(8)
# 1922023             복정(8)
# 1922024                산성
# 1922025                산성
# 1922026            남한산성입구
# 1922027            남한산성입구
# 1922028             단대오거리
# 1922029             단대오거리
# 1922030                신흥
# 1922031                신흥
# 1922032                수진
# 1922033                수진
# 1922034             모란(8)
# 1922035             모란(8)
# Name:  역명 , Length: 1922036, dtype: object

# %%
s = df[' 역명 ']

# %%
s = set(s)

# %%
len(s)
# Out:
# 547

# %%
s = list(s)
# s = list(set(df[' 역명 ']))

# %%
s
# Out:
# [' 상왕십리(207) ',
#  '상봉(7)',
#  '수서(339)',
#  '성수(211)',
#  '목동',
#  '오금',
#  ' 모란(8) ',
#  '영등포시장',
#  '월드컵경기장',
#  '군자(5)',
#  ' 공릉 ',
#  ' 안암 ',
#  ' 길음(417) ',
#  '온수(7)',
#  ' 수유(414) ',
#  ' 애오개 ',
#  ' 굽은다리 ',
#  '이촌(430)',
#  ' 내방 ',
#  '잠실(216)',
#  '공덕(6)',
#  ' 군자(5) ',
#  '먹골',
#  ' 경복궁(317) ',
#  '명일',
#  ' 역삼(221) ',
#  ' 중화 ',
#  ' 이수(7) ',
#  ' 아차산 ',
#  '무악재(315)',
#  ' 상월곡 ',
#  ' 역촌 ',
#  ' 옥수(325) ',
#  '남한산성입구',
#  ' 행당 ',
#  ' 당산(237) ',
#  ' 충무로(423) ',
#  ' 장승배기 ',
#  ' 신당(6) ',
#  '도림천(247)',
#  '태릉입구(7)',
#  ' 개화산 ',
#  ' 방화 ',
#  ' 서울대입구(228) ',
#  '시청(151)',
#  '답십리',
#  '응암',
#  '당산(237)',
#  ' 고속터미널(329) ',
#  ' 왕십리(208) ',
#  '문래(235)',
#  '신용산(429)',
#  ' 남한산성입구 ',
#  '중계',
#  ' 숙대입구(427) ',
#  '동대문역사문화공원(205)',
#  ' 남부터미널(331) ',
#  ' 태릉입구(7) ',
#  ' 월드컵경기장 ',
#  '불광(312)',
#  '지축(309)',
#  '부천시청',
#  '뚝섬(210)',
#  '한성대입구(419)',
#  '상월곡',
#  ' 수서(339) ',
#  ' 성수(211) ',
#  ' 마포 ',
#  '상일동',
#  ' 신정 ',
#  '공릉',
#  '동작(431)',
#  ' 명일 ',
#  ' 성신여대입구(418) ',
#  ' 천호(8) ',
#  ' 충정로(243) ',
#  '중화',
#  ' 강동 ',
#  '부천종합운동장',
#  '신길(5)',
#  '산성',
#  ' 디지털미디어시티(6) ',
#  ' 대림(233) ',
#  ' 잠원(328) ',
#  '노원(411)',
#  ' 이대(241) ',
#  '보문(6)',
#  ' 김포공항(5) ',
#  '대림(7)',
#  ' 연신내(311) ',
#  '뚝섬유원지',
#  ' 하계 ',
#  ' 홍대입구(239) ',
#  ' 한양대(209) ',
#  '마포',
#  '을지로3가(203)',
#  ' 미아삼거리(416) ',
#  ' 독바위 ',
#  ' 숭실대입구 ',
#  '서울역(150)',
#  '교대(330)',
#  ' 수락산 ',
#  '강동구청',
#  '낙성대(227)',
#  '신당(206)',
#  '수유(414)',
#  '서초(224)',
#  '신설동(156)',
#  '회현(425)',
#  '구의(213)',
#  ' 을지로입구(202) ',
#  ' 신천(217) ',
#  '영등포구청(5)',
#  ' 합정(238) ',
#  '아현(242)',
#  ' 종합운동장(218) ',
#  ' 대림(7) ',
#  ' 무악재(315) ',
#  ' 마곡 ',
#  '단대오거리',
#  '대림(233)',
#  ' 미아(415) ',
#  ' 발산 ',
#  ' 총신대입구(432) ',
#  ' 삼각지(6) ',
#  ' 독립문(316) ',
#  '삼산체육관',
#  ' 사가정 ',
#  '화곡',
#  '남구로',
#  '모란(8)',
#  '둔촌동',
#  ' 남성 ',
#  '화랑대',
#  ' 종로3가(153) ',
#  '충무로(423)',
#  '마장',
#  '안국(318)',
#  '청구(6)',
#  '신설동(246)',
#  '서울대입구(228)',
#  ' 압구정(326) ',
#  ' 대흥 ',
#  '이수(7)',
#  '장지',
#  '시청(201)',
#  ' 새절 ',
#  ' 면목 ',
#  ' 창동(412) ',
#  '고려대',
#  '새절',
#  ' 태릉입구(6) ',
#  ' 용마산 ',
#  '방이',
#  '도봉산(7)',
#  ' 충정로(5) ',
#  ' 낙성대(227) ',
#  '광나루',
#  '삼각지(6)',
#  ' 쌍문(413) ',
#  '청량리(지하)(158)',
#  '잠실(8)',
#  '왕십리(208)',
#  ' 이촌(430) ',
#  '동대문운동장(422)',
#  ' 녹번(313) ',
#  '가락시장(340)',
#  '애오개',
#  '까치울',
#  '신촌(240)',
#  ' 신당(206) ',
#  ' 석계(6) ',
#  '숙대입구(427)',
#  ' 강남(222) ',
#  ' 가산디지털단지(7) ',
#  '광명사거리',
#  ' 동대문(421) ',
#  '사가정',
#  '선릉(220)',
#  '경복궁(317)',
#  '천왕',
#  '신정네거리(249)',
#  '남성',
#  '잠원(328)',
#  ' 안국(318) ',
#  ' 아현(242) ',
#  '양천구청(248)',
#  '효창공원앞',
#  ' 서울역(150) ',
#  '봉천(229)',
#  ' 산성 ',
#  ' 동묘앞(6) ',
#  ' 삼각지(428) ',
#  '상동',
#  ' 교대(223) ',
#  '구산',
#  '남부터미널(331)',
#  '경찰병원(341)',
#  '송파',
#  ' 보라매 ',
#  '아차산',
#  ' 신용산(429) ',
#  ' 한강진 ',
#  ' 마천 ',
#  ' 강남구청 ',
#  ' 잠실(216) ',
#  ' 시청(151) ',
#  ' 상도 ',
#  '신답(245)',
#  ' 송정 ',
#  '여의나루',
#  ' 시청(201) ',
#  '고속터미널(7)',
#  ' 동대문(155) ',
#  ' 월곡 ',
#  '을지로입구(202)',
#  ' 둔촌동 ',
#  ' 복정(8) ',
#  '태릉입구(6)',
#  '동묘앞(159)',
#  ' 회현(425) ',
#  '복정(8)',
#  '반포',
#  ' 금호(324) ',
#  ' 불광(312) ',
#  ' 선릉(220) ',
#  '망원',
#  ' 구의(213) ',
#  '신림(230)',
#  '영등포구청(236)',
#  '성신여대입구(418)',
#  ' 건대입구(212) ',
#  '불광(6)',
#  ' 사당(226) ',
#  ' 대치(335) ',
#  '청구(5)',
#  ' 마포구청 ',
#  ' 온수(7) ',
#  ' 수진 ',
#  '종로3가(319)',
#  ' 우장산 ',
#  '쌍문(413)',
#  ' 청량리(지하)(158) ',
#  ' 서대문 ',
#  '독바위',
#  ' 천왕 ',
#  ' 광화문 ',
#  '미아(415)',
#  '신중동',
#  '가락시장(8)',
#  '광흥창',
#  ' 뚝섬유원지 ',
#  ' 청담 ',
#  ' 교대(330) ',
#  '고덕',
#  ' 몽촌토성 ',
#  '연신내(6)',
#  ' 불광(6) ',
#  '종로3가(5)',
#  '한강진',
#  ' 어린이대공원 ',
#  '강변(214)',
#  '학여울(336)',
#  ' 도봉산(7) ',
#  '건대입구(7)',
#  '상계(410)',
#  '상왕십리(207)',
#  '길음(417)',
#  '옥수(325)',
#  '가산디지털단지(7)',
#  '마곡',
#  ' 광명사거리 ',
#  '장승배기',
#  '춘의',
#  ' 오목교 ',
#  '마들',
#  '잠실새내(217)',
#  '노원(7)',
#  '보문',
#  '미아삼거리(416)',
#  '논현',
#  '디지털미디어시티(6)',
#  ' 문래(235) ',
#  ' 녹사평 ',
#  '동대문(155)',
#  ' 고덕 ',
#  '종로3가(153)',
#  ' 목동 ',
#  '오목교',
#  ' 고속터미널(7) ',
#  '합정(238)',
#  ' 당고개(409) ',
#  '발산',
#  '창신',
#  ' 송파 ',
#  '사당(433)',
#  ' 공덕(6) ',
#  '교대(223)',
#  '천호(5)',
#  '대흥',
#  '일원(338)',
#  '신천(217)',
#  '역삼(221)',
#  '삼성(219)',
#  ' 답십리 ',
#  ' 개롱 ',
#  '청담',
#  ' 신설동(156) ',
#  '잠실나루(215)',
#  '김포공항(5)',
#  '철산',
#  '암사',
#  '홍대입구(239)',
#  '거여',
#  ' 혜화(420) ',
#  ' 건대입구(7) ',
#  ' 반포 ',
#  '길동',
#  ' 천호(5) ',
#  '당고개(409)',
#  '개롱',
#  '동대문(421)',
#  '석계(6)',
#  '충정로(243)',
#  '약수(323)',
#  '매봉(333)',
#  ' 구산 ',
#  ' 양평(5) ',
#  '이태원',
#  ' 화랑대 ',
#  ' 강동구청 ',
#  ' 동묘앞(159) ',
#  '개화산',
#  '안암',
#  ' 동대문역사문화공원5 ',
#  '신도림(234)',
#  '제기동(157)',
#  ' 도림천(247) ',
#  ' 광나루 ',
#  '독립문(316)',
#  ' 대청(337) ',
#  ' 약수(6) ',
#  ' 양천구청(248) ',
#  '홍제(314)',
#  ' 을지로4가(204) ',
#  ' 중계 ',
#  ' 여의나루 ',
#  '몽촌토성',
#  ' 왕십리(5) ',
#  '신당(6)',
#  ' 고려대 ',
#  '수유(강북구청)(414)',
#  ' 신금호 ',
#  ' 삼성(219) ',
#  ' 학동 ',
#  '건대입구(212)',
#  '신금호',
#  ' 까치산(5) ',
#  ' 을지로4가(5) ',
#  ' 영등포구청(5) ',
#  ' 군자(7) ',
#  '을지로3가(320)',
#  ' 제기동(157) ',
#  ' 동대문운동장(422) ',
#  ' 상봉(7) ',
#  ' 신도림(234) ',
#  '도곡(334)',
#  ' 홍제(314) ',
#  ' 사당(433) ',
#  '창동(412)',
#  '수진',
#  ' 가락시장(8) ',
#  ' 화곡 ',
#  '봉화산',
#  ' 종로3가(319) ',
#  '이대(241)',
#  '구파발(310)',
#  ' 암사 ',
#  '강남구청',
#  '양재(332)',
#  '장한평',
#  ' 돌곶이 ',
#  ' 응암 ',
#  '천호(8)',
#  '문정',
#  ' 종각(152) ',
#  ' 을지로3가(320) ',
#  '방화',
#  ' 단대오거리 ',
#  ' 약수(323) ',
#  ' 철산 ',
#  '숭실대입구',
#  '을지로4가(5)',
#  '신정',
#  '신흥',
#  '종합운동장(218)',
#  '장암',
#  '강남(222)',
#  ' 이태원 ',
#  '올림픽공원',
#  '용답(244)',
#  ' 마들 ',
#  '남태령(434)',
#  '서울역(426)',
#  '굴포천',
#  '양평(5)',
#  ' 신흥 ',
#  '공덕(5)',
#  ' 영등포구청(236) ',
#  ' 매봉(333) ',
#  ' 보문 ',
#  ' 방배(225) ',
#  '내방',
#  '학동',
#  ' 종로3가(5) ',
#  ' 여의도(5) ',
#  '신풍',
#  '신사(327)',
#  ' 양재(332) ',
#  ' 신대방삼거리 ',
#  ' 신정네거리(249) ',
#  ' 마장 ',
#  ' 구로디지털단지(232) ',
#  ' 봉천(229) ',
#  '까치산(5)',
#  ' 광흥창 ',
#  '종로5가(154)',
#  '대치(335)',
#  ' 논현 ',
#  ' 봉화산 ',
#  ' 신답(245) ',
#  '왕십리(5)',
#  ' 장암 ',
#  '한양대(209)',
#  '왕십리(성동구청)(208)',
#  '합정(6)',
#  ' 신림(230) ',
#  '녹번(313)',
#  ' 증산 ',
#  ' 남태령(434) ',
#  ' 합정(6) ',
#  ' 신사(327) ',
#  '석촌',
#  '여의도(5)',
#  '강동',
#  '신대방(231)',
#  ' 성내(215) ',
#  '상수',
#  ' 문정 ',
#  '종각(152)',
#  '방배(225)',
#  '동대문역사문화공원(422)',
#  ' 명동(424) ',
#  '동대문운동장(205)',
#  '동묘앞(6)',
#  ' 상일동 ',
#  ' 종로5가(154) ',
#  ' 동작(431) ',
#  '마포구청',
#  ' 잠실(8) ',
#  '용두(250)',
#  ' 동대문운동장(205) ',
#  ' 을지로3가(203) ',
#  ' 장지 ',
#  '을지로4가(204)',
#  ' 한성대입구(419) ',
#  '명동(424)',
#  ' 장한평 ',
#  '사당(226)',
#  '서대문',
#  ' 일원(338) ',
#  ' 영등포시장 ',
#  ' 먹골 ',
#  '군자(7)',
#  ' 상계(410) ',
#  ' 공덕(5) ',
#  '중곡',
#  '연신내(311)',
#  '월곡',
#  '고속터미널(329)',
#  '부평구청(7)',
#  ' 지축(309) ',
#  '구로디지털단지(232)',
#  ' 도곡(334) ',
#  ' 청구(5) ',
#  ' 서초(224) ',
#  ' 효창공원앞 ',
#  ' 남구로 ',
#  ' 방이 ',
#  '면목',
#  '녹사평',
#  '금호(324)',
#  ' 동대입구(322) ',
#  '어린이대공원',
#  '압구정(326)',
#  '오금(342)',
#  '하계',
#  '역촌',
#  ' 노원(7) ',
#  ' 강변(214) ',
#  ' 서울역(426) ',
#  ' 중곡 ',
#  ' 거여 ',
#  '마천',
#  ' 버티고개 ',
#  '송정',
#  '신대방삼거리',
#  '우장산',
#  '약수(6)',
#  '총신대입구(432)',
#  ' 신촌(240) ',
#  ' 신설동(246) ',
#  '대청(337)',
#  ' 뚝섬(210) ',
#  '수락산',
#  '상도',
#  ' 신대방(231) ',
#  ' 구파발(310) ',
#  ' 석촌 ',
#  '굽은다리',
#  '버티고개',
#  ' 망원 ',
#  ' 상수 ',
#  '광화문',
#  ' 청구(6) ',
#  '돌곶이',
#  ' 용답(244) ',
#  ' 길동 ',
#  ' 용두(250) ',
#  '충정로(5)',
#  ' 오금 ',
#  ' 창신 ',
#  '증산',
#  ' 신길(5) ',
#  ' 학여울(336) ',
#  '미아사거리(416)',
#  '성내(215)',
#  '행당',
#  ' 신풍 ',
#  '삼각지(428)',
#  '동대문역사문화공원5',
#  ' 올림픽공원 ',
#  '동대입구(322)',
#  '혜화(420)',
#  '보라매',
#  '용마산',
#  ' 노원(411) ']

# %%
data1 = df[df[' 역명 ']==s[0]]

# %%
data1
# Out:
#                  날짜    역번호           역명    구분   05~06   06~07   07~08   \
# 32       2008-01-01     207   상왕십리(207)    승차     130     131     117
# 33       2008-01-01     207   상왕십리(207)    하차      23     123     103
# 556      2008-01-02     207   상왕십리(207)    승차     225     393   1,177
# 557      2008-01-02     207   상왕십리(207)    하차      19     130     376
# 1080     2008-01-03     207   상왕십리(207)    승차     220     362   1,163
# 1081     2008-01-03     207   상왕십리(207)    하차      21     127     325
# 1604     2008-01-04     207   상왕십리(207)    승차     224     364   1,129
# 1605     2008-01-04     207   상왕십리(207)    하차      24     149     359
# 2128     2008-01-05     207   상왕십리(207)    승차     197     255     460
# 2129     2008-01-05     207   상왕십리(207)    하차      26     135     213
# 2652     2008-01-06     207   상왕십리(207)    승차     109     170     179
# 2653     2008-01-06     207   상왕십리(207)    하차       9     101     120
# 3176     2008-01-07     207   상왕십리(207)    승차     252     453   1,273
# 3177     2008-01-07     207   상왕십리(207)    하차      26     142     439
# 3700     2008-01-08     207   상왕십리(207)    승차     241     429   1,194
# 3701     2008-01-08     207   상왕십리(207)    하차      19     150     372
# 4224     2008-01-09     207   상왕십리(207)    승차     217     429   1,193
# 4225     2008-01-09     207   상왕십리(207)    하차      25     146     394
# 4748     2008-01-10     207   상왕십리(207)    승차     233     397   1,137
# 4749     2008-01-10     207   상왕십리(207)    하차      22     173     401
# 5272     2008-01-11     207   상왕십리(207)    승차     218     393   1,137
# 5273     2008-01-11     207   상왕십리(207)    하차      34     151     340
# 5796     2008-01-12     207   상왕십리(207)    승차     190     262     463
# 5797     2008-01-12     207   상왕십리(207)    하차      23     133     231
# 6320     2008-01-13     207   상왕십리(207)    승차     114     161     182
# 6321     2008-01-13     207   상왕십리(207)    하차      21     114     100
# 6844     2008-01-14     207   상왕십리(207)    승차     255     384   1,244
# 6845     2008-01-14     207   상왕십리(207)    하차      21     132     414
# 7368     2008-01-15     207   상왕십리(207)    승차     201     386   1,194
# 7369     2008-01-15     207   상왕십리(207)    하차      26     147     331
# ...              ...    ...          ...   ...     ...     ...     ...
# 184316   2008-12-17     207   상왕십리(207)    승차     202     307   1,081
# 184317   2008-12-17     207   상왕십리(207)    하차      18     151     401
# 184842   2008-12-18     207   상왕십리(207)    승차     185     333   1,052
# 184843   2008-12-18     207   상왕십리(207)    하차      22     128     343
# 185368   2008-12-19     207   상왕십리(207)    승차     202     300   1,060
# 185369   2008-12-19     207   상왕십리(207)    하차      15     159     370
# 185894   2008-12-20     207   상왕십리(207)    승차     155     212     466
# 185895   2008-12-20     207   상왕십리(207)    하차      24     123     217
# 186420   2008-12-21     207   상왕십리(207)    승차      91     126     174
# 186421   2008-12-21     207   상왕십리(207)    하차      15     114     127
# 186946   2008-12-22     207   상왕십리(207)    승차     176     345   1,062
# 186947   2008-12-22     207   상왕십리(207)    하차      18     131     401
# 187472   2008-12-23     207   상왕십리(207)    승차     169     314   1,075
# 187473   2008-12-23     207   상왕십리(207)    하차      15     142     361
# 187998   2008-12-24     207   상왕십리(207)    승차     195     288     969
# 187999   2008-12-24     207   상왕십리(207)    하차      24     132     350
# 188524   2008-12-25     207   상왕십리(207)    승차     121     127     190
# 188525   2008-12-25     207   상왕십리(207)    하차      17     122     137
# 189050   2008-12-26     207   상왕십리(207)    승차     166     275     835
# 189051   2008-12-26     207   상왕십리(207)    하차      17     125     331
# 189576   2008-12-27     207   상왕십리(207)    승차     168     187     341
# 189577   2008-12-27     207   상왕십리(207)    하차      24     130     191
# 190102   2008-12-28     207   상왕십리(207)    승차      96     141     160
# 190103   2008-12-28     207   상왕십리(207)    하차      17      94     141
# 190628   2008-12-29     207   상왕십리(207)    승차     181     302     999
# 190629   2008-12-29     207   상왕십리(207)    하차      12     138     415
# 191154   2008-12-30     207   상왕십리(207)    승차     182     263     942
# 191155   2008-12-30     207   상왕십리(207)    하차      20     134     377
# 191680   2008-12-31     207   상왕십리(207)    승차     139     251     779
# 191681   2008-12-31     207   상왕십리(207)    하차      14     120     321
#
#         08~09   09~10   10~11  ...  16~17   17~18   18~19   19~20   20~21   \
# 32        210     259     288  ...    363     334     307     240     211
# 33        108     147     149  ...    341     385     379     334     355
# 556     2,029     893     488  ...    601     781   1,053     695     454
# 557     1,601     715     440  ...    534     681   1,042   1,165     815
# 1080    2,089     964     590  ...    665     711   1,041     718     420
# 1081    1,667     759     427  ...    589     678   1,163   1,129     749
# 1604    2,090     945     608  ...    661     774   1,145     735     472
# 1605    1,610     727     497  ...    638     748   1,181   1,191     784
# 2128      974     799     589  ...    739     709     681     507     396
# 2129      670     600     357  ...    661     836     888     701     508
# 2652      370     498     444  ...    503     427     327     286     250
# 2653      211     340     330  ...    510     538     544     479     461
# 3176    2,141     975     607  ...    612     776   1,064     723     449
# 3177    1,630     774     475  ...    645     729   1,175   1,210     743
# 3700    2,130     996     580  ...    612     809   1,108     669     473
# 3701    1,609     928     438  ...    635     698   1,254   1,166     745
# 4224    2,087     980     574  ...    748     661   1,101     705     481
# 4225    1,557     868     497  ...    617     713   1,231   1,225     757
# 4748    2,122     953     575  ...    608     773   1,106     766     488
# 4749    1,676     943     426  ...    665     706   1,115   1,216     754
# 5272    2,236   1,053     655  ...    589     775   1,135     792     487
# 5273    1,571     976     509  ...    640     752   1,263   1,314     764
# 5796      951     790     538  ...    801     800     758     504     344
# 5797      824     601     393  ...    700     843     880     660     529
# 6320      416     475     471  ...    420     433     386     350     211
# 6321      197     242     386  ...    484     602     594     436     415
# 6844    2,088     960     562  ...    593     801   1,115     716     473
# 6845    1,709     725     461  ...    592     639   1,181   1,170     810
# 7368    2,117     927     578  ...    558     816   1,056     757     436
# 7369    1,743     675     442  ...    698     677   1,177   1,154     760
# ...        ...     ...     ... ...     ...     ...     ...     ...     ...
# 184316  1,924     779     529  ...    570     708   1,058     650     431
# 184317  1,615     789     471  ...    583     687   1,067     954     607
# 184842  1,929     798     561  ...    504     730   1,111     674     421
# 184843  1,607     788     468  ...    610     643   1,022     962     566
# 185368  1,962     813     541  ...    577     769   1,175     927     460
# 185369  1,583     762     454  ...    593     682     997   1,887     643
# 185894    925     610     485  ...    644     801     709     542     405
# 185895    689     543     371  ...    662     791     724     553     448
# 186420    315     451     432  ...    507     474     354     235     216
# 186421    169     400     384  ...    393     461     517     377     369
# 186946  1,983     738     462  ...    541     709   1,026     690     390
# 186947  1,693     754     424  ...    567     657   1,008     900     561
# 187472  1,916     853     525  ...    590     816   1,118     693     413
# 187473  1,698     763     420  ...    588     646   1,073     948     584
# 187998  1,909     766     517  ...    612     863   1,286     949     578
# 187999  1,402     758     449  ...    631     749   1,077   1,264     709
# 188524    344     384     399  ...    403     461     372     339     259
# 188525    359     418     440  ...    370     482     524     397     357
# 189050  1,721     695     513  ...    528     700   1,058     710     416
# 189051  1,446     703     472  ...    529     602     924     929     572
# 189576    696     582     436  ...    615     751     595     405     339
# 189577    623     532     311  ...    513     615     735     590     469
# 190102    290     360     390  ...    492     389     318     238     223
# 190103    159     291     354  ...    379     482     432     363     370
# 190628  1,713     779     563  ...    540     678   1,008     644     382
# 190629  1,690     656     488  ...    562     616     988     854     578
# 191154  1,667     747     519  ...    498     705     985     629     416
# 191155  1,462     714     397  ...    516     624     859     893     572
# 191680  1,571     689     525  ...    730     742     948     617     411
# 191681  1,405     678     433  ...    581     749     983     748     573
#
#         21~22   22~23   23~24   24~  역명
# 32        157     132      49    48
# 33        366     356     202    82
# 556       334     241     112     9
# 557       648     661     436   114
# 1080      397     304     130    36
# 1081      759     697     488   173
# 1604      466     360     143    25
# 1605      690     757     484   211
# 2128      317     266     126     4
# 2129      589     563     423    20
# 2652      208     168      86     0
# 2653      465     448     272     1
# 3176      404     282     112    10
# 3177      696     738     408   154
# 3700      387     327     124    30
# 3701      702     748     466   187
# 4224      370     314     140    27
# 4225      657     789     426   208
# 4748      345     316     151    28
# 4749      677     690     504   194
# 5272      488     360     198    30
# 5273      681     692     603   229
# 5796      319     253     111     6
# 5797      587     590     400    23
# 6320      243     175      42     0
# 6321      442     432     276     0
# 6844      390     274      98    10
# 6845      727     677     452   124
# 7368      387     292      93    16
# 7369      617     765     461   161
# ...        ...     ...     ...   ... ..
# 184316    376     352     136    33
# 184317    564     581     442   171
# 184842    367     317     140    25
# 184843    580     668     415   206
# 185368    434     316     166    25
# 185369    517     623     443   269
# 185894    251     234      90     7
# 185895    451     478     389    43
# 186420    206     127      50     2
# 186421    368     413     258     7
# 186946    380     287     126    22
# 186947    537     563     458   218
# 187472    424     308     141    22
# 187473    583     599     471   222
# 187998    473     334     170    32
# 187999    572     553     486   260
# 188524    198     149      81     7
# 188525    399     381     245    27
# 189050    408     295     118    22
# 189051    458     526     416   162
# 189576    256     253      81     5
# 189577    393     424     353    19
# 190102    167     135      55     0
# 190103    379     357     248     0
# 190628    307     269     126    23
# 190629    518     528     445   166
# 191154    386     297     119    25
# 191155    507     616     485   169
# 191680    335     286     154    82
# 191681    491     490     350   320
#
# [732 rows x 25 columns]

# %%
data1_a = data1[' 05~06 ']

# %%
data1_a
# Out:
# 32        130
# 33         23
# 556       225
# 557        19
# 1080      220
# 1081       21
# 1604      224
# 1605       24
# 2128      197
# 2129       26
# 2652      109
# 2653        9
# 3176      252
# 3177       26
# 3700      241
# 3701       19
# 4224      217
# 4225       25
# 4748      233
# 4749       22
# 5272      218
# 5273       34
# 5796      190
# 5797       23
# 6320      114
# 6321       21
# 6844      255
# 6845       21
# 7368      201
# 7369       26
#           ...
# 184316    202
# 184317     18
# 184842    185
# 184843     22
# 185368    202
# 185369     15
# 185894    155
# 185895     24
# 186420     91
# 186421     15
# 186946    176
# 186947     18
# 187472    169
# 187473     15
# 187998    195
# 187999     24
# 188524    121
# 188525     17
# 189050    166
# 189051     17
# 189576    168
# 189577     24
# 190102     96
# 190103     17
# 190628    181
# 190629     12
# 191154    182
# 191155     20
# 191680    139
# 191681     14
# Name:  05~06 , Length: 732, dtype: object

# %%
data1_a = data1[' 05~06 '].values

# %%
type(data1_a)
# Out:
# numpy.ndarray

# %%
data1_a = data1_a.reshape(len(data1_a), 1)
data1_a
# Out:
# array([['130 '],
#        ['23 '],
#        ['225 '],
#        ['19 '],
#        ['220 '],
#        ['21 '],
#        ['224 '],
#        ['24 '],
#        ['197 '],
#        ['26 '],
#        ['109 '],
#        ['9 '],
#        ['252 '],
#        ['26 '],
#        ['241 '],
#        ['19 '],
#        ['217 '],
#        ['25 '],
#        ['233 '],
#        ['22 '],
#        ['218 '],
#        ['34 '],
#        ['190 '],
#        ['23 '],
#        ['114 '],
#        ['21 '],
#        ['255 '],
#        ['21 '],
#        ['201 '],
#        ['26 '],
#        ['198 '],
#        ['24 '],
#        ['174 '],
#        ['20 '],
#        ['199 '],
#        ['21 '],
#        ['171 '],
#        ['24 '],
#        ['109 '],
#        ['11 '],
#        ['231 '],
#        ['24 '],
#        ['215 '],
#        ['26 '],
#        ['215 '],
#        ['27 '],
#        ['208 '],
#        ['17 '],
#        ['195 '],
#        ['27 '],
#        ['187 '],
#        ['31 '],
#        ['115 '],
#        ['20 '],
#        ['226 '],
#        ['20 '],
#        ['205 '],
#        ['21 '],
#        ['215 '],
#        ['23 '],
#        ['207 '],
#        ['18 '],
#        ['215 '],
#        ['24 '],
#        ['169 '],
#        ['22 '],
#        ['122 '],
#        ['19 '],
#        ['219 '],
#        ['27 '],
#        ['173 '],
#        ['20 '],
#        ['97 '],
#        ['21 '],
#        ['90 '],
#        ['8 '],
#        ['57 '],
#        ['16 '],
#        ['101 '],
#        ['19 '],
#        ['70 '],
#        ['15 '],
#        ['234 '],
#        ['15 '],
#        ['222 '],
#        ['25 '],
#        ['211 '],
#        ['17 '],
#        ['225 '],
#        ['26 '],
#        ['218 '],
#        ['20 '],
#        ['184 '],
#        ['24 '],
#        ['126 '],
#        ['11 '],
#        ['246 '],
#        ['22 '],
#        ['210 '],
#        ['19 '],
#        ['206 '],
#        ['20 '],
#        ['210 '],
#        ['13 '],
#        ['219 '],
#        ['24 '],
#        ['218 '],
#        ['22 '],
#        ['96 '],
#        ['11 '],
#        ['276 '],
#        ['14 '],
#        ['193 '],
#        ['20 '],
#        ['230 '],
#        ['16 '],
#        ['237 '],
#        ['16 '],
#        ['224 '],
#        ['16 '],
#        ['166 '],
#        ['22 '],
#        ['122 '],
#        ['19 '],
#        ['249 '],
#        ['23 '],
#        ['245 '],
#        ['15 '],
#        ['243 '],
#        ['23 '],
#        ['265 '],
#        ['13 '],
#        ['245 '],
#        ['24 '],
#        ['243 '],
#        ['16 '],
#        ['128 '],
#        ['13 '],
#        ['268 '],
#        ['17 '],
#        ['242 '],
#        ['18 '],
#        ['246 '],
#        ['19 '],
#        ['236 '],
#        ['18 '],
#        ['245 '],
#        ['13 '],
#        ['224 '],
#        ['16 '],
#        ['133 '],
#        ['8 '],
#        ['264 '],
#        ['16 '],
#        ['252 '],
#        ['17 '],
#        ['237 '],
#        ['17 '],
#        ['255 '],
#        ['16 '],
#        ['238 '],
#        ['22 '],
#        ['228 '],
#        ['17 '],
#        ['98 '],
#        ['6 '],
#        ['268 '],
#        ['19 '],
#        ['249 '],
#        ['16 '],
#        ['239 '],
#        ['15 '],
#        ['258 '],
#        ['23 '],
#        ['249 '],
#        ['23 '],
#        ['213 '],
#        ['18 '],
#        ['122 '],
#        ['17 '],
#        ['284 '],
#        ['15 '],
#        ['253 '],
#        ['17 '],
#        ['230 '],
#        ['22 '],
#        ['231 '],
#        ['17 '],
#        ['254 '],
#        ['19 '],
#        ['213 '],
#        ['16 '],
#        ['117 '],
#        ['16 '],
#        ['262 '],
#        ['19 '],
#        ['283 '],
#        ['20 '],
#        ['155 '],
#        ['16 '],
#        ['265 '],
#        ['23 '],
#        ['256 '],
#        ['18 '],
#        ['154 '],
#        ['13 '],
#        ['127 '],
#        ['12 '],
#        ['180 '],
#        ['10 '],
#        ['262 '],
#        ['18 '],
#        ['243 '],
#        ['18 '],
#        ['258 '],
#        ['13 '],
#        ['234 '],
#        ['20 '],
#        ['212 '],
#        ['13 '],
#        ['121 '],
#        ['21 '],
#        ['281 '],
#        ['13 '],
#        ['252 '],
#        ['18 '],
#        ['247 '],
#        ['19 '],
#        ['291 '],
#        ['17 '],
#        ['243 '],
#        ['18 '],
#        ['239 '],
#        ['24 '],
#        ['163 '],
#        ['14 '],
#        ['326 '],
#        ['21 '],
#        ['270 '],
#        ['16 '],
#        ['267 '],
#        ['13 '],
#        ['190 '],
#        ['18 '],
#        ['292 '],
#        ['17 '],
#        ['260 '],
#        ['22 '],
#        ['150 '],
#        ['21 '],
#        ['216 '],
#        ['22 '],
#        ['331 '],
#        ['19 '],
#        ['280 '],
#        ['17 '],
#        ['281 '],
#        ['19 '],
#        ['277 '],
#        ['16 '],
#        ['258 '],
#        ['23 '],
#        ['155 '],
#        ['18 '],
#        ['195 '],
#        ['22 '],
#        ['280 '],
#        ['17 '],
#        ['285 '],
#        ['24 '],
#        ['273 '],
#        ['21 '],
#        ['265 '],
#        ['18 '],
#        ['158 '],
#        ['12 '],
#        ['142 '],
#        ['19 '],
#        ['289 '],
#        ['24 '],
#        ['270 '],
#        ['22 '],
#        ['277 '],
#        ['19 '],
#        ['261 '],
#        ['26 '],
#        ['280 '],
#        ['23 '],
#        ['266 '],
#        ['36 '],
#        ['168 '],
#        ['19 '],
#        ['297 '],
#        ['23 '],
#        ['282 '],
#        ['20 '],
#        ['190 '],
#        ['19 '],
#        ['278 '],
#        ['20 '],
#        ['277 '],
#        ['27 '],
#        ['275 '],
#        ['30 '],
#        ['126 '],
#        ['23 '],
#        ['322 '],
#        ['17 '],
#        ['246 '],
#        ['22 '],
#        ['272 '],
#        ['18 '],
#        ['208 '],
#        ['20 '],
#        ['241 '],
#        ['19 '],
#        ['243 '],
#        ['32 '],
#        ['149 '],
#        ['10 '],
#        ['305 '],
#        ['25 '],
#        ['294 '],
#        ['17 '],
#        ['280 '],
#        ['25 '],
#        ['304 '],
#        ['21 '],
#        ['264 '],
#        ['24 '],
#        ['233 '],
#        ['25 '],
#        ['138 '],
#        ['20 '],
#        ['327 '],
#        ['25 '],
#        ['236 '],
#        ['22 '],
#        ['213 '],
#        ['17 '],
#        ['270 '],
#        ['28 '],
#        ['269 '],
#        ['20 '],
#        ['243 '],
#        ['30 '],
#        ['131 '],
#        ['18 '],
#        ['281 '],
#        ['19 '],
#        ['263 '],
#        ['17 '],
#        ['263 '],
#        ['19 '],
#        ['255 '],
#        ['16 '],
#        ['246 '],
#        ['26 '],
#        ['262 '],
#        ['26 '],
#        ['99 '],
#        ['24 '],
#        ['266 '],
#        ['19 '],
#        ['258 '],
#        ['29 '],
#        ['217 '],
#        ['15 '],
#        ['202 '],
#        ['21 '],
#        ['245 '],
#        ['21 '],
#        ['227 '],
#        ['25 '],
#        ['128 '],
#        ['19 '],
#        ['296 '],
#        ['24 '],
#        ['272 '],
#        ['22 '],
#        ['266 '],
#        ['26 '],
#        ['282 '],
#        ['25 '],
#        ['248 '],
#        ['23 '],
#        ['203 '],
#        ['25 '],
#        ['86 '],
#        ['13 '],
#        ['275 '],
#        ['20 '],
#        ['254 '],
#        ['21 '],
#        ['240 '],
#        ['20 '],
#        ['250 '],
#        ['22 '],
#        ['260 '],
#        ['20 '],
#        ['221 '],
#        ['23 '],
#        ['103 '],
#        ['19 '],
#        ['230 '],
#        ['20 '],
#        ['244 '],
#        ['16 '],
#        ['257 '],
#        ['26 '],
#        ['170 '],
#        ['17 '],
#        ['210 '],
#        ['23 '],
#        ['200 '],
#        ['19 '],
#        ['119 '],
#        ['18 '],
#        ['284 '],
#        ['21 '],
#        ['238 '],
#        ['28 '],
#        ['249 '],
#        ['23 '],
#        ['227 '],
#        ['29 '],
#        ['212 '],
#        ['13 '],
#        ['180 '],
#        ['13 '],
#        ['119 '],
#        ['14 '],
#        ['252 '],
#        ['21 '],
#        ['252 '],
#        ['22 '],
#        ['259 '],
#        ['26 '],
#        ['254 '],
#        ['21 '],
#        ['245 '],
#        ['28 '],
#        ['234 '],
#        ['21 '],
#        ['120 '],
#        ['16 '],
#        ['271 '],
#        ['20 '],
#        ['178 '],
#        ['20 '],
#        ['191 '],
#        ['14 '],
#        ['241 '],
#        ['23 '],
#        ['202 '],
#        ['13 '],
#        ['167 '],
#        ['24 '],
#        ['138 '],
#        ['20 '],
#        ['209 '],
#        ['17 '],
#        ['234 '],
#        ['24 '],
#        ['233 '],
#        ['22 '],
#        ['230 '],
#        ['19 '],
#        ['198 '],
#        ['25 '],
#        ['195 '],
#        ['24 '],
#        ['131 '],
#        ['22 '],
#        ['261 '],
#        ['20 '],
#        ['240 '],
#        ['26 '],
#        ['254 '],
#        ['20 '],
#        ['238 '],
#        ['28 '],
#        ['245 '],
#        ['30 '],
#        ['241 '],
#        ['23 '],
#        ['160 '],
#        ['19 '],
#        ['221 '],
#        ['21 '],
#        ['224 '],
#        ['21 '],
#        ['249 '],
#        ['22 '],
#        ['251 '],
#        ['14 '],
#        ['241 '],
#        ['21 '],
#        ['211 '],
#        ['22 '],
#        ['130 '],
#        ['18 '],
#        ['287 '],
#        ['17 '],
#        ['245 '],
#        ['22 '],
#        ['258 '],
#        ['16 '],
#        ['243 '],
#        ['20 '],
#        ['175 '],
#        ['20 '],
#        ['98 '],
#        ['16 '],
#        ['62 '],
#        ['8 '],
#        ['69 '],
#        ['12 '],
#        ['165 '],
#        ['19 '],
#        ['248 '],
#        ['25 '],
#        ['260 '],
#        ['20 '],
#        ['242 '],
#        ['25 '],
#        ['248 '],
#        ['22 '],
#        ['113 '],
#        ['14 '],
#        ['0 '],
#        ['0 '],
#        ['266 '],
#        ['25 '],
#        ['256 '],
#        ['23 '],
#        ['206 '],
#        ['11 '],
#        ['251 '],
#        ['19 '],
#        ['197 '],
#        ['23 '],
#        ['127 '],
#        ['18 '],
#        ['241 '],
#        ['19 '],
#        ['240 '],
#        ['22 '],
#        ['211 '],
#        ['16 '],
#        ['231 '],
#        ['16 '],
#        ['179 '],
#        ['20 '],
#        ['221 '],
#        ['21 '],
#        ['122 '],
#        ['13 '],
#        ['272 '],
#        ['14 '],
#        ['265 '],
#        ['24 '],
#        ['261 '],
#        ['14 '],
#        ['277 '],
#        ['22 '],
#        ['247 '],
#        ['15 '],
#        ['194 '],
#        ['22 '],
#        ['118 '],
#        ['9 '],
#        ['233 '],
#        ['20 '],
#        ['243 '],
#        ['16 '],
#        ['214 '],
#        ['14 '],
#        ['233 '],
#        ['20 '],
#        ['221 '],
#        ['16 '],
#        ['227 '],
#        ['13 '],
#        ['121 '],
#        ['11 '],
#        ['252 '],
#        ['11 '],
#        ['253 '],
#        ['14 '],
#        ['242 '],
#        ['15 '],
#        ['213 '],
#        ['24 '],
#        ['235 '],
#        ['11 '],
#        ['214 '],
#        ['25 '],
#        ['134 '],
#        ['5 '],
#        ['256 '],
#        ['21 '],
#        ['244 '],
#        ['16 '],
#        ['228 '],
#        ['22 '],
#        ['246 '],
#        ['19 '],
#        ['175 '],
#        ['20 '],
#        ['222 '],
#        ['23 '],
#        ['132 '],
#        ['13 '],
#        ['255 '],
#        ['19 '],
#        ['231 '],
#        ['23 '],
#        ['243 '],
#        ['26 '],
#        ['236 '],
#        ['20 '],
#        ['246 '],
#        ['18 '],
#        ['219 '],
#        ['24 '],
#        ['125 '],
#        ['16 '],
#        ['272 '],
#        ['22 '],
#        ['216 '],
#        ['22 '],
#        ['216 '],
#        ['15 '],
#        ['227 '],
#        ['16 '],
#        ['207 '],
#        ['21 '],
#        ['186 '],
#        ['34 '],
#        ['82 '],
#        ['23 '],
#        ['253 '],
#        ['23 '],
#        ['219 '],
#        ['18 '],
#        ['219 '],
#        ['23 '],
#        ['202 '],
#        ['17 '],
#        ['206 '],
#        ['16 '],
#        ['181 '],
#        ['21 '],
#        ['106 '],
#        ['18 '],
#        ['217 '],
#        ['29 '],
#        ['208 '],
#        ['27 '],
#        ['200 '],
#        ['24 '],
#        ['182 '],
#        ['17 '],
#        ['193 '],
#        ['17 '],
#        ['206 '],
#        ['24 '],
#        ['119 '],
#        ['22 '],
#        ['212 '],
#        ['22 '],
#        ['201 '],
#        ['19 '],
#        ['228 '],
#        ['14 '],
#        ['164 '],
#        ['22 '],
#        ['178 '],
#        ['11 '],
#        ['141 '],
#        ['19 '],
#        ['83 '],
#        ['12 '],
#        ['207 '],
#        ['23 '],
#        ['206 '],
#        ['14 '],
#        ['197 '],
#        ['28 '],
#        ['203 '],
#        ['18 '],
#        ['200 '],
#        ['22 '],
#        ['194 '],
#        ['23 '],
#        ['106 '],
#        ['23 '],
#        ['225 '],
#        ['25 '],
#        ['206 '],
#        ['22 '],
#        ['202 '],
#        ['18 '],
#        ['185 '],
#        ['22 '],
#        ['202 '],
#        ['15 '],
#        ['155 '],
#        ['24 '],
#        ['91 '],
#        ['15 '],
#        ['176 '],
#        ['18 '],
#        ['169 '],
#        ['15 '],
#        ['195 '],
#        ['24 '],
#        ['121 '],
#        ['17 '],
#        ['166 '],
#        ['17 '],
#        ['168 '],
#        ['24 '],
#        ['96 '],
#        ['17 '],
#        ['181 '],
#        ['12 '],
#        ['182 '],
#        ['20 '],
#        ['139 '],
#        ['14 ']], dtype=object)

# %%
# 데이터셋 전처리
scaler = MinMaxScaler(feature_range=(0, 1))
signal_data = scaler.fit_transform(data1_a)
# Out:
# C:\Users\ML\Anaconda3\envs\me\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
train_size = int(len(signal_data) * 0.80)
test_size = len(signal_data) - train_size

# %%
train = signal_data[0:train_size]
test = signal_data[train_size:len(signal_data)]

# %%
def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data) - look_back):
        dataX.append(signal_data[i:(i + look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

look_back = 10

# %%
x_train, y_train = create_dataset(train, look_back)
x_test, y_test = create_dataset(test, look_back)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
# 모델 구성하기
model = Sequential()
model.add(LSTM(32, input_shape=(None, 1)))
model.add(Dropout(0.3))
model.add(Dense(1))

# %%
# 모델 학습과정 설정하기
model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['accuracy'])

# %%
# 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 575/575 [==============================] - 1s 1ms/step - loss: 0.0716 - acc: 0.0017
# Epoch 2/10
# 575/575 [==============================] - 0s 158us/step - loss: 0.0654 - acc: 0.0035
# Epoch 3/10
# 575/575 [==============================] - 0s 143us/step - loss: 0.0615 - acc: 0.0052
# Epoch 4/10
# 575/575 [==============================] - 0s 146us/step - loss: 0.0577 - acc: 0.0035
# Epoch 5/10
# 575/575 [==============================] - 0s 156us/step - loss: 0.0516 - acc: 0.0017
# Epoch 6/10
# 575/575 [==============================] - 0s 134us/step - loss: 0.0468 - acc: 0.0017
# Epoch 7/10
# 575/575 [==============================] - 0s 141us/step - loss: 0.0422 - acc: 0.0017
# Epoch 8/10
# 575/575 [==============================] - 0s 146us/step - loss: 0.0351 - acc: 0.0017
# Epoch 9/10
# 575/575 [==============================] - 0s 163us/step - loss: 0.0387 - acc: 0.0017
# Epoch 10/10
# 575/575 [==============================] - 0s 139us/step - loss: 0.0316 - acc: 0.0035

# %%
# 모델 평가하기
trainScore = model.evaluate(x_train, y_train, verbose=0)
model.reset_states()
print('Train Score: ', trainScore)

testScore = model.evaluate(x_test, y_test, verbose=0)
model.reset_states()
print('Test Score: ', testScore)
# Out:
# Train Score:  [0.024708444382185522, 0.0034782608695652175]
# Test Score:  [0.016046456958636317, 0.0]

# %%
# 정확도 그리기.
p = model.predict(x_test)

# %%
import matplotlib.pyplot as plt

plt.plot(y_test)
plt.plot(p)
plt.legend(['testY', 'p'], loc='upper right')
plt.show()
